# %% [markdown]
# # **Amazon Analysis**
#
# Nesse projeto, temos como objetivo principal deste projeto analisar os fatores que mais influenciam a satisfação do cliente em produtos vendidos na Amazon.
#
# A análise buscará identificar padrões e tendências que possam ajudar a entender melhor os fatores determinantes para avaliações positivas ou negativas, fornecendo insights para otimização de estratégias de vendas e marketing.

# %% [markdown]
# # **Imports**

# %% [markdown]
# *📍* Imports são a forma de incluir módulos (arquivos de código Python) ou pacotes (coleções de módulos). Isso permite acessar e utilizar funções, classes, variáveis e constantes definidas nesses módulos sem precisar reescrevê-las.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import plotly.express as px

from scipy.stats import normaltest, shapiro, ttest_ind, mannwhitneyu, kruskal
from sklearn.linear_model import LinearRegression
from tabulate import tabulate

# %% [markdown]
# # Tabelas

# %% [markdown]
# 📍 Tabelas utilizadas para essa análise.

# %%
review = pd.read_csv("https://docs.google.com/spreadsheets/d/1XmWsJM8BH8alTV3_tM_amA1sYTl8hcbZyV-uvg9slDo/export?format=csv")

# %%
product = pd.read_csv("https://docs.google.com/spreadsheets/d/1jP7H8lcwyS5SIsaOR6ivHUa6D7vewJYrh9Kj0cJypWM/export?format=csv")

# %% [markdown]
# # **Informações sobre as Tabelas**

# %% [markdown]
# 📍 Informações básicas sobre a tabela review e sobre a tabela product.

# %% [markdown]
# ## **Tabela review**
#
#
# ---

# %% [markdown]
# **Sobre a tabela review:**
#
# * A tabela review é como um grande repositório de opiniões de clientes sobre os produtos vendidos na Amazon. Cada linha dessa tabela captura a avaliação de um usuário sobre um produto específico. Ela nos mostra quem fez a avaliação, o que foi dito, e fornece detalhes tanto sobre o avaliador quanto sobre o produto que está sendo discutido. Em outras palavras, é uma coleção de feedbacks dos clientes, ajudando a entender melhor a experiência de compra de cada pessoa.

# %% [markdown]
# **Insumos da tabela review:**
#
# - user_id: ID do usuário que escreveu a avaliação do produto
# - user_name: nome do usuário que escreveu a avaliação do produto
# - Review_id: ID da avaliação do usuário
# - Review_title: Breve avaliação do usuário
# - Review_content: Avaliação completa do usuário
# - Img_link: link da imagem do produto
# - Product_link: Link para o site oficial do produto
# - Product_id: ID do produto
# - Rating: Classificação do produto
# - Rating_count: número de pessoas que votaram na classificação da Amazon.

# %% [markdown]
# ## **Tabela product**
#
#
# ---

# %% [markdown]
# **Sobre a tabela product:**
#
# * A tabela product é como um catálogo detalhado de todos os produtos disponíveis na Amazon. Cada linha nessa tabela representa um produto diferente, com informações como o nome, preços, descontos, e uma descrição do que ele é e o que faz. Basicamente, é um resumo completo de tudo que está à venda, ajudando a entender cada item e suas características principais.

# %% [markdown]
# **Insumos da tabela product:**
#
# - product_id: ID do produto
# - product_name: nome do produto
# - category: categoria do produto
# - discounted_price: preço com desconto do produto
# - actual_price: preço real do produto
# - discount_percentage: porcentagem de desconto do produto
# - about_product: Descrição sobre o produto

# %% [markdown]
# # **Tabela review**

# %% [markdown]
# ## **Prévia da tabela review**
#
#
# ---

# %%
review.head(2)
# Out:
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  product_id rating  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  B07JW9H4J1    4.2
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...  B098NS6PVG      4
#
#   rating_count
# 0       24,269
# 1       43,994

# %% [markdown]
# ## **Informações sobre os dados da tabela review**
#
#
# ---

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         1465 non-null   object
#  1   user_name       1465 non-null   object
#  2   review_id       1465 non-null   object
#  3   review_title    1465 non-null   object
#  4   review_content  1465 non-null   object
#  5   img_link        999 non-null    object
#  6   product_link    999 non-null    object
#  7   product_id      1465 non-null   object
#  8   rating          1465 non-null   object
#  9   rating_count    1463 non-null   object
# dtypes: object(10)
# memory usage: 114.6+ KB

# %% [markdown]
# Observações:
# * Total de linhas da tabela: 1465.
# * Existem valores nulos nas colunas img_link, product_link, e rating_count.
# * Todas as colunas são do tipo object.

# %% [markdown]
# ## **Dados fora do escopo**
#
#
# ---

# %% [markdown]
# 📍 Excluir dados que não foram considerados necessários para a análise. Para essa análise, a coluna rating_count foi excluída.

# %% [markdown]
# ### **Excluir a coluna rating_count**

# %% [markdown]
# A coluna rating_count contém dados sobre o número de pessoas que votaram na classificação da Amazon. Essa coluna não foi considerada necessária para essa análise.

# %%
# Dropar a coluna rating_count:
review = review.drop('rating_count', axis=1)

# %% [markdown]
# ## **Nulos**
#
#
# ---

# %% [markdown]
# 📍 Identificar e tratar dados nulos da coluna review.

# %% [markdown]
# #### **Total de dados nulos**

# %%
review_null = review.isnull().sum()
print(review_null)
# Out:
# user_id             0
# user_name           0
# review_id           0
# review_title        0
# review_content      0
# img_link          466
# product_link      466
# product_id          0
# rating              0
# dtype: int64

# %% [markdown]
# Observações sobre o total de valores nulos:
# * As colunas img_link e product_link contêm 466 valores nulos.

# %% [markdown]
# #### **Tratar dados nulos**
#
#
# ---

# %%
# Substituir dados nulos pela string "indisponível":
review['img_link'] = review['img_link'].fillna("indisponível")
review['product_link'] = review['product_link'].fillna("indisponível")

# %%
# Conferir o total de nulos após alteração:
review_null = review.isnull().sum()
print(review_null)
# Out:
# user_id           0
# user_name         0
# review_id         0
# review_title      0
# review_content    0
# img_link          0
# product_link      0
# product_id        0
# rating            0
# dtype: int64

# %% [markdown]
# ## **Duplicados**
#
#
# ---

# %% [markdown]
# 📍 Identificar e tratar dados duplicados da tabela review.

# %% [markdown]
# #### **Total de linhas duplicadas**

# %%
review_duplicated = review.duplicated().sum()
print("Total de linhas duplicadas: ",review_duplicated)
# Out:
# Total de linhas duplicadas:  0

# %% [markdown]
# Foi possível observar que a tabela review não possui linhas inteiramente duplicadas.

# %% [markdown]
# #### **Verificar combinações em que user_id, product_id e review_id se repetem**

# %% [markdown]
# Essa análise foi feita para verificar se existem ocorrências de reviews com o mesmo ID de usuário, mesmo ID de produto e mesmo ID de review. Isso é importante para identificar se uma mesma review foi repetida na tabela.

# %%
# Contar a frequência de cada combinação das colunas user_id, product_id e review_id:
combinations_count = review.groupby(['user_id', 'product_id', 'review_id']).size().reset_index(name='combinations')
combinations_count
# Out:
#                                                 user_id  product_id  \
# 0     AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1     AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 2                          AE242TR3GQ6TYC6W4SJ5UYYKBTYQ  B09XJ1LM7R
# 3     AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
# 4     AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2Q4QVQ
# ...                                                 ...         ...
# 1356  AHZFKWGDBRQKNMNQ4ZPL52OZBRKA,AGBEFVJFOQIRF7C7K...  B085LPT5F4
# 1357  AHZJHJWFZLYD64GVP4PXVI2F4LXA,AEUCRZPOISXKHXMCZ...  B0BJ966M5K
# 1358  AHZNSNBVKQR4OGJAQHE4DCDA4YHA,AFBW6COTZXGHQMWVD...  B0B3MWYCHQ
# 1359  AHZWJCVEIEI76H2VGMUSN5D735IQ,AH2DFUHFTG4CKQFVG...  B09W5XR9RT
# 1360  AHZWXUWE3RGLDH4JJUK3HT3VMBJA,AFWUWJMEO4IQEMHKM...  B09HSKYMB3
#
#                                               review_id  combinations
# 0     RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...             1
# 1     R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...             1
# 2                                        R38OAD16RVS9D4             1
# 3     R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...             1
# 4     R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...             1
# ...                                                 ...           ...
# 1356  R2F6HAXHI2E0QM,R3ARFHUPI2UTDN,R2NFBRLIKTBYX6,R...             1
# 1357  R410I44U1ORFS,R2EL6RDO42L8HA,R2LMSC4S998NYI,R2...             1
# 1358  R1AIQQLE21YDXS,R26ABOIUJ8UXJ7,R93L2MCBC4Y90,R2...             2
# 1359  R1Y30KU04V3QF4,RK3DSUGKIZT8Z,R3BIG7J6V2JZTU,R1...             3
# 1360  R1GS92IDBGXYCS,R8H8QTOWYMITR,RCSP9RH3A0VAE,R2S...             1
#
# [1361 rows x 4 columns]

# %% [markdown]
# Observações:
# * Existem combinações de user_id, product_id e review_id que se repetem. Isso indica que existem reviews duplicadas na tabela.

# %% [markdown]
# #### **Total de ocorrências em que user_id, product_id e review_id se repetem**

# %%
# Contagem do total de linhas em que user_id, product_id e review_id se repetem:
duplicates_total = combinations_count[combinations_count['combinations'] > 1].shape[0]
print("Total de combinações de user_id, product_id e review_id que se repetem:", duplicates_total)
# Out:
# Total de combinações de user_id, product_id e review_id que se repetem: 84

# %% [markdown]
# #### **Combinações em que user_id, product_id e review_id se repetem**

# %%
# Analisar linhas em que as combinações de user_id, product_id e review_id se repetem:
combinations_count[combinations_count['combinations'] > 1]
# Out:
#                                                 user_id  product_id  \
# 9     AE2OFVZSIE6KSBAPG6GMKCER35LA,AFEOAY5PB4XEYIOL6...  B07DJLFMPS
# 21    AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...  B08CF3B7N1
# 31    AE47XF2766XJOEOI42DVP2HMB4YQ,AH6JPV326WGUKC2J4...  B07XJYYH7L
# 51    AE6CROVUGPHR7BRT5JASNRWSPBVQ,AHL5MROK5N63VXVBM...  B096VF5YYF
# 73    AEAX7BRPDS3NSYCZQBQDL5DGZDVA,AFI76LT4UP2L3SFJM...  B0B9BD2YL4
# ...                                                 ...         ...
# 1303  AHUH7OYN3LAUATF5EGA575WCDI6A,AFQRX6TAM6CHKARXI...  B09RZS1NQT
# 1320  AHVZCQP5SYIVGZJK4LRP55ZXWETA,AF6YDBL3KYIK3LBKK...  B01GGKYKQM
# 1322  AHW6E5LQ2BDYOIVLAJGDH45J5V5Q,AF74RSGCHPZITVFSZ...  B08DDRGWTJ
# 1358  AHZNSNBVKQR4OGJAQHE4DCDA4YHA,AFBW6COTZXGHQMWVD...  B0B3MWYCHQ
# 1359  AHZWJCVEIEI76H2VGMUSN5D735IQ,AH2DFUHFTG4CKQFVG...  B09W5XR9RT
#
#                                               review_id  combinations
# 9     RPA8V1051ERUL,R2M7ENP70GK5P4,R3PA1IDUY9QNC8,R1...             2
# 21    R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...             3
# 31    RWSHFGBE1WU3I,R1VBNTH3HSMVMB,RTATA9H2ELJ81,R1B...             2
# 51    R1ZQQKZCCG4KD2,R1OHAWNCB4K26S,R1A7EDRAMKIXJ6,R...             2
# 73    R1HOV97NOJFX4W,R3BIRU7WH404ND,RAU26U2KP1OQH,R1...             2
# ...                                                 ...           ...
# 1303  RW294SCHB5QTK,R24AGC1O5RVWYI,R3NT7AA2V3I2FB,R2...             2
# 1320  R1BC08IFG4REKS,R1FJKIHIO54SOW,R3JR48W2CI480,R3...             3
# 1322  R2X090D1YHACKR,R32ZCIH9AFNJ60,R3N57EVVG0EHAF,R...             3
# 1358  R1AIQQLE21YDXS,R26ABOIUJ8UXJ7,R93L2MCBC4Y90,R2...             2
# 1359  R1Y30KU04V3QF4,RK3DSUGKIZT8Z,R3BIG7J6V2JZTU,R1...             3
#
# [84 rows x 4 columns]

# %% [markdown]
# **Buscar linhas por ID para conferir as ocorrências em que as combinações de user_id, product_id e review_id se repetem**

# %%
review[review['product_id'] == "B0B9BD2YL4"]
# Out:
#                                                 user_id  \
# 583   AEAX7BRPDS3NSYCZQBQDL5DGZDVA,AFI76LT4UP2L3SFJM...
# 1017  AEAX7BRPDS3NSYCZQBQDL5DGZDVA,AFI76LT4UP2L3SFJM...
#
#                                               user_name  \
# 583   Ak,Jitesh,anil,Umpo,G'DAS ENTERPRISES,Neetu,Va...
# 1017  Ak,Jitesh,anil,Umpo,G'DAS ENTERPRISES,Neetu,Va...
#
#                                               review_id  \
# 583   R1HOV97NOJFX4W,R3BIRU7WH404ND,RAU26U2KP1OQH,R1...
# 1017  R1HOV97NOJFX4W,R3BIRU7WH404ND,RAU26U2KP1OQH,R1...
#
#                                            review_title  \
# 583   Quite Good,good pencil,Value for money,Brillia...
# 1017  Quite Good,good pencil,Value for money,Brillia...
#
#                                          review_content  \
# 583   After 10 days of use bhaut acha chl rha ha and...
# 1017  After 10 days of use bhaut acha chl rha ha and...
#
#                                                img_link  \
# 583   https://m.media-amazon.com/images/I/217Lv1D3bH...
# 1017                                       indisponível
#
#                                            product_link  product_id rating
# 583   https://www.amazon.in/Wireless-Generation-Sens...  B0B9BD2YL4    4.5
# 1017                                       indisponível  B0B9BD2YL4    4.5

# %% [markdown]
# Observações:
# * No produto cujo product_id é B0B9BD2YL4, os links de img_link e product_link estão indisponíveis em uma das ocorrências. Esse problema não aparece em todas as ocorrências analisadas nesta seção.

# %% [markdown]
# #### **Total de ocorrências em que user_id, product_id, review_id e rating se repetem**

# %%
# Contar a frequência de cada combinação única das colunas user_id, product_id, review_id e rating:
combinations_count_2 = review.groupby(['user_id', 'product_id', 'review_id', 'rating']).size().reset_index(name='combinations')

# Contagem do total de ocorrências em que user_id, product_id, review_id e rating se repetem.
duplicates_total_2 = combinations_count_2[combinations_count_2['combinations'] > 1].shape[0]
print("Total de combinações de user_id, product_id, review_id e rating que se repetem:", duplicates_total_2)
# Out:
# Total de combinações de user_id, product_id, review_id e rating que se repetem: 84

# %% [markdown]
# É interessante notar que o número de ocorrências em que user_id, product_id e review_id se repetem é igual ao número de ocorrências em que user_id, product_id, review_id e **rating** se repetem. A partir dessa observação, inferi que sempre que uma combinação de user_id, product_id e review_id se repete, o valor de rating também se repete. Por isso, optei por calcular a média dos valores de rating ao agrupar os dados por user_id, product_id e review_id.

# %% [markdown]
# #### **Tratar linhas duplicadas**

# %% [markdown]
# Para tratar as linhas duplicadas, agrupei os dados por 'user_id', 'product_id' e 'review_id' e calculei a média de 'rating'.

# %%
# Analisar linha que contém valor não numérico na coluna rating:
review[review['rating'] == "|"]
# Out:
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content      img_link  \
# 1279  Does the job well,doesn't work on sand. though...  indisponível
#
#       product_link  product_id rating
# 1279  indisponível  B08L12N5H1      |

# %%
# Excluir a linha que contém a string "|":
review.drop(review[review['rating'] == "|"].index, inplace=True)

# %%
# Converter a coluna review de object para float:
review['rating'] = review['rating'].astype(float)

# %%
# Calcular a média dos valores da coluna rating para as linhas com valores duplicados:
review_unique = review.groupby(['user_id', 'product_id', 'review_id'], as_index=False)['rating'].mean()

# %%
# Tabela livre repetições:
review_unique.head(3)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 2                       AE242TR3GQ6TYC6W4SJ5UYYKBTYQ  B09XJ1LM7R
#
#                                            review_id  rating
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...     4.4
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...     4.2
# 2                                     R38OAD16RVS9D4     4.3

# %%
# Confirmar que a tabela está livre de combinações repetidas de user_id, product_id e review_id:
combinations_count_2 = review_unique.groupby(['user_id', 'product_id', 'review_id']).size().reset_index(name='combinations')
duplicates_total_2 = combinations_count_2[combinations_count_2['combinations'] > 1].shape[0]
print("Total de combinações de user_id, product_id e review_id que se repetem:", duplicates_total_2)
# Out:
# Total de combinações de user_id, product_id e review_id que se repetem: 0

# %% [markdown]
#  Após o processo de limpeza dos dados, o total de combinações repetidas dos valores de 'user_id', 'product_id' e 'review_id' passou de 84 para 0. Agora, tenho uma nova tabela contendo os dados tratados, a tabela review_unique.

# %%
# Unir a tabela review (original) com a tabela review_unique (tabela review livre de combinações duplicadas), para gerar uma única tabela com todas as variáveis:
review_2 = pd.merge(review_unique, review, on=['user_id', 'product_id', 'review_id'], how='left')
review_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1464 entries, 0 to 1463
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         1464 non-null   object
#  1   product_id      1464 non-null   object
#  2   review_id       1464 non-null   object
#  3   rating_x        1464 non-null   float64
#  4   user_name       1464 non-null   object
#  5   review_title    1464 non-null   object
#  6   review_content  1464 non-null   object
#  7   img_link        1464 non-null   object
#  8   product_link    1464 non-null   object
#  9   rating_y        1464 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 114.5+ KB

# %%
# Filtrar apenas as variáveis necessárias:
filtered_review = review_2[['user_id', 'product_id', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link', 'rating_x']]
filtered_review.head(3)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 2                       AE242TR3GQ6TYC6W4SJ5UYYKBTYQ  B09XJ1LM7R
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 2                                     R38OAD16RVS9D4
#
#                                         review_title  \
# 0  Excellent solution for Sony TVs,Worth purchase...
# 1  Just go for it.👍🏻,3 PIN Plug should be there,M...
# 2                                         do not buy
#
#                                       review_content  \
# 0  Sometimes its simple solutions that come to re...
# 1  Product is so good but packaging was so bad😠.,...
# 2  tv on off not working, so difficult to battery...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  rating_x
# 0  https://www.amazon.in/Universal-Remote-Control...       4.4
# 1                                       indisponível       4.2
# 2  https://www.amazon.in/7SEVEN%C2%AE-Compatible-...       4.3

# %% [markdown]
# # **Tabela product**

# %% [markdown]
# ## **Prévia da tabela product**
#
#
# ---

# %%
product.head(2)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage  \
# 0       ₹1,099                 64%
# 1         ₹349                 43%
#
#                                        about_product
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...

# %% [markdown]
# ## **Informações sobre os dados da tabela product**
#
#
# ---

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1469 entries, 0 to 1468
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1469 non-null   object
#  1   product_name         1469 non-null   object
#  2   category             1469 non-null   object
#  3   discounted_price     1469 non-null   object
#  4   actual_price         1469 non-null   object
#  5   discount_percentage  1469 non-null   object
#  6   about_product        1465 non-null   object
# dtypes: object(7)
# memory usage: 80.5+ KB

# %% [markdown]
# Observações:
# * Total de linhas: 1469.
# * Existem valores nulos na coluna about_product.
# * Todas as colunas são do tipo object.

# %% [markdown]
# ## **Converter tipo de dado**
#
#
# ---

# %% [markdown]
# Converter tipo de dado de string para float.

# %%
product['discounted_price'] = product['discounted_price'].str.replace('₹', '')
product['actual_price'] = product['actual_price'].str.replace('₹', '')
product['discount_percentage'] = product['discount_percentage'].str.replace('%', '')

# %%
#product.head(3)

# %%
# Ver valores de 'discounted_price':
## product['discounted_price'].unique()
# Ver valores de 'actual_price'
## product['actual_price'].unique()

# %%
# Substituir vírgulas por uma string vazia, pois os valores estão no padrão estadunidense:
product['discounted_price'] = product['discounted_price'].str.replace(',', '')
product['actual_price'] = product['actual_price'].str.replace(',', '')

# %%
# Converter o tipo das colunas discounted_price, actual_price, e discounted_percentage de object para float:
product['discounted_price'] = product['discounted_price'].astype(float)
product['actual_price'] = product['actual_price'].astype(float)
product['discount_percentage'] = product['discount_percentage'].astype(float)

# %% [markdown]
# ## **Nulos**
#
#
# ---

# %% [markdown]
# #### **Total de dados nulos**

# %%
product_null = product.isnull().sum()
print(product_null)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          4
# dtype: int64

# %% [markdown]
# Observações sobre o total de valores nulos:
# * A coluna about_product possui 4 valores nulos.

# %% [markdown]
# ## **Duplicados**
#
#
# ---

# %% [markdown]
# #### **Total de linhas duplicadas**

# %%
product_duplicated = product.duplicated().sum()
print("Total de linhas duplicadas: ", product_duplicated)
# Out:
# Total de linhas duplicadas:  106

# %% [markdown]
# #### **Ver linhas duplicadas**

# %%
duplicate_lines = product[product.duplicated()]
duplicate_lines
# Out:
#       product_id                                       product_name  \
# 369   B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 377   B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 392   B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 393   B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 403   B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# ...          ...                                                ...
# 1007  B0B9BXKBC7  WeCool S5 Long Selfie Stick, with Large Reinfo...
# 1010  B07GVGTSLN  Wayona Usb Type C Fast Charger Cable Fast Char...
# 1017  B0B9BD2YL4  KINGONE Wireless Charging Pencil (2nd Generati...
# 1018  B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
# 1019  B0141EZMAI  Gizga Essentials USB WiFi Adapter for PC, 150 ...
#
#                                                category  discounted_price  \
# 369   Computers&Accessories|Accessories&Peripherals|...             399.0
# 377   Computers&Accessories|Accessories&Peripherals|...             199.0
# 392   Computers&Accessories|Accessories&Peripherals|...             329.0
# 393   Computers&Accessories|Accessories&Peripherals|...             154.0
# 403   Computers&Accessories|Accessories&Peripherals|...             149.0
# ...                                                 ...               ...
# 1007  Electronics|Mobiles&Accessories|MobileAccessor...            1799.0
# 1010  Computers&Accessories|Accessories&Peripherals|...             325.0
# 1017  Electronics|Mobiles&Accessories|MobileAccessor...            2599.0
# 1018  Computers&Accessories|Accessories&Peripherals|...             199.0
# 1019  Computers&Accessories|NetworkingDevices|Networ...             269.0
#
#       actual_price  discount_percentage  \
# 369         1099.0                 64.0
# 377          349.0                 43.0
# 392          699.0                 53.0
# 393          399.0                 61.0
# 403         1000.0                 85.0
# ...            ...                  ...
# 1007        3999.0                 55.0
# 1010        1299.0                 75.0
# 1017        6999.0                 63.0
# 1018         999.0                 80.0
# 1019         800.0                 66.0
#
#                                           about_product
# 369   High Compatibility : Compatible With iPhone 12...
# 377   Compatible with all Type C enabled devices, be...
# 392   The boAt Deuce USB 300 2 in 1 cable is compati...
# 393   [CHARGE & SYNC FUNCTION]- This cable comes wit...
# 403   Fast Charging & Data Sync: Solero TB301 Type-C...
# ...                                                 ...
# 1007  64" Tall Cell Phone Tripods with 7 section adj...
# 1010  Fast Charge & Data Sync: Fast charge& data tra...
# 1017  【2022 latest iPad Magnetic Charging】 The lates...
# 1018  -1 meter type c to c cable fast charging cable...
# 1019  USB WiFi Adapter: Fast wireless transmission a...
#
# [106 rows x 7 columns]

# %% [markdown]
# #### **Buscar linhas por ID**

# %%
product[product['product_id'] == "B07JW9H4J1"]
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 369  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 614  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                               category  discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             399.0
# 369  Computers&Accessories|Accessories&Peripherals|...             399.0
# 614  Computers&Accessories|Accessories&Peripherals|...             399.0
#
#      actual_price  discount_percentage  \
# 0          1099.0                 64.0
# 369        1099.0                 64.0
# 614        1099.0                 64.0
#
#                                          about_product
# 0    High Compatibility : Compatible With iPhone 12...
# 369  High Compatibility : Compatible With iPhone 12...
# 614  High Compatibility : Compatible With iPhone 12...

# %% [markdown]
# #### **Excluir  linhas duplicadas**

# %% [markdown]
# Criei uma nova tabela com os dados da tabela product, livre de linhas duplicadas. Nomeei a tabela como product_no_duplicates.

# %%
product_no_duplicates = product.drop_duplicates()

# %% [markdown]
# #### **Verificar a existência de IDs de produto duplicados**

# %%
# Contar as ocorrências de cada `product_id`:
duplicates_product_id = product_no_duplicates["product_id"].value_counts().reset_index(name='count_product_id')
duplicates_product_id
# Out:
#       product_id  count_product_id
# 0     B096MSW6CT                 3
# 1     B01486F4G6                 2
# 2     B08CF3D7QR                 2
# 3     B0B5B6PQCT                 2
# 4     B09MT84WV5                 2
# ...          ...               ...
# 1346  B0B244R4KB                 1
# 1347  B01F25X6RQ                 1
# 1348  B07WJWRNVK                 1
# 1349  B0B53QFZPY                 1
# 1350  B08VRMK55F                 1
#
# [1351 rows x 2 columns]

# %% [markdown]
# Observações:
# * Existem IDs de produtos duplicados.

# %% [markdown]
# #### **Buscar linhas por ID de produto**

# %%
product_no_duplicates[product_no_duplicates['product_id'] == "B096MSW6CT"]
# Out:
#      product_id                                       product_name  \
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 379  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 623  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                               category  discounted_price  \
# 2    Computers&Accessories|Accessories&Peripherals|...             199.0
# 379  Computers&Accessories|Accessories&Peripherals|...             199.0
# 623  Computers&Accessories|Accessories&Peripherals|...             199.0
#
#      actual_price  discount_percentage  \
# 2          1899.0                 90.0
# 379         999.0                 80.0
# 623         999.0                 80.0
#
#                                          about_product
# 2    【 Fast Charger& Data Sync】-With built-in safet...
# 379  【 Fast Charger& Data Sync】-With built-in safet...
# 623  【 Fast Charger& Data Sync】-With built-in safet...

# %% [markdown]
# Observações:
# * Existem IDs de produtos que se repetem, mas com preços diferentes e, portanto, com percentuais de desconto diferentes.

# %% [markdown]
# #### **IDs de produto que se repetem**

# %%
# Identificar o total de IDs de produto que se repetem:
total_duplicates_product_id = duplicates_product_id[duplicates_product_id['count_product_id'] > 1].shape[0]
print("Total de IDs de produto que se repetem:", total_duplicates_product_id)
# Out:
# Total de IDs de produto que se repetem: 11

# %%
# IDs de produto que se repetem:
duplicates_product_id[duplicates_product_id['count_product_id'] > 1]
# Out:
#     product_id  count_product_id
# 0   B096MSW6CT                 3
# 1   B01486F4G6                 2
# 2   B08CF3D7QR                 2
# 3   B0B5B6PQCT                 2
# 4   B09MT84WV5                 2
# 5   B07DJLFMPS                 2
# 6   B083342NKJ                 2
# 7   B0B5LVS732                 2
# 8   B01M6453MB                 2
# 9   B00J5DYCCA                 2
# 10  B009P2LIL4                 2

# %% [markdown]
# #### **Filtro de linhas por ID de produto na tabela duplicated_rows**

# %%
product_no_duplicates[product_no_duplicates['product_id'] == "B009P2LIL4"]
# Out:
#       product_id                                       product_name  \
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1466  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
#
#                                                category  discounted_price  \
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...            2219.0
# 1466  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...            2219.0
#
#       actual_price  discount_percentage  \
# 1462        3080.0                 28.0
# 1466        3080.0                 28.0
#
#                                           about_product
# 1462  International design and styling|Two heat sett...
# 1466                                                NaN

# %% [markdown]
# **Observações sobre cada caso em que product_id se repete:**
#
# ➡️ 0) product_id B096MSW6CT (diferentes discounted_price e discount_percentage)
#
# * Total de ocorrências: 3.
# * Ação: Excluir todas as ocorrências.
#
# ➡️ 1) product_id B01486F4G6 (about_product = NaN)
#
# * Total de ocorrências: 2.
# * Ação: Excluir o índice 1468, ocorrência em que about_product é igual a NaN.
#
# ➡️ 2) product_id B08CF3D7QR	(discounted_price, actual_price e discount_percentage iguais)
#
# * Total de ocorrências: 2.
# * Ação: Excluir o índice 428, a primeira ocorrência.
#
# ➡️ 3) product_id B0B5B6PQCT (diferentes discounted_price e discount_percentage)
#
# * Total de ocorrências: 2.
# * Ação: Excluir todas as ocorrências.
#
# ➡️ 4) product_id B09MT84WV5	(diferentes discounted_price e discount_percentage)
#
# * Total de ocorrências: 2.
# * Ação: Excluir todas as ocorrências.
#
# ➡️ 5) product_id B07DJLFMPS	(discounted_price, actual_price e discount_percentage iguais)
#
# * Total de ocorrências: 2.
# * Ação: Excluir a primeira ocorrência.
#
# ➡️ 6) product_id B083342NKJ	(discounted_price, actual_price e discount_percentage iguais)
#
# * Total de ocorrências: 2.
# * Ação: Excluir a primeira ocorrência.
#
# ➡️ 7) product_id B0B5LVS732 (diferentes discounted_price e discount_percentage)
#
# * Total de ocorrências: 2.
# * Ação: Excluir todas as ocorrências.
#
# ➡️ 8) product_id B01M6453MB (about_product = NaN)
#
# * Total de ocorrências: 2.
# * Ação: Excluir o índice 1465, ocorrência em que about_product é igual a NaN.
#
# ➡️ 9) product_id B00J5DYCCA (about_product = NaN)
#
# * Total de ocorrências: 2.
# * Ação: Excluir o índice 1467, ocorrência em que about_product é igual a NaN.
#
# ➡️ 10) product_id B009P2LIL4 (about_product = NaN)
#
# * Total de ocorrências: 2.
# * Ação: Excluir o índice 1466, ocorrência em que about_product é igual a NaN.

# %% [markdown]
# #### **Excluir IDs de produto repetidos caso a caso**

# %%
# 0) product_id B096MSW6CT:
product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B096MSW6CT"].index, inplace=True)

# 1) product_id B01486F4G6:
product_no_duplicates.drop(1468, inplace=True)

# 2) product_id B08CF3D7QR:
product_no_duplicates.drop(10, inplace=True)

# 3) product_id B0B5B6PQCT:
product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B0B5B6PQCT"].index, inplace=True)

# 4) product_id B09MT84WV5:
product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B09MT84WV5"].index, inplace=True)

# 5) product_id B07DJLFMPS:
product_no_duplicates.drop(686, inplace=True)

# 6) product_id B083342NKJ:
product_no_duplicates.drop(15, inplace=True)

# 7) product_id B0B5LVS732:
product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B0B5LVS732"].index, inplace=True)

# 8) product_id B01M6453MB:
product_no_duplicates.drop(1465, inplace=True)

# 9) product_id B00J5DYCCA:
product_no_duplicates.drop(1467, inplace=True)

# 10) product_id B009P2LIL4:
product_no_duplicates.drop(1466, inplace=True)
# Out:
# <ipython-input-41-6cd88889f8b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B096MSW6CT"].index, inplace=True)
# <ipython-input-41-6cd88889f8b6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(1468, inplace=True)
# <ipython-input-41-6cd88889f8b6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(10, inplace=True)
# <ipython-input-41-6cd88889f8b6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B0B5B6PQCT"].index, inplace=True)
# <ipython-input-41-6cd88889f8b6>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B09MT84WV5"].index, inplace=True)
# <ipython-input-41-6cd88889f8b6>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(686, inplace=True)
# <ipython-input-41-6cd88889f8b6>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(15, inplace=True)
# <ipython-input-41-6cd88889f8b6>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(product_no_duplicates[product_no_duplicates['product_id'] == "B0B5LVS732"].index, inplace=True)
# <ipython-input-41-6cd88889f8b6>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(1465, inplace=True)
# <ipython-input-41-6cd88889f8b6>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(1467, inplace=True)
# <ipython-input-41-6cd88889f8b6>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_no_duplicates.drop(1466, inplace=True)

# %% [markdown]
# **Verificar se ainda existem IDs de produto que se repetem:**

# %%
# Contar as ocorrências de cada `product_id`:
duplicates_product_id = product_no_duplicates["product_id"].value_counts().reset_index(name='count_product_id')

# Identificar o total de IDs de produto que se repetem:
total_duplicates_product_id = duplicates_product_id[duplicates_product_id['count_product_id'] > 1].shape[0]
print("Total de IDs de produto que se repetem:", total_duplicates_product_id)
# Out:
# Total de IDs de produto que se repetem: 0

# %% [markdown]
# # Unir tabelas reviews e produtos

# %%
# Unir tabelas review_unique e filtered_review:
review_product = pd.merge(filtered_review, product_no_duplicates, on='product_id', how='left')

# %%
# Renomear a coluna rating_x:
review_product.rename(columns={'rating_x': 'rating'}, inplace=True)

# %%
# Informações sobre a tabela:
review_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1464 entries, 0 to 1463
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              1464 non-null   object
#  1   product_id           1464 non-null   object
#  2   review_id            1464 non-null   object
#  3   review_title         1464 non-null   object
#  4   review_content       1464 non-null   object
#  5   img_link             1464 non-null   object
#  6   product_link         1464 non-null   object
#  7   rating               1464 non-null   float64
#  8   product_name         1455 non-null   object
#  9   category             1455 non-null   object
#  10  discounted_price     1455 non-null   float64
#  11  actual_price         1455 non-null   float64
#  12  discount_percentage  1455 non-null   float64
#  13  about_product        1455 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 160.2+ KB

# %% [markdown]
# **Insumos da tabela:**
#
# * 0 user_id: ID do usuário que escreveu a avaliação do produto
# * 1 product_id: ID do produto
# * 2 review_id: ID da avaliação do usuário
# * 3 review_title: Breve avaliação do usuário
# * 4 review_content: Avaliação completa do usuário
# * 5 img_link: link da imagem do produto
# * 6 product_link: Link para o site oficial do produto
# * 7 rating_x: Classificação do produto
# * 8 product_name: nome do produto
# * 9 category: categoria do produto
# * 10 discounted_price: preço com desconto do produto
# * 11 actual_price: preço real do produto
# * 12 discount_percentage: porcentagem de desconto do produto
# * 13 about_product: Descrição sobre o produto

# %%
review_product.head(2)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
#
#                                         review_title  \
# 0  Excellent solution for Sony TVs,Worth purchase...
# 1  Just go for it.👍🏻,3 PIN Plug should be there,M...
#
#                                       review_content  \
# 0  Sometimes its simple solutions that come to re...
# 1  Product is so good but packaging was so bad😠.,...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
#
#                                         product_name  \
# 0  Universal Remote Control for All Sony TV for A...
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...
#
#                                             category  discounted_price  \
# 0  Electronics|HomeTheater,TV&Video|Accessories|R...             239.0
# 1  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            1999.0
#
#    actual_price  discount_percentage  \
# 0         699.0                 66.0
# 1        3210.0                 38.0
#
#                                        about_product
# 0  Replacement for Sony RM-YD092 ,Fits with vario...
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...

# %%
# Informações sobre a tabela:
review_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1464 entries, 0 to 1463
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              1464 non-null   object
#  1   product_id           1464 non-null   object
#  2   review_id            1464 non-null   object
#  3   review_title         1464 non-null   object
#  4   review_content       1464 non-null   object
#  5   img_link             1464 non-null   object
#  6   product_link         1464 non-null   object
#  7   rating               1464 non-null   float64
#  8   product_name         1455 non-null   object
#  9   category             1455 non-null   object
#  10  discounted_price     1455 non-null   float64
#  11  actual_price         1455 non-null   float64
#  12  discount_percentage  1455 non-null   float64
#  13  about_product        1455 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 160.2+ KB

# %% [markdown]
# # **Variáveis numéricas**

# %% [markdown]
# ➡️ Informações sobre as variáveis numéricas da tabela review_product

# %%
review_product.describe()
# Out:
#             rating  discounted_price   actual_price  discount_percentage
# count  1464.000000       1455.000000    1455.000000          1455.000000
# mean      4.096585       3138.131567    5454.666172            47.548454
# std       0.291674       6966.121784   10909.686316            21.581367
# min       2.000000         39.000000      39.000000             0.000000
# 25%       4.000000        325.000000     800.000000            32.000000
# 50%       4.100000        799.000000    1639.000000            50.000000
# 75%       4.300000       1999.000000    4292.500000            63.000000
# max       5.000000      77990.000000  139900.000000            94.000000

# %% [markdown]
# ## **Variável rating**

# %%
px.histogram(review_product, x='rating')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3180f492-f20b-496c-aa44-2318d2f568b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3180f492-f20b-496c-aa44-2318d2f568b2")) {                    Plotly.newPlot(                        "3180f492-f20b-496c-aa44-2318d2f568b2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"rating=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4.4,4.2,4.3,4.0,4.0,4.0,4.0,4.4,4.4,4.0,4.0,3.5,4.2,3.5,4.1,4.3,3.9,4.1,4.2,4.5,4.3,4.3,4.2,4.2,4.2,4.0,4.3,4.1,4.0,4.0,3.7,4.5,3.6,4.2,3.3,3.3,4.4,4.3,3.8,4.0,3.5,4.1,4.5,4.2,3.8,4.3,3.7,4.2,3.6,4.3,4.3,4.0,3.8,4.1,3.9,4.1,4.1,4.3,4.1,4.1,4.4,4.6,3.9,3.0,4.5,3.6,4.6,4.1,3.9,3.8,4.4,4.4,4.3,4.5,4.3,4.5,4.1,4.1,4.5,4.5,3.8,4.0,3.9,3.9,4.0,4.0,4.5,4.3,4.2,4.3,4.1,4.0,4.2,4.2,4.2,4.2,4.2,3.6,4.1,4.2,4.2,4.0,4.3,4.3,4.0,4.0,4.0,4.0,4.0,4.0,4.0,3.9,4.5,3.5,3.9,4.2,3.6,4.3,4.1,3.7,4.3,3.9,4.4,3.9,3.9,4.2,4.5,4.0,3.8,3.9,4.4,4.0,3.8,4.4,3.9,4.5,4.2,4.4,3.8,3.9,3.9,3.9,4.5,4.2,3.9,4.1,4.4,3.9,3.7,4.0,4.0,4.0,4.0,4.1,4.1,4.1,4.4,3.8,4.4,3.5,3.7,4.1,3.9,4.3,4.3,4.2,4.1,4.2,4.2,4.2,4.0,4.0,3.8,4.3,4.3,3.8,3.9,3.9,2.8,4.3,4.1,4.1,4.1,4.1,4.2,4.2,4.2,4.0,4.4,4.1,4.0,4.1,4.4,3.8,4.5,4.1,4.2,4.5,4.3,4.2,4.0,4.3,4.0,4.0,4.0,3.9,4.1,4.1,4.1,4.3,4.3,4.3,4.0,3.0,3.9,4.1,4.2,4.3,4.3,3.8,4.4,4.5,4.0,4.0,4.0,4.0,4.3,4.3,4.1,4.6,3.9,4.2,4.1,4.2,4.5,3.9,3.7,3.7,4.3,4.1,4.3,4.5,4.5,3.7,4.4,3.4,4.1,4.3,4.4,3.6,4.1,3.9,3.9,3.9,3.9,3.9,3.9,4.4,4.3,4.3,4.3,4.2,3.9,4.3,4.3,4.3,4.1,4.3,3.5,3.3,4.0,4.0,3.5,3.8,4.4,4.4,4.3,4.0,4.3,4.2,4.1,4.2,4.3,3.5,3.9,4.1,4.3,4.3,4.3,3.5,3.9,4.8,3.9,4.5,4.2,3.8,4.3,4.3,4.0,4.3,4.7,4.3,4.2,4.2,4.3,4.2,4.2,4.2,4.2,4.2,4.2,4.2,4.4,4.3,4.3,3.8,4.3,4.3,4.3,4.3,4.2,4.2,4.4,3.8,3.9,4.2,4.2,4.2,3.9,4.4,4.2,3.9,4.1,3.8,4.3,4.3,4.1,4.5,4.5,4.4,4.4,4.4,4.4,4.1,4.1,4.1,4.0,4.2,3.5,4.1,4.1,4.0,4.3,3.8,4.3,4.0,4.2,4.5,4.0,4.0,4.2,4.1,4.3,4.4,4.4,4.4,4.4,4.4,4.0,4.0,4.0,4.3,4.5,4.1,4.1,4.1,3.9,4.3,4.1,4.1,4.5,4.5,4.2,4.1,4.2,4.0,4.0,4.0,4.0,3.5,3.6,3.7,4.0,4.0,4.0,4.4,3.9,3.9,3.9,3.9,3.9,4.4,4.3,3.7,4.1,4.1,4.1,4.6,4.4,4.2,4.2,4.0,4.0,4.0,4.2,4.1,4.0,4.1,3.7,4.0,4.2,4.4,4.1,4.5,3.6,4.2,4.1,4.0,2.9,4.1,4.1,4.7,4.5,4.1,4.1,4.1,4.1,4.2,5.0,4.2,4.2,4.2,4.3,4.3,4.1,3.6,3.8,4.4,4.4,4.3,4.2,4.3,4.3,4.3,4.3,4.2,4.0,4.2,4.1,4.1,4.1,4.1,4.1,4.1,3.7,4.2,4.2,4.1,4.1,4.1,4.1,4.2,3.9,4.1,4.3,4.2,4.2,4.0,3.3,3.9,4.5,3.9,4.1,4.2,4.4,4.4,3.9,3.2,3.8,4.3,4.3,3.9,3.8,4.3,4.3,4.6,3.9,4.0,4.4,3.7,4.4,4.1,4.1,4.1,4.1,4.2,4.0,4.0,3.6,4.5,4.0,3.0,4.1,4.0,4.5,4.3,4.3,3.6,3.9,3.9,4.0,3.8,4.2,4.1,4.1,4.1,4.1,3.8,4.1,4.1,4.3,4.3,4.1,3.7,4.4,4.3,4.3,4.1,3.9,3.8,3.8,4.2,4.5,4.2,4.1,4.0,4.0,4.0,3.3,4.3,4.2,4.2,3.9,3.8,4.2,4.1,3.5,4.0,3.5,4.3,4.2,4.1,4.1,4.1,4.1,4.1,3.9,4.3,3.3,4.2,4.1,4.1,4.5,3.3,4.1,4.1,4.6,4.0,4.1,5.0,4.4,4.0,4.1,3.4,4.1,4.2,4.4,3.8,4.0,3.7,3.9,4.1,4.0,4.2,4.0,4.1,4.3,3.6,4.5,4.5,4.5,3.9,3.9,4.6,3.6,4.2,4.4,4.2,3.7,4.1,4.2,3.1,4.3,4.2,4.3,4.5,4.6,4.6,4.1,3.9,4.4,4.3,4.2,4.1,3.9,3.9,4.2,3.7,4.1,4.0,4.0,4.2,4.2,4.0,4.3,3.7,3.8,4.2,4.2,4.5,4.3,4.1,4.1,3.9,4.2,4.1,4.2,4.1,4.1,4.2,4.1,3.4,4.3,4.3,4.3,4.3,4.3,4.1,4.0,4.3,4.3,4.0,4.0,4.5,4.2,4.2,4.1,3.6,4.1,3.7,4.1,4.1,4.1,3.3,4.2,3.8,3.9,4.2,4.2,4.2,4.3,4.1,4.2,4.1,4.1,3.6,4.2,4.3,4.3,3.7,4.3,3.8,3.3,3.8,4.2,3.1,4.2,4.3,4.3,4.3,4.1,4.1,4.1,4.5,4.3,4.1,4.3,4.3,4.2,4.2,3.8,3.8,4.2,3.9,4.0,3.7,3.6,4.1,3.7,4.3,3.9,4.0,4.0,4.7,4.1,4.0,3.4,3.9,4.4,3.8,4.4,3.7,4.4,4.0,4.0,4.3,4.3,4.0,4.1,4.2,2.6,4.3,4.3,3.9,3.7,4.3,4.2,4.2,4.2,3.8,4.1,3.8,3.8,3.8,4.2,4.1,4.2,4.2,4.2,4.2,4.2,4.2,4.2,4.2,3.7,4.3,3.3,4.4,4.2,4.1,4.1,4.3,4.3,4.3,3.9,4.2,4.4,4.4,4.4,4.4,4.4,4.4,4.2,4.2,4.5,4.3,4.3,3.9,3.9,4.0,3.8, ...

# %%
px.box(review_product, x='rating')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fce5a21e-2ce3-4dcd-b119-a4a5c83291fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fce5a21e-2ce3-4dcd-b119-a4a5c83291fa")) {                    Plotly.newPlot(                        "fce5a21e-2ce3-4dcd-b119-a4a5c83291fa",                        [{"alignmentgroup":"True","hovertemplate":"rating=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[4.4,4.2,4.3,4.0,4.0,4.0,4.0,4.4,4.4,4.0,4.0,3.5,4.2,3.5,4.1,4.3,3.9,4.1,4.2,4.5,4.3,4.3,4.2,4.2,4.2,4.0,4.3,4.1,4.0,4.0,3.7,4.5,3.6,4.2,3.3,3.3,4.4,4.3,3.8,4.0,3.5,4.1,4.5,4.2,3.8,4.3,3.7,4.2,3.6,4.3,4.3,4.0,3.8,4.1,3.9,4.1,4.1,4.3,4.1,4.1,4.4,4.6,3.9,3.0,4.5,3.6,4.6,4.1,3.9,3.8,4.4,4.4,4.3,4.5,4.3,4.5,4.1,4.1,4.5,4.5,3.8,4.0,3.9,3.9,4.0,4.0,4.5,4.3,4.2,4.3,4.1,4.0,4.2,4.2,4.2,4.2,4.2,3.6,4.1,4.2,4.2,4.0,4.3,4.3,4.0,4.0,4.0,4.0,4.0,4.0,4.0,3.9,4.5,3.5,3.9,4.2,3.6,4.3,4.1,3.7,4.3,3.9,4.4,3.9,3.9,4.2,4.5,4.0,3.8,3.9,4.4,4.0,3.8,4.4,3.9,4.5,4.2,4.4,3.8,3.9,3.9,3.9,4.5,4.2,3.9,4.1,4.4,3.9,3.7,4.0,4.0,4.0,4.0,4.1,4.1,4.1,4.4,3.8,4.4,3.5,3.7,4.1,3.9,4.3,4.3,4.2,4.1,4.2,4.2,4.2,4.0,4.0,3.8,4.3,4.3,3.8,3.9,3.9,2.8,4.3,4.1,4.1,4.1,4.1,4.2,4.2,4.2,4.0,4.4,4.1,4.0,4.1,4.4,3.8,4.5,4.1,4.2,4.5,4.3,4.2,4.0,4.3,4.0,4.0,4.0,3.9,4.1,4.1,4.1,4.3,4.3,4.3,4.0,3.0,3.9,4.1,4.2,4.3,4.3,3.8,4.4,4.5,4.0,4.0,4.0,4.0,4.3,4.3,4.1,4.6,3.9,4.2,4.1,4.2,4.5,3.9,3.7,3.7,4.3,4.1,4.3,4.5,4.5,3.7,4.4,3.4,4.1,4.3,4.4,3.6,4.1,3.9,3.9,3.9,3.9,3.9,3.9,4.4,4.3,4.3,4.3,4.2,3.9,4.3,4.3,4.3,4.1,4.3,3.5,3.3,4.0,4.0,3.5,3.8,4.4,4.4,4.3,4.0,4.3,4.2,4.1,4.2,4.3,3.5,3.9,4.1,4.3,4.3,4.3,3.5,3.9,4.8,3.9,4.5,4.2,3.8,4.3,4.3,4.0,4.3,4.7,4.3,4.2,4.2,4.3,4.2,4.2,4.2,4.2,4.2,4.2,4.2,4.4,4.3,4.3,3.8,4.3,4.3,4.3,4.3,4.2,4.2,4.4,3.8,3.9,4.2,4.2,4.2,3.9,4.4,4.2,3.9,4.1,3.8,4.3,4.3,4.1,4.5,4.5,4.4,4.4,4.4,4.4,4.1,4.1,4.1,4.0,4.2,3.5,4.1,4.1,4.0,4.3,3.8,4.3,4.0,4.2,4.5,4.0,4.0,4.2,4.1,4.3,4.4,4.4,4.4,4.4,4.4,4.0,4.0,4.0,4.3,4.5,4.1,4.1,4.1,3.9,4.3,4.1,4.1,4.5,4.5,4.2,4.1,4.2,4.0,4.0,4.0,4.0,3.5,3.6,3.7,4.0,4.0,4.0,4.4,3.9,3.9,3.9,3.9,3.9,4.4,4.3,3.7,4.1,4.1,4.1,4.6,4.4,4.2,4.2,4.0,4.0,4.0,4.2,4.1,4.0,4.1,3.7,4.0,4.2,4.4,4.1,4.5,3.6,4.2,4.1,4.0,2.9,4.1,4.1,4.7,4.5,4.1,4.1,4.1,4.1,4.2,5.0,4.2,4.2,4.2,4.3,4.3,4.1,3.6,3.8,4.4,4.4,4.3,4.2,4.3,4.3,4.3,4.3,4.2,4.0,4.2,4.1,4.1,4.1,4.1,4.1,4.1,3.7,4.2,4.2,4.1,4.1,4.1,4.1,4.2,3.9,4.1,4.3,4.2,4.2,4.0,3.3,3.9,4.5,3.9,4.1,4.2,4.4,4.4,3.9,3.2,3.8,4.3,4.3,3.9,3.8,4.3,4.3,4.6,3.9,4.0,4.4,3.7,4.4,4.1,4.1,4.1,4.1,4.2,4.0,4.0,3.6,4.5,4.0,3.0,4.1,4.0,4.5,4.3,4.3,3.6,3.9,3.9,4.0,3.8,4.2,4.1,4.1,4.1,4.1,3.8,4.1,4.1,4.3,4.3,4.1,3.7,4.4,4.3,4.3,4.1,3.9,3.8,3.8,4.2,4.5,4.2,4.1,4.0,4.0,4.0,3.3,4.3,4.2,4.2,3.9,3.8,4.2,4.1,3.5,4.0,3.5,4.3,4.2,4.1,4.1,4.1,4.1,4.1,3.9,4.3,3.3,4.2,4.1,4.1,4.5,3.3,4.1,4.1,4.6,4.0,4.1,5.0,4.4,4.0,4.1,3.4,4.1,4.2,4.4,3.8,4.0,3.7,3.9,4.1,4.0,4.2,4.0,4.1,4.3,3.6,4.5,4.5,4.5,3.9,3.9,4.6,3.6,4.2,4.4,4.2,3.7,4.1,4.2,3.1,4.3,4.2,4.3,4.5,4.6,4.6,4.1,3.9,4.4,4.3,4.2,4.1,3.9,3.9,4.2,3.7,4.1,4.0,4.0,4.2,4.2,4.0,4.3,3.7,3.8,4.2,4.2,4.5,4.3,4.1,4.1,3.9,4.2,4.1,4.2,4.1,4.1,4.2,4.1,3.4,4.3,4.3,4.3,4.3,4.3,4.1,4.0,4.3,4.3,4.0,4.0,4.5,4.2,4.2,4.1,3.6,4.1,3.7,4.1,4.1,4.1,3.3,4.2,3.8,3.9,4.2,4.2,4.2,4.3,4.1,4.2,4.1,4.1,3.6,4.2,4.3,4.3,3.7,4.3,3.8,3.3,3.8,4.2,3.1,4.2,4.3,4.3,4.3,4.1,4.1,4.1,4.5,4.3,4.1,4.3,4.3,4.2,4.2,3.8,3.8,4.2,3.9,4.0,3.7,3.6,4.1,3.7,4.3,3.9,4.0,4.0,4.7,4.1,4.0,3.4,3.9,4.4,3.8,4.4,3.7,4.4,4.0,4.0,4.3,4.3,4.0,4.1,4.2,2.6,4.3,4.3,3.9,3.7,4.3,4.2,4.2,4.2,3.8,4.1,3.8,3.8,3.8,4.2,4.1,4.2,4.2,4.2,4.2,4.2,4.2,4.2,4.2,3.7,4.3,3.3,4.4,4.2,4.1,4.1,4.3,4.3,4.3,3.9,4.2,4.4,4.4,4.4,4.4,4.4,4.4,4.2,4.2,4.5,4.3,4.3,3.9,3.9,4.0,3.8,4.6,4.5,3.8,4.1,4.2,4.0,4.1,4.7,4.2,4.4,4.2,4. ...

# %% [markdown]
# ## **Variável discounted_price**

# %%
px.histogram(review_product, x='discounted_price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="80b1bc22-8cd1-45d6-aeef-31c64357f538" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80b1bc22-8cd1-45d6-aeef-31c64357f538")) {                    Plotly.newPlot(                        "80b1bc22-8cd1-45d6-aeef-31c64357f538",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"discounted_price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[239.0,1999.0,399.0,1299.0,1299.0,1324.0,1324.0,1599.0,1499.0,369.0,369.0,1099.0,230.0,999.0,598.0,5999.0,448.0,469.0,499.0,199.0,89.0,479.0,154.0,154.0,154.0,272.0,99.0,616.0,1499.0,1499.0,799.0,1625.0,229.0,12999.0,333.0,333.0,399.0,15990.0,1799.0,745.0,279.0,134.0,1448.0,2025.0,2899.0,150.0,2499.0,1999.0,949.0,1399.0,1099.0,9199.0,1299.0,529.0,3249.0,2999.0,2999.0,279.0,225.0,1464.0,399.0,1295.0,3859.0,199.0,2640.0,1799.0,160.0,475.0,1499.0,2499.0,1549.0,326.0,457.0,252.0,253.0,2649.0,2490.0,1624.0,2599.0,2599.0,1099.0,279.0,209.0,209.0,3249.0,219.0,499.0,32990.0,1199.0,2903.0,199.0,1434.0,1799.0,1799.0,1799.0,1799.0,1799.0,999.0,3487.77,980.0,89.0,2699.0,499.0,499.0,249.0,249.0,199.0,199.0,199.0,199.0,199.0,329.0,999.0,263.0,215.0,3599.0,96.0,1990.0,510.0,179.0,799.0,749.0,561.0,179.0,1199.0,2199.0,599.0,599.0,2299.0,2599.0,190.0,399.0,39.0,799.0,250.0,310.0,789.0,799.0,199.0,4799.0,8990.0,8199.0,249.0,37990.0,6850.0,225.0,380.0,499.0,10990.0,115.0,115.0,115.0,149.0,29990.0,699.0,1679.0,10389.0,2399.0,1249.0,1563.0,1499.0,2499.0,351.0,299.0,699.0,299.0,12999.0,329.0,329.0,549.0,349.0,349.0,1999.0,12499.0,35999.0,59.0,13999.0,13999.0,499.0,999.0,12999.0,12999.0,12999.0,12999.0,2199.0,2199.0,2199.0,2249.0,99.0,999.0,717.0,1235.0,1709.0,999.0,688.0,1187.0,999.0,939.0,269.0,6299.0,1804.0,69.0,699.0,699.0,249.0,899.0,1799.0,2998.0,2998.0,20999.0,19999.0,20999.0,15999.0,429.0,399.0,649.0,599.0,999.0,999.0,1149.0,238.0,599.0,1399.0,1399.0,99.0,99.0,3569.0,3349.0,198.0,998.0,1449.0,1745.0,2599.0,3645.0,120.0,3249.0,279.0,279.0,3290.0,355.0,249.0,349.0,349.0,230.0,1500.0,2033.0,199.0,12000.0,489.0,660.0,999.0,99.0,149.0,99.0,149.0,149.0,99.0,309.0,474.0,599.0,599.0,765.0,2199.0,28999.0,28999.0,33999.0,289.0,445.0,179.0,399.0,1799.0,1799.0,100.0,1199.0,209.0,29999.0,1499.0,3599.0,353.0,775.0,89.0,1889.0,298.0,39.0,1409.0,1890.0,99.0,3711.0,1321.0,699.0,1199.0,1439.0,3599.0,157.0,3199.0,1349.0,1799.0,90.0,1414.0,50.0,1499.0,1149.0,15490.0,15490.0,657.0,299.0,299.0,299.0,299.0,329.0,329.0,329.0,269.0,1999.0,449.0,1498.0,299.0,480.0,1529.0,100.0,625.0,89.0,200.0,1055.0,185.0,325.0,325.0,325.0,299.0,3303.0,399.0,24499.0,1699.0,2499.0,29990.0,1399.0,1474.0,209.0,209.0,309.0,309.0,219.0,219.0,2999.0,2499.0,1699.0,299.0,8699.0,347.0,2499.0,2799.0,7799.0,1109.0,299.0,549.0,549.0,1130.0,5490.0,1665.0,899.0,299.0,6236.0,379.0,899.0,899.0,899.0,949.0,949.0,645.0,1399.0,349.0,549.0,230.0,159.0,159.0,159.0,8499.0,770.0,199.0,199.0,266.0,157.0,2499.0,199.0,9999.0,1999.0,1599.0,1599.0,1999.0,2699.0,204.0,252.0,139.0,139.0,149.0,1490.0,199.0,199.0,249.0,89.0,99.0,599.0,889.0,1484.0,365.0,349.0,379.0,319.0,1349.0,5499.0,184.0,16499.0,17999.0,16499.0,199.0,199.0,37247.0,999.0,1999.0,1089.0,1149.0,298.0,175.0,799.0,1199.0,1345.0,1456.0,2699.0,199.0,263.0,263.0,77990.0,1499.0,6499.0,6499.0,7499.0,8499.0,349.0,399.0,179.0,199.0,199.0,579.0,1614.0,1490.0,1699.0,1349.0,2742.0,1499.0,3600.0,979.0,349.0,299.0,299.0,273.1,189.0,149.0,479.0,1799.0,1799.0,99.0,99.0,399.0,399.0,499.0,299.0,139.0,199.0,199.0,699.0,1969.0,2089.0,23999.0,8499.0,1260.0,2299.0,2299.0,849.0,244.0,848.99,440.0,1099.0,7390.0,5998.0,90.0,7199.0,599.0,498.0,9 ...

# %%
px.box(review_product, x='discounted_price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f3ec3f50-4593-4c81-bdc1-3ff67ea30929" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3ec3f50-4593-4c81-bdc1-3ff67ea30929")) {                    Plotly.newPlot(                        "f3ec3f50-4593-4c81-bdc1-3ff67ea30929",                        [{"alignmentgroup":"True","hovertemplate":"discounted_price=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[239.0,1999.0,399.0,1299.0,1299.0,1324.0,1324.0,1599.0,1499.0,369.0,369.0,1099.0,230.0,999.0,598.0,5999.0,448.0,469.0,499.0,199.0,89.0,479.0,154.0,154.0,154.0,272.0,99.0,616.0,1499.0,1499.0,799.0,1625.0,229.0,12999.0,333.0,333.0,399.0,15990.0,1799.0,745.0,279.0,134.0,1448.0,2025.0,2899.0,150.0,2499.0,1999.0,949.0,1399.0,1099.0,9199.0,1299.0,529.0,3249.0,2999.0,2999.0,279.0,225.0,1464.0,399.0,1295.0,3859.0,199.0,2640.0,1799.0,160.0,475.0,1499.0,2499.0,1549.0,326.0,457.0,252.0,253.0,2649.0,2490.0,1624.0,2599.0,2599.0,1099.0,279.0,209.0,209.0,3249.0,219.0,499.0,32990.0,1199.0,2903.0,199.0,1434.0,1799.0,1799.0,1799.0,1799.0,1799.0,999.0,3487.77,980.0,89.0,2699.0,499.0,499.0,249.0,249.0,199.0,199.0,199.0,199.0,199.0,329.0,999.0,263.0,215.0,3599.0,96.0,1990.0,510.0,179.0,799.0,749.0,561.0,179.0,1199.0,2199.0,599.0,599.0,2299.0,2599.0,190.0,399.0,39.0,799.0,250.0,310.0,789.0,799.0,199.0,4799.0,8990.0,8199.0,249.0,37990.0,6850.0,225.0,380.0,499.0,10990.0,115.0,115.0,115.0,149.0,29990.0,699.0,1679.0,10389.0,2399.0,1249.0,1563.0,1499.0,2499.0,351.0,299.0,699.0,299.0,12999.0,329.0,329.0,549.0,349.0,349.0,1999.0,12499.0,35999.0,59.0,13999.0,13999.0,499.0,999.0,12999.0,12999.0,12999.0,12999.0,2199.0,2199.0,2199.0,2249.0,99.0,999.0,717.0,1235.0,1709.0,999.0,688.0,1187.0,999.0,939.0,269.0,6299.0,1804.0,69.0,699.0,699.0,249.0,899.0,1799.0,2998.0,2998.0,20999.0,19999.0,20999.0,15999.0,429.0,399.0,649.0,599.0,999.0,999.0,1149.0,238.0,599.0,1399.0,1399.0,99.0,99.0,3569.0,3349.0,198.0,998.0,1449.0,1745.0,2599.0,3645.0,120.0,3249.0,279.0,279.0,3290.0,355.0,249.0,349.0,349.0,230.0,1500.0,2033.0,199.0,12000.0,489.0,660.0,999.0,99.0,149.0,99.0,149.0,149.0,99.0,309.0,474.0,599.0,599.0,765.0,2199.0,28999.0,28999.0,33999.0,289.0,445.0,179.0,399.0,1799.0,1799.0,100.0,1199.0,209.0,29999.0,1499.0,3599.0,353.0,775.0,89.0,1889.0,298.0,39.0,1409.0,1890.0,99.0,3711.0,1321.0,699.0,1199.0,1439.0,3599.0,157.0,3199.0,1349.0,1799.0,90.0,1414.0,50.0,1499.0,1149.0,15490.0,15490.0,657.0,299.0,299.0,299.0,299.0,329.0,329.0,329.0,269.0,1999.0,449.0,1498.0,299.0,480.0,1529.0,100.0,625.0,89.0,200.0,1055.0,185.0,325.0,325.0,325.0,299.0,3303.0,399.0,24499.0,1699.0,2499.0,29990.0,1399.0,1474.0,209.0,209.0,309.0,309.0,219.0,219.0,2999.0,2499.0,1699.0,299.0,8699.0,347.0,2499.0,2799.0,7799.0,1109.0,299.0,549.0,549.0,1130.0,5490.0,1665.0,899.0,299.0,6236.0,379.0,899.0,899.0,899.0,949.0,949.0,645.0,1399.0,349.0,549.0,230.0,159.0,159.0,159.0,8499.0,770.0,199.0,199.0,266.0,157.0,2499.0,199.0,9999.0,1999.0,1599.0,1599.0,1999.0,2699.0,204.0,252.0,139.0,139.0,149.0,1490.0,199.0,199.0,249.0,89.0,99.0,599.0,889.0,1484.0,365.0,349.0,379.0,319.0,1349.0,5499.0,184.0,16499.0,17999.0,16499.0,199.0,199.0,37247.0,999.0,1999.0,1089.0,1149.0,298.0,175.0,799.0,1199.0,1345.0,1456.0,2699.0,199.0,263.0,263.0,77990.0,1499.0,6499.0,6499.0,7499.0,8499.0,349.0,399.0,179.0,199.0,199.0,579.0,1614.0,1490.0,1699.0,1349.0,2742.0,1499.0,3600.0,979.0,349.0,299.0,299.0,273.1,189.0,149.0,479.0,1799.0,1799.0,99.0,99.0,399.0,399.0,499.0,299.0,139.0,199.0,199.0,699.0,1969.0,2089.0,23999.0,8499.0,1260.0,2299.0,2299.0,849.0,244.0,848.99,440.0,1099.0,7390.0,5998.0,90.0,7199.0,599.0,498.0,99.0,47990.0,30990.0,369.0,139.0,154.0,154.0,99 ...

# %%
# Gráfico de dispersão:
plt.scatter(review_product['rating'], review_product['discounted_price'])
plt.xlabel('rating')
plt.ylabel('discounted_price')
plt.title('Título')
plt.show()

# %% [markdown]
# ## **Variável actual_price**

# %%
px.histogram(review_product, x='actual_price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="40236166-1f6b-4192-a20a-a0a88bd293bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40236166-1f6b-4192-a20a-a0a88bd293bb")) {                    Plotly.newPlot(                        "40236166-1f6b-4192-a20a-a0a88bd293bb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"actual_price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[699.0,3210.0,799.0,1599.0,1599.0,1699.0,1699.0,1999.0,1999.0,1600.0,1600.0,5999.0,999.0,4199.0,1150.0,11495.0,699.0,1499.0,625.0,599.0,599.0,599.0,399.0,399.0,399.0,320.0,499.0,1190.0,4999.0,4999.0,1999.0,2995.0,399.0,15999.0,999.0,999.0,795.0,23990.0,3295.0,795.0,599.0,699.0,2999.0,5999.0,5500.0,150.0,5999.0,3300.0,2299.0,2490.0,1899.0,18000.0,2999.0,1499.0,6299.0,7990.0,7990.0,375.0,225.0,1650.0,549.0,1645.0,10295.0,999.0,3195.0,2599.0,299.0,999.0,1775.0,3945.0,2495.0,799.0,799.0,315.0,500.0,3499.0,3990.0,2495.0,6999.0,6999.0,2400.0,1299.0,499.0,499.0,6375.0,249.0,1299.0,56790.0,1899.0,3295.0,999.0,3999.0,19999.0,19999.0,19999.0,19999.0,19999.0,1560.0,4990.0,980.0,99.0,3799.0,775.0,799.0,399.0,399.0,299.0,299.0,349.0,349.0,349.0,999.0,2100.0,699.0,1499.0,7950.0,399.0,2595.0,640.0,799.0,3990.0,1245.0,720.0,299.0,1950.0,3045.0,849.0,899.0,3999.0,2999.0,220.0,1499.0,39.0,1295.0,250.0,310.0,1999.0,1199.0,499.0,5795.0,18990.0,16000.0,599.0,74999.0,11990.0,499.0,400.0,799.0,19990.0,499.0,499.0,499.0,499.0,65000.0,999.0,1999.0,32000.0,4200.0,2796.0,3098.0,8999.0,2999.0,899.0,999.0,1299.0,1499.0,13499.0,845.0,845.0,995.0,1299.0,1299.0,4700.0,22990.0,49990.0,59.0,15999.0,15999.0,2199.0,1999.0,17999.0,18999.0,18999.0,18999.0,9999.0,9999.0,9999.0,3550.0,999.0,2490.0,1390.0,1499.0,4000.0,1950.0,747.0,1929.0,1999.0,1800.0,649.0,13750.0,2380.0,299.0,1199.0,1199.0,649.0,1249.0,4999.0,5999.0,5999.0,29990.0,27990.0,29990.0,24500.0,999.0,399.0,1300.0,1299.0,1599.0,1599.0,2499.0,699.0,849.0,1630.0,1630.0,999.0,999.0,5190.0,3995.0,800.0,2999.0,2349.0,2400.0,4400.0,6070.0,120.0,6295.0,499.0,499.0,5799.0,899.0,999.0,899.0,899.0,499.0,1500.0,4295.0,400.0,29999.0,1200.0,1100.0,1499.0,666.66,1000.0,666.66,1000.0,1000.0,800.0,404.0,1799.0,599.0,599.0,970.0,3895.0,28999.0,28999.0,33999.0,999.0,999.0,799.0,999.0,6990.0,6990.0,499.0,4999.0,600.0,50999.0,1499.0,7299.0,1199.0,875.0,499.0,5499.0,999.0,299.0,2199.0,5490.0,99.0,4495.0,1545.0,999.0,5999.0,1999.0,7290.0,160.0,3500.0,2999.0,2911.0,100.0,2799.0,50.0,3500.0,1800.0,20990.0,20990.0,999.0,799.0,799.0,799.0,699.0,699.0,699.0,699.0,650.0,2999.0,999.0,2300.0,485.0,600.0,2399.0,100.0,1400.0,89.0,230.0,1249.0,599.0,1099.0,1299.0,1299.0,699.0,4699.0,1290.0,50000.0,1975.0,5000.0,39990.0,2999.0,4650.0,695.0,695.0,475.0,1400.0,700.0,700.0,7990.0,7990.0,3495.0,595.0,16899.0,999.0,5999.0,6499.0,8995.0,2800.0,599.0,1499.0,999.0,1130.0,7200.0,2099.0,1999.0,799.0,9999.0,999.0,1900.0,1900.0,1900.0,1999.0,1999.0,1100.0,1890.0,999.0,1799.0,230.0,399.0,399.0,399.0,11999.0,1547.0,349.0,349.0,315.0,160.0,3299.0,799.0,27990.0,3999.0,3999.0,3999.0,3990.0,3500.0,599.0,999.0,999.0,999.0,999.0,1695.0,999.0,999.0,931.0,800.0,800.0,895.0,1295.0,2499.0,999.0,999.0,999.0,749.0,1850.0,13150.0,450.0,20999.0,21990.0,20990.0,999.0,499.0,59890.0,1490.0,9999.0,1600.0,1699.0,499.0,499.0,2999.0,7999.0,2295.0,3190.0,5000.0,699.0,699.0,699.0,139900.0,2999.0,8499.0,7999.0,9499.0,10999.0,999.0,1999.0,500.0,395.0,395.0,1400.0,1745.0,1990.0,3499.0,2495.0,3995.0,2199.0,6190.0,1395.0,699.0,999.0,999.0,999.0,299.0,399.0,1000.0,2499.0,2499.0,499.0,499.0,1099.0,1099.0,2199.0,499.0,499.0,499.0,499.0,1595.0,5000.0,4000.0,3 ...

# %%
px.box(review_product, x='actual_price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3cf01299-4b9d-4ea4-aefa-b5bc767f9a3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cf01299-4b9d-4ea4-aefa-b5bc767f9a3f")) {                    Plotly.newPlot(                        "3cf01299-4b9d-4ea4-aefa-b5bc767f9a3f",                        [{"alignmentgroup":"True","hovertemplate":"actual_price=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[699.0,3210.0,799.0,1599.0,1599.0,1699.0,1699.0,1999.0,1999.0,1600.0,1600.0,5999.0,999.0,4199.0,1150.0,11495.0,699.0,1499.0,625.0,599.0,599.0,599.0,399.0,399.0,399.0,320.0,499.0,1190.0,4999.0,4999.0,1999.0,2995.0,399.0,15999.0,999.0,999.0,795.0,23990.0,3295.0,795.0,599.0,699.0,2999.0,5999.0,5500.0,150.0,5999.0,3300.0,2299.0,2490.0,1899.0,18000.0,2999.0,1499.0,6299.0,7990.0,7990.0,375.0,225.0,1650.0,549.0,1645.0,10295.0,999.0,3195.0,2599.0,299.0,999.0,1775.0,3945.0,2495.0,799.0,799.0,315.0,500.0,3499.0,3990.0,2495.0,6999.0,6999.0,2400.0,1299.0,499.0,499.0,6375.0,249.0,1299.0,56790.0,1899.0,3295.0,999.0,3999.0,19999.0,19999.0,19999.0,19999.0,19999.0,1560.0,4990.0,980.0,99.0,3799.0,775.0,799.0,399.0,399.0,299.0,299.0,349.0,349.0,349.0,999.0,2100.0,699.0,1499.0,7950.0,399.0,2595.0,640.0,799.0,3990.0,1245.0,720.0,299.0,1950.0,3045.0,849.0,899.0,3999.0,2999.0,220.0,1499.0,39.0,1295.0,250.0,310.0,1999.0,1199.0,499.0,5795.0,18990.0,16000.0,599.0,74999.0,11990.0,499.0,400.0,799.0,19990.0,499.0,499.0,499.0,499.0,65000.0,999.0,1999.0,32000.0,4200.0,2796.0,3098.0,8999.0,2999.0,899.0,999.0,1299.0,1499.0,13499.0,845.0,845.0,995.0,1299.0,1299.0,4700.0,22990.0,49990.0,59.0,15999.0,15999.0,2199.0,1999.0,17999.0,18999.0,18999.0,18999.0,9999.0,9999.0,9999.0,3550.0,999.0,2490.0,1390.0,1499.0,4000.0,1950.0,747.0,1929.0,1999.0,1800.0,649.0,13750.0,2380.0,299.0,1199.0,1199.0,649.0,1249.0,4999.0,5999.0,5999.0,29990.0,27990.0,29990.0,24500.0,999.0,399.0,1300.0,1299.0,1599.0,1599.0,2499.0,699.0,849.0,1630.0,1630.0,999.0,999.0,5190.0,3995.0,800.0,2999.0,2349.0,2400.0,4400.0,6070.0,120.0,6295.0,499.0,499.0,5799.0,899.0,999.0,899.0,899.0,499.0,1500.0,4295.0,400.0,29999.0,1200.0,1100.0,1499.0,666.66,1000.0,666.66,1000.0,1000.0,800.0,404.0,1799.0,599.0,599.0,970.0,3895.0,28999.0,28999.0,33999.0,999.0,999.0,799.0,999.0,6990.0,6990.0,499.0,4999.0,600.0,50999.0,1499.0,7299.0,1199.0,875.0,499.0,5499.0,999.0,299.0,2199.0,5490.0,99.0,4495.0,1545.0,999.0,5999.0,1999.0,7290.0,160.0,3500.0,2999.0,2911.0,100.0,2799.0,50.0,3500.0,1800.0,20990.0,20990.0,999.0,799.0,799.0,799.0,699.0,699.0,699.0,699.0,650.0,2999.0,999.0,2300.0,485.0,600.0,2399.0,100.0,1400.0,89.0,230.0,1249.0,599.0,1099.0,1299.0,1299.0,699.0,4699.0,1290.0,50000.0,1975.0,5000.0,39990.0,2999.0,4650.0,695.0,695.0,475.0,1400.0,700.0,700.0,7990.0,7990.0,3495.0,595.0,16899.0,999.0,5999.0,6499.0,8995.0,2800.0,599.0,1499.0,999.0,1130.0,7200.0,2099.0,1999.0,799.0,9999.0,999.0,1900.0,1900.0,1900.0,1999.0,1999.0,1100.0,1890.0,999.0,1799.0,230.0,399.0,399.0,399.0,11999.0,1547.0,349.0,349.0,315.0,160.0,3299.0,799.0,27990.0,3999.0,3999.0,3999.0,3990.0,3500.0,599.0,999.0,999.0,999.0,999.0,1695.0,999.0,999.0,931.0,800.0,800.0,895.0,1295.0,2499.0,999.0,999.0,999.0,749.0,1850.0,13150.0,450.0,20999.0,21990.0,20990.0,999.0,499.0,59890.0,1490.0,9999.0,1600.0,1699.0,499.0,499.0,2999.0,7999.0,2295.0,3190.0,5000.0,699.0,699.0,699.0,139900.0,2999.0,8499.0,7999.0,9499.0,10999.0,999.0,1999.0,500.0,395.0,395.0,1400.0,1745.0,1990.0,3499.0,2495.0,3995.0,2199.0,6190.0,1395.0,699.0,999.0,999.0,999.0,299.0,399.0,1000.0,2499.0,2499.0,499.0,499.0,1099.0,1099.0,2199.0,499.0,499.0,499.0,499.0,1595.0,5000.0,4000.0,32999.0,12999.0,2299.0,7990.0,7990.0,1499.0,499 ...

# %%
# Gráfico de dispersão:
plt.scatter(review_product['rating'], review_product['actual_price'])
plt.xlabel('rating')
plt.ylabel('actual_price')
plt.title('Título')
plt.show()

# %% [markdown]
# ## **Variável discount_percentage**

# %%
px.histogram(review_product, x='discount_percentage')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="50d1d27f-44c3-45b3-87bb-6967d5af690a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50d1d27f-44c3-45b3-87bb-6967d5af690a")) {                    Plotly.newPlot(                        "50d1d27f-44c3-45b3-87bb-6967d5af690a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"discount_percentage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[66.0,38.0,50.0,19.0,19.0,22.0,22.0,20.0,25.0,77.0,77.0,82.0,77.0,76.0,48.0,48.0,36.0,69.0,20.0,67.0,85.0,20.0,61.0,61.0,61.0,15.0,80.0,48.0,70.0,70.0,60.0,46.0,43.0,19.0,67.0,67.0,50.0,33.0,45.0,6.0,53.0,81.0,52.0,66.0,47.0,0.0,58.0,39.0,59.0,44.0,42.0,49.0,57.0,65.0,48.0,62.0,62.0,26.0,0.0,11.0,27.0,21.0,63.0,80.0,17.0,31.0,46.0,52.0,16.0,37.0,38.0,59.0,43.0,20.0,49.0,24.0,38.0,35.0,63.0,63.0,54.0,79.0,58.0,58.0,49.0,12.0,62.0,42.0,37.0,12.0,80.0,64.0,91.0,91.0,91.0,91.0,91.0,36.0,30.0,0.0,10.0,29.0,36.0,38.0,38.0,38.0,33.0,33.0,43.0,43.0,43.0,67.0,52.0,62.0,86.0,55.0,76.0,23.0,20.0,78.0,80.0,40.0,22.0,40.0,39.0,28.0,29.0,33.0,43.0,13.0,14.0,73.0,0.0,38.0,0.0,0.0,61.0,33.0,60.0,17.0,53.0,49.0,58.0,49.0,43.0,55.0,5.0,38.0,45.0,77.0,77.0,77.0,70.0,54.0,30.0,16.0,68.0,43.0,55.0,50.0,83.0,17.0,61.0,70.0,46.0,80.0,4.0,61.0,61.0,45.0,73.0,73.0,57.0,46.0,28.0,0.0,13.0,13.0,77.0,50.0,28.0,32.0,32.0,32.0,78.0,78.0,78.0,37.0,90.0,60.0,48.0,18.0,57.0,49.0,8.0,38.0,50.0,48.0,59.0,54.0,24.0,77.0,42.0,42.0,62.0,28.0,64.0,50.0,50.0,30.0,29.0,30.0,35.0,57.0,0.0,50.0,54.0,38.0,38.0,54.0,66.0,29.0,14.0,14.0,90.0,90.0,31.0,16.0,75.0,67.0,38.0,27.0,41.0,40.0,0.0,48.0,44.0,44.0,43.0,61.0,75.0,61.0,61.0,54.0,0.0,53.0,50.0,60.0,59.0,40.0,33.0,85.0,85.0,85.0,85.0,85.0,88.0,24.0,74.0,0.0,0.0,21.0,44.0,0.0,0.0,0.0,71.0,55.0,78.0,60.0,74.0,74.0,80.0,76.0,65.0,41.0,0.0,51.0,71.0,11.0,82.0,66.0,70.0,87.0,36.0,66.0,0.0,17.0,14.0,30.0,80.0,28.0,51.0,2.0,9.0,55.0,38.0,10.0,49.0,0.0,57.0,36.0,26.0,26.0,34.0,63.0,63.0,63.0,57.0,53.0,53.0,53.0,59.0,33.0,55.0,35.0,38.0,20.0,36.0,0.0,55.0,0.0,13.0,16.0,69.0,70.0,75.0,75.0,57.0,30.0,69.0,51.0,14.0,50.0,25.0,53.0,68.0,70.0,70.0,35.0,78.0,69.0,69.0,62.0,69.0,51.0,50.0,49.0,65.0,58.0,57.0,13.0,60.0,50.0,63.0,45.0,0.0,24.0,21.0,55.0,63.0,38.0,62.0,53.0,53.0,53.0,53.0,53.0,41.0,26.0,65.0,69.0,0.0,60.0,60.0,60.0,29.0,50.0,43.0,43.0,16.0,2.0,24.0,75.0,64.0,50.0,60.0,60.0,50.0,23.0,66.0,75.0,86.0,86.0,85.0,12.0,80.0,80.0,73.0,89.0,88.0,33.0,31.0,41.0,63.0,65.0,62.0,57.0,27.0,58.0,59.0,21.0,18.0,21.0,80.0,60.0,38.0,33.0,80.0,32.0,32.0,40.0,65.0,73.0,85.0,41.0,54.0,46.0,72.0,62.0,62.0,44.0,50.0,24.0,19.0,21.0,23.0,65.0,80.0,64.0,50.0,50.0,59.0,8.0,25.0,51.0,46.0,31.0,32.0,42.0,30.0,50.0,70.0,70.0,73.0,37.0,63.0,52.0,28.0,28.0,80.0,80.0,64.0,64.0,77.0,40.0,72.0,60.0,60.0,56.0,61.0,48.0,27.0,35.0,45.0,71.0,71.0,43.0,51.0,43.0,0.0,45.0,63.0,25.0,49.0,28.0,79.0,59.0,90.0,40.0,38.0,38.0,54.0,56.0,56.0,66.0,43.0,40.0,37.0,49.0,53.0,47.0,40.0,40.0,54.0,0.0,52.0,25.0,58.0,51.0,45.0,74.0,29.0,73.0,0.0,0.0,0.0,29.0,43.0,74.0,6.0,78.0,88.0,47.0,60.0,69.0,25.0,20.0,null,null,83.0,43.0,64.0,30.0,25.0,22.0,55.0,57.0,79.0,63.0,63.0,80.0,42.0,81.0,25.0,25.0,25.0,25.0,60.0,55.0,48.0,46.0,60.0,50.0,50.0,11.0,35.0,82.0,33.0,46.0,80.0,11.0,59.0,60.0,60.0,60.0,85.0,62.0,49.0,48.0,52.0,52.0,59.0,60.0,60.0,60.0,31.0,76.0,62.0,50.0,17.0,53.0,54.0,62.0,4.0,66.0,44.0,57.0,11.0,90.0,38.0,75.0,55.0,43.0,59.0,90.0,56.0,52.0,46.0,46.0,46.0,50.0,60.0,58.0,60.0,15.0,55.0,64.0,17.0,53.0,56.0,80.0,10.0,44.0,33.0,15.0,55.0,55.0,62.0,45.0,56.0,56.0,29.0,56.0,75.0,77.0,50.0,54.0,37.0,64.0,54.0,42.0,18.0,63.0,47.0,71.0,29.0,58. ...

# %%
px.box(review_product, x='discount_percentage')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="048d8ff5-92dc-43c6-b656-db5885496844" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("048d8ff5-92dc-43c6-b656-db5885496844")) {                    Plotly.newPlot(                        "048d8ff5-92dc-43c6-b656-db5885496844",                        [{"alignmentgroup":"True","hovertemplate":"discount_percentage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[66.0,38.0,50.0,19.0,19.0,22.0,22.0,20.0,25.0,77.0,77.0,82.0,77.0,76.0,48.0,48.0,36.0,69.0,20.0,67.0,85.0,20.0,61.0,61.0,61.0,15.0,80.0,48.0,70.0,70.0,60.0,46.0,43.0,19.0,67.0,67.0,50.0,33.0,45.0,6.0,53.0,81.0,52.0,66.0,47.0,0.0,58.0,39.0,59.0,44.0,42.0,49.0,57.0,65.0,48.0,62.0,62.0,26.0,0.0,11.0,27.0,21.0,63.0,80.0,17.0,31.0,46.0,52.0,16.0,37.0,38.0,59.0,43.0,20.0,49.0,24.0,38.0,35.0,63.0,63.0,54.0,79.0,58.0,58.0,49.0,12.0,62.0,42.0,37.0,12.0,80.0,64.0,91.0,91.0,91.0,91.0,91.0,36.0,30.0,0.0,10.0,29.0,36.0,38.0,38.0,38.0,33.0,33.0,43.0,43.0,43.0,67.0,52.0,62.0,86.0,55.0,76.0,23.0,20.0,78.0,80.0,40.0,22.0,40.0,39.0,28.0,29.0,33.0,43.0,13.0,14.0,73.0,0.0,38.0,0.0,0.0,61.0,33.0,60.0,17.0,53.0,49.0,58.0,49.0,43.0,55.0,5.0,38.0,45.0,77.0,77.0,77.0,70.0,54.0,30.0,16.0,68.0,43.0,55.0,50.0,83.0,17.0,61.0,70.0,46.0,80.0,4.0,61.0,61.0,45.0,73.0,73.0,57.0,46.0,28.0,0.0,13.0,13.0,77.0,50.0,28.0,32.0,32.0,32.0,78.0,78.0,78.0,37.0,90.0,60.0,48.0,18.0,57.0,49.0,8.0,38.0,50.0,48.0,59.0,54.0,24.0,77.0,42.0,42.0,62.0,28.0,64.0,50.0,50.0,30.0,29.0,30.0,35.0,57.0,0.0,50.0,54.0,38.0,38.0,54.0,66.0,29.0,14.0,14.0,90.0,90.0,31.0,16.0,75.0,67.0,38.0,27.0,41.0,40.0,0.0,48.0,44.0,44.0,43.0,61.0,75.0,61.0,61.0,54.0,0.0,53.0,50.0,60.0,59.0,40.0,33.0,85.0,85.0,85.0,85.0,85.0,88.0,24.0,74.0,0.0,0.0,21.0,44.0,0.0,0.0,0.0,71.0,55.0,78.0,60.0,74.0,74.0,80.0,76.0,65.0,41.0,0.0,51.0,71.0,11.0,82.0,66.0,70.0,87.0,36.0,66.0,0.0,17.0,14.0,30.0,80.0,28.0,51.0,2.0,9.0,55.0,38.0,10.0,49.0,0.0,57.0,36.0,26.0,26.0,34.0,63.0,63.0,63.0,57.0,53.0,53.0,53.0,59.0,33.0,55.0,35.0,38.0,20.0,36.0,0.0,55.0,0.0,13.0,16.0,69.0,70.0,75.0,75.0,57.0,30.0,69.0,51.0,14.0,50.0,25.0,53.0,68.0,70.0,70.0,35.0,78.0,69.0,69.0,62.0,69.0,51.0,50.0,49.0,65.0,58.0,57.0,13.0,60.0,50.0,63.0,45.0,0.0,24.0,21.0,55.0,63.0,38.0,62.0,53.0,53.0,53.0,53.0,53.0,41.0,26.0,65.0,69.0,0.0,60.0,60.0,60.0,29.0,50.0,43.0,43.0,16.0,2.0,24.0,75.0,64.0,50.0,60.0,60.0,50.0,23.0,66.0,75.0,86.0,86.0,85.0,12.0,80.0,80.0,73.0,89.0,88.0,33.0,31.0,41.0,63.0,65.0,62.0,57.0,27.0,58.0,59.0,21.0,18.0,21.0,80.0,60.0,38.0,33.0,80.0,32.0,32.0,40.0,65.0,73.0,85.0,41.0,54.0,46.0,72.0,62.0,62.0,44.0,50.0,24.0,19.0,21.0,23.0,65.0,80.0,64.0,50.0,50.0,59.0,8.0,25.0,51.0,46.0,31.0,32.0,42.0,30.0,50.0,70.0,70.0,73.0,37.0,63.0,52.0,28.0,28.0,80.0,80.0,64.0,64.0,77.0,40.0,72.0,60.0,60.0,56.0,61.0,48.0,27.0,35.0,45.0,71.0,71.0,43.0,51.0,43.0,0.0,45.0,63.0,25.0,49.0,28.0,79.0,59.0,90.0,40.0,38.0,38.0,54.0,56.0,56.0,66.0,43.0,40.0,37.0,49.0,53.0,47.0,40.0,40.0,54.0,0.0,52.0,25.0,58.0,51.0,45.0,74.0,29.0,73.0,0.0,0.0,0.0,29.0,43.0,74.0,6.0,78.0,88.0,47.0,60.0,69.0,25.0,20.0,null,null,83.0,43.0,64.0,30.0,25.0,22.0,55.0,57.0,79.0,63.0,63.0,80.0,42.0,81.0,25.0,25.0,25.0,25.0,60.0,55.0,48.0,46.0,60.0,50.0,50.0,11.0,35.0,82.0,33.0,46.0,80.0,11.0,59.0,60.0,60.0,60.0,85.0,62.0,49.0,48.0,52.0,52.0,59.0,60.0,60.0,60.0,31.0,76.0,62.0,50.0,17.0,53.0,54.0,62.0,4.0,66.0,44.0,57.0,11.0,90.0,38.0,75.0,55.0,43.0,59.0,90.0,56.0,52.0,46.0,46.0,46.0,50.0,60.0,58.0,60.0,15.0,55.0,64.0,17.0,53.0,56.0,80.0,10.0,44.0,33.0,15.0,55.0,55.0,62.0,45.0,56.0,56.0,29.0,56.0,75.0,77.0,50.0,54.0,37.0,64.0,54.0,42.0,18.0,63.0,47.0,71.0,29.0,58.0,65.0,27.0,15.0,45.0,65.0,53.0,62.0,48.0,40.0 ...

# %%
# Gráfico de dispersão:
plt.scatter(review_product['rating'], review_product['discount_percentage'])
plt.xlabel('rating')
plt.ylabel('discount_percentage')
plt.title('Título')
plt.show()

# %% [markdown]
# # **Categorias de produto**

# %% [markdown]
# ➡️ Análise das avaliações por categoria de produto.

# %%
# Melhorar a visualização dos dados na variável category:
review_product['category'] = review_product['category'].str.replace('|', ',')

# %%
review_product.groupby('category').median('rating')
# Out:
#                        rating  discounted_price  actual_price  \
# category
# Car&Motorbike            3.80            2339.0        4000.0
# Computers&Accessories    4.20             349.5         999.0
# Electronics              4.10            1399.0        2999.0
# Health&PersonalCare      4.00             899.0        1900.0
# Home&Kitchen             4.10            1199.0        2000.0
# HomeImprovement          4.25             337.0         799.0
# MusicalInstruments       3.90             638.0        1347.0
# OfficeProducts           4.30             178.0         210.0
# Toys&Games               4.30             150.0         150.0
#
#                        discount_percentage
# category
# Car&Motorbike                         42.0
# Computers&Accessories                 57.0
# Electronics                           53.0
# Health&PersonalCare                   53.0
# Home&Kitchen                          42.0
# HomeImprovement                       57.5
# MusicalInstruments                    46.0
# OfficeProducts                         5.0
# Toys&Games                             0.0

# %%
# Função para resumir as categorias em categorias mais gerais:
def summarize_categories(text):
  if isinstance(text, str): # Check if the value is a string
    return text.split(',')[0]
  else:
    return text # Return the original value if it's not a string

# %%
# Aplicar a função à coluna 'category':
review_product['category'] = review_product['category'].apply(summarize_categories)

# %%
review_product.head(3)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 2                       AE242TR3GQ6TYC6W4SJ5UYYKBTYQ  B09XJ1LM7R
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 2                                     R38OAD16RVS9D4
#
#                                         review_title  \
# 0  Excellent solution for Sony TVs,Worth purchase...
# 1  Just go for it.👍🏻,3 PIN Plug should be there,M...
# 2                                         do not buy
#
#                                       review_content  \
# 0  Sometimes its simple solutions that come to re...
# 1  Product is so good but packaging was so bad😠.,...
# 2  tv on off not working, so difficult to battery...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 2  https://www.amazon.in/7SEVEN%C2%AE-Compatible-...     4.3
#
#                                         product_name      category  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen
# 2  7SEVEN® Compatible for Tata Sky Remote Origina...   Electronics
#
#    discounted_price  actual_price  discount_percentage  \
# 0             239.0         699.0                 66.0
# 1            1999.0        3210.0                 38.0
# 2             399.0         799.0                 50.0
#
#                                        about_product
# 0  Replacement for Sony RM-YD092 ,Fits with vario...
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...
# 2  [Compatible] All model of dth SD / HD / HD+ Pl...

# %%
review_product_categories = review_product.groupby('category').agg({'rating': ['mean', 'count']})
review_product_categories
# Out:
#                          rating
#                            mean count
# category
# Car&Motorbike          3.800000     1
# Computers&Accessories  4.156667   450
# Electronics            4.081923   520
# Health&PersonalCare    4.000000     1
# Home&Kitchen           4.040716   447
# HomeImprovement        4.250000     2
# MusicalInstruments     3.900000     2
# OfficeProducts         4.309677    31
# Toys&Games             4.300000     1

# %% [markdown]
# # **Correlação**

# %% [markdown]
# ➡️ Correlação das variáveis numéricas.

# %%
# Variáveis numéricas
numeric_variables = review_product.select_dtypes(include=['float64', 'int64'])
numeric_variables.columns
# Out:
# Index(['rating', 'discounted_price', 'actual_price', 'discount_percentage'], dtype='object')

# %%
# Calcular a matriz de correlação de Pearson
correlation_matrix = numeric_variables.corr(method='pearson')
print("\nMatriz de Correlação de Pearson:")
correlation_matrix
# Out:
# Matriz de Correlação de Pearson:
#                        rating  discounted_price  actual_price  \
# rating               1.000000          0.120001      0.121774
# discounted_price     0.120001          1.000000      0.962048
# actual_price         0.121774          0.962048      1.000000
# discount_percentage -0.153398         -0.241713     -0.117995
#
#                      discount_percentage
# rating                         -0.153398
# discounted_price               -0.241713
# actual_price                   -0.117995
# discount_percentage             1.000000

# %%
# gráfico da matriz de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt=".2f", linewidths=0.5)
plt.title('Matriz de Correlação de Pearson')
plt.show()

# %%
# Calcular a matriz de correlação de Spearman
correlation_matrix_spearman = numeric_variables.corr(method='spearman')
print("\nMatriz de Correlação de Spearman:")
correlation_matrix_spearman
# Out:
# Matriz de Correlação de Spearman:
#                        rating  discounted_price  actual_price  \
# rating               1.000000          0.078960      0.033866
# discounted_price     0.078960          1.000000      0.933731
# actual_price         0.033866          0.933731      1.000000
# discount_percentage -0.142540         -0.373952     -0.069711
#
#                      discount_percentage
# rating                         -0.142540
# discounted_price               -0.373952
# actual_price                   -0.069711
# discount_percentage             1.000000

# %%
# gráfico da matriz de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_spearman, annot=True, cmap='crest', fmt=".2f", linewidths=0.5)
plt.title('Matriz de Correlação de Spearman')
plt.show()

# %% [markdown]
# # **Testes de Hipóteses**

# %% [markdown]
# ## **Pergunta 1 - Produtos com maior desconto tendem a receber melhores avaliações?**

# %% [markdown]
# **Regressão Linear**
#
#
# ---

# %% [markdown]
# ➡️ Relação entre a porcentagem de desconto e a avaliação dos produtos, com uma linha de regressão vermelha indicando a tendência geral dessa relação.

# %%
sns.regplot(x='discount_percentage', y='rating', data=review_product, line_kws={'color': 'red'})
plt.title('Regressão Linear')
plt.xlabel('Desconto (%)')
plt.ylabel('Avaliação')
plt.show()

# %% [markdown]
# **Correlação**
#
#
# ---

# %%
# Correlação de Pearson
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Handle potential infinite or missing values
review_product_clean = review_product.replace([np.inf, -np.inf], np.nan).dropna(subset=['discount_percentage', 'rating'])

# Calculate Pearson correlation on the cleaned data
pearsons_corr, pearsons_p_value = stats.pearsonr(review_product_clean['discount_percentage'], review_product_clean['rating'])

print(f"Correlação de Pearson: {pearsons_corr:.2f}")
print(f"P-value: {pearsons_p_value:.2f}")
# Out:
# Correlação de Pearson: -0.15
# P-value: 0.00

# %% [markdown]
# 📍 Não há uma forte relação linear entre a porcentagem de desconto e a avaliação dos produtos.

# %% [markdown]
# **Informações sobre as avaliações de produtos com altos descontos e baixos descontos**
#
#
# ---

# %%
# Definir um critério para altos e baixos descontos
threshold = 50
high_discount = review_product[review_product['discount_percentage'] > threshold]['rating']
low_discount = review_product[review_product['discount_percentage'] <= threshold]['rating']

# %%
high_discount.describe()
# Out:
# count    686.000000
# mean       4.063557
# std        0.313233
# min        2.300000
# 25%        3.900000
# 50%        4.100000
# 75%        4.300000
# max        5.000000
# Name: rating, dtype: float64

# %%
low_discount.describe()
# Out:
# count    769.000000
# mean       4.127048
# std        0.268623
# min        2.000000
# 25%        4.000000
# 50%        4.200000
# 75%        4.300000
# max        5.000000
# Name: rating, dtype: float64

# %% [markdown]
# **Teste de normalidade**
#
#
# ---

# %%
# Definindo significância
significancia = 0.05

# Lista de variáveis e seus nomes
variaveis = [("high_discount", high_discount), ("low_discount", low_discount)]

# Lista para armazenar os resultados
resultados = []

# Loop sobre os testes
for nome_variavel, variavel in variaveis:
    # Realiza o teste de normalidade para a categoria atual
    test_stat, p_value = normaltest(variavel)

    # Determina se há diferença significativa
    if p_value <= significancia:
        diferenca_significativa = 'Não é normal'
    else:
        diferenca_significativa = 'É normal'

    # Salvando os resultados
    resultados.append([nome_variavel, test_stat, p_value, diferenca_significativa])

# Criando DataFrame com os resultados
df_results = pd.DataFrame(resultados, columns=['Categoria', 'Teste de Normalidade', 'P-valor', 'É normal?'])

# Imprimindo os resultados formatados
print(tabulate(df_results, headers='keys', tablefmt='grid', showindex=False))
# Out:
# +---------------+------------------------+-------------+--------------+
# | Categoria     |   Teste de Normalidade |     P-valor | É normal?    |
# +===============+========================+=============+==============+
# | high_discount |                147.653 | 8.66052e-33 | Não é normal |
# +---------------+------------------------+-------------+--------------+
# | low_discount  |                255.489 | 3.32132e-56 | Não é normal |
# +---------------+------------------------+-------------+--------------+

# %% [markdown]
# **Mann-Whitney**
#
#
# ---

# %%
# Definindo significância
significancia = 0.05

# Realizando o teste de Mann-Whitney
test_stat, p_value = mannwhitneyu(high_discount, low_discount)

# Determina se há diferença significativa
if p_value <= significancia:
    diferenca_significativa = 'Há diferença significativa'
else:
    diferenca_significativa = 'Não há diferença significativa'

# Salvando os resultados
resultados = [['high_discount vs low_discount', test_stat, p_value, diferenca_significativa]]

# Criando DataFrame com os resultados
df_results = pd.DataFrame(resultados, columns=['Comparação', 'Estatística do Teste', 'P-valor', 'Diferença Significativa'])

# Imprimindo os resultados formatados
print(tabulate(df_results, headers='keys', tablefmt='grid', showindex=False))
# Out:
# +-------------------------------+------------------------+-------------+----------------------------+
# | Comparação                    |   Estatística do Teste |     P-valor | Diferença Significativa    |
# +===============================+========================+=============+============================+
# | high_discount vs low_discount |                 232752 | 9.32782e-05 | Há diferença significativa |
# +-------------------------------+------------------------+-------------+----------------------------+

# %% [markdown]
# 📍 P-valor deu < 0.05, então há uma diferença significativa nas médias das avaliações entre produtos com altos e baixos descontos.
#
# 📍 Para determinar se produtos com maiores descontos recebem melhores avaliações, podemos comparar as médias das duas amostras:

# %%
#comparando as médias
mean_high_discount = high_discount.mean().round(2)
mean_low_discount = low_discount.mean().round(2)

print(f'Média de avaliações para altos descontos: {mean_high_discount}')
print(f'Média de avaliações para baixos descontos: {mean_low_discount}')
# Out:
# Média de avaliações para altos descontos: 4.06
# Média de avaliações para baixos descontos: 4.13

# %% [markdown]
# 📍 Essas médias sugerem que, em média, os produtos com baixos descontos têm uma avaliação ligeiramente melhor do que os produtos com altos descontos.

# %% [markdown]
# ## **Pergunta 2 - Produtos mais caros tendem a receber uma melhor avaliação?**

# %% [markdown]
# **Regressão Linear**
#
#
# ---

# %% [markdown]
# ➡️ Visualizar e analisar a relação entre o preço do produto com desconto e a avaliação dos produtos

# %%
sns.regplot(x='discounted_price', y='rating', data=review_product, line_kws={'color': 'red'})
plt.title('Regressão Linear')
plt.xlabel('Preço com Desconto')
plt.ylabel('Avaliação')
plt.show()

# %% [markdown]
# **Correlação**
#
#
#
# ---

# %%
# Lidar com potenciais valores infinitos ou ausentes
import numpy as np
review_product['discounted_price'] = np.nan_to_num(review_product['discounted_price'])
review_product['rating'] = np.nan_to_num(review_product['rating'])

# Calculando correlação de Pearson
import scipy.stats as stats
r_pearson, p_value = stats.pearsonr(review_product['discounted_price'], review_product['rating'])
print(f"R-Pearson: {r_pearson:.4f}")
# Out:
# R-Pearson: 0.1206

# %% [markdown]
# 📍 Fraca relação positiva entre o preço do produto com desconto e a avaliação dos produtos.

# %% [markdown]
# **Informações sobre as avaliações de produtos com altos preços e baixos preços**
#
#
# ---

# %%
# Definir um critério para avaliações altas e baixas
threshold_rating = review_product['rating'].median()  # Usar a mediana como ponto de corte
high_ratings = review_product[review_product['rating'] > threshold_rating]['actual_price']
low_ratings = review_product[review_product['rating'] <= threshold_rating]['actual_price']

# %%
high_ratings.describe()
# Out:
# count       683.000000
# mean       6904.609078
# std       13682.519251
# min          50.000000
# 25%         868.000000
# 50%        1699.000000
# 75%        4999.000000
# max      139900.000000
# Name: actual_price, dtype: float64

# %%
low_ratings.describe()
# Out:
# count      772.000000
# mean      4171.879896
# std       7439.555357
# min         39.000000
# 25%        799.000000
# 50%       1599.000000
# 75%       3999.000000
# max      69999.000000
# Name: actual_price, dtype: float64

# %% [markdown]
# **Shapiro-Wilk**
#
#
# ---

# %% [markdown]
# ➡️ Verificar se existe diferença significativa entre as médias ou medianas.

# %%
# Realizar o teste de normalidade (Shapiro-Wilk)
shapiro_high = shapiro(high_ratings.dropna())
shapiro_low = shapiro(low_ratings.dropna())

print(f'Teste de Shapiro-Wilk para avaliações altas: Estatística={shapiro_high.statistic}, p-valor={shapiro_high.pvalue}')
print(f'Teste de Shapiro-Wilk para avaliações baixas: Estatística={shapiro_low.statistic}, p-valor={shapiro_low.pvalue}')

# Verificar normalidade
normal_high = shapiro_high.pvalue > 0.05
normal_low = shapiro_low.pvalue > 0.05
# Out:
# Teste de Shapiro-Wilk para avaliações altas: Estatística=0.5130423307418823, p-valor=1.382876994712803e-39
# Teste de Shapiro-Wilk para avaliações baixas: Estatística=0.5081530809402466, p-valor=1.0407443694540416e-41

# %%
if normal_high and normal_low:
    # Realizar o teste t de Student
    t_stat, p_value = ttest_ind(high_ratings.dropna(), low_ratings.dropna())
    print(f'Teste t de Student: T-statistic={t_stat}, p-value={p_value}')
else:
    # Realizar o teste de Mann-Whitney U
    u_stat, p_value = mannwhitneyu(high_ratings.dropna(), low_ratings.dropna())
    print(f'Teste de Mann-Whitney U: U-statistic={u_stat}, p-value={p_value}')
# Out:
# Teste de Mann-Whitney U: U-statistic=276969.5, p-value=0.09544628617729782

# %% [markdown]
# 📍 A análise de correlação revelou um coeficiente de Pearson de 0.12, indicando uma relação positiva fraca, o que contraria nossa hipótese inicial. Além disso, o teste de Mann-Whitney demonstrou que não há diferença significativa entre os preços dos produtos que receberam avaliações altas e baixas. Isso refuta nossa hipótese inicial de que produtos mais caros teriam melhores avaliações.

# %% [markdown]
# ## **Pergunta 3 - Quanto maior o número de pessoas que avaliaram o produto, melhor será a classificação?**

# %% [markdown]
# **Total de pessoas que avaliaram cada produto**
#
#
# ---

# %%
# Quantidade de pessoas que avaliaram cada produto
review_count = review_product.groupby('product_id').agg(review_count=('review_id', 'count'), rating_mean=('rating','mean')).reset_index()
review_count
# Out:
#       product_id  review_count  rating_mean
# 0     B002PD61Y4             2          4.1
# 1     B002SZEOLG             1          4.2
# 2     B003B00484             1          4.3
# 3     B003L62T7W             1          4.3
# 4     B004IO5BMQ             1          4.5
# ...          ...           ...          ...
# 1345  B0BPCJM7TB             1          4.0
# 1346  B0BPJBTB3F             1          2.0
# 1347  B0BQ3K23Y1             1          4.8
# 1348  B0BQRJ3C47             1          5.0
# 1349  B0BR4F878Q             1          4.8
#
# [1350 rows x 3 columns]

# %% [markdown]
# **Correlação**
#
#
# ---

# %%
# Correlação de pearson
r_pearson, p_value = stats.pearsonr(review_count['review_count'], review_count['rating_mean'])
print(f"R-Pearson: {r_pearson:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# R-Pearson: 0.0521
# P-value: 0.0558

# %% [markdown]
# 📍 O resultado mostra que não existe uma correlação entre número de pessoas que avaliaram um produto e o produto receber uma melhor avaliação.

# %% [markdown]
# **Regressão Linear**
#
#
# ---

# %%
sns.regplot(x='review_count', y='rating_mean', data=review_count, line_kws={'color': 'red'})
plt.title('Regressão Linear')
plt.xlabel('Número de Avaliações')
plt.ylabel('Avaliação')
plt.show()

# %% [markdown]
# 📍 Analisamos a relação entre o número de pessoas que avaliaram um produto e a sua classificação média. A análise de correlação mostrou 0.004137, indicando uma fraca relação positiva. Esse resultado sugere que não há evidências de que quanto maior o número de pessoas que avaliaram o produto, melhor será a classificação, refutando a nossa hipótese inicial.

# %% [markdown]
# ## **Pergunta 4 - Quais categorias de produtos possuem melhores avaliações e mais compras? Quais são as categorias mais bem avaliadas?**

# %% [markdown]
# ➡️ Nessa sessão, iremos dividir primeiramente, a seção category, pois ela possui as subcategorias agrupadas em uma mesma coluna. O objetivo é eliminar as subcategorias dessa coluna e deixar somente os valores das categorias.

# %%
# Separarando e deixando somente a primeira palavra da variável category
review_product['category'] = review_product['category'].str.split("|").str[0]

# Mostrar somente a coluna category
print(review_product['category'])
# Out:
# 0                 Electronics
# 1                Home&Kitchen
# 2                 Electronics
# 3                 Electronics
# 4                 Electronics
#                 ...
# 1459              Electronics
# 1460    Computers&Accessories
# 1461    Computers&Accessories
# 1462    Computers&Accessories
# 1463              Electronics
# Name: category, Length: 1464, dtype: object

# %%
# Agrupar os dados da variável category
review_product_category = review_product.groupby('category').agg(rating_mean=('rating', 'mean'), rating_median=('rating', 'median'), review_id=('review_id', 'count')).reset_index()
review_product_category['rating_mean'] = review_product_category['rating_mean'].round(2)
review_product_category

# Colocando em ordem crescente de média
review_product_category_sorted = review_product_category.sort_values(by='rating_mean', ascending=False)
review_product_category_sorted
# Out:
#                 category  rating_mean  rating_median  review_id
# 7         OfficeProducts         4.31           4.30         31
# 8             Toys&Games         4.30           4.30          1
# 5        HomeImprovement         4.25           4.25          2
# 1  Computers&Accessories         4.16           4.20        450
# 2            Electronics         4.08           4.10        520
# 4           Home&Kitchen         4.04           4.10        447
# 3    Health&PersonalCare         4.00           4.00          1
# 6     MusicalInstruments         3.90           3.90          2
# 0          Car&Motorbike         3.80           3.80          1

# %% [markdown]
# ## **Testes de Hipóteses**

# %% [markdown]
# Nessa sesção, iremos fazer o teste de hipótese para entender se existe diferença significativa entre as medianas das diferentes categorias.

# %% [markdown]
# Algumas categorias acima apresentam valores muito reduzidos de avaliações (COMPUTERS&ACCESSORIES, HEALTH&PERSONALCARE, HOMEIMPROVEMENT, MUSICALINSTRUMENTS e TOYS&GAMES), por isso, essas variáveis não serão consideradas na análise.

# %% [markdown]
# **Teste de Normalidade**
#
#
# ---

# %%
significancia = 0.05

# Lista de variáveis
variaveis = ['Computers&Accessories', 'Electronics', 'Home&Kitchen', 'OfficeProducts']

# Lista para armazenar os resultados
resultados = []

# Loop sobre os testes
for variavel in variaveis:
    # Filtrando o DataFrame para a categoria atual
    categoria_df = review_product[review_product['category'] == variavel]

    # Verificando se há dados suficientes para o teste
    if len(categoria_df) < 8:
        print(f"Não há dados suficientes para a categoria {variavel}. Pulando teste.")
        resultados.append([variavel, 'N/A', 'N/A', 'N/A'])
        continue  # Pula para a próxima categoria

    # Realiza o teste de normalidade para a categoria atual
    test_stat, p_value = normaltest(categoria_df['rating'])

    # Determina se há diferença significativa
    if p_value <= significancia:
        diferenca_significativa = 'Não é normal'
    else:
        diferenca_significativa = 'É normal'

    # Salvando os resultados
    resultados.append([variavel, test_stat, p_value, diferenca_significativa])

# Criando DataFrame com os resultados
normalization_results = pd.DataFrame(resultados, columns=['Categoria', 'Teste de Normalidade', 'P-valor', 'É normal?'])

# Imprimindo os resultados formatados
print(tabulate(normalization_results, headers='keys', tablefmt='grid', showindex=False))
# Out:
# +-----------------------+------------------------+-------------+--------------+
# | Categoria             |   Teste de Normalidade |     P-valor | É normal?    |
# +=======================+========================+=============+==============+
# | Computers&Accessories |               62.6663  | 2.46704e-14 | Não é normal |
# +-----------------------+------------------------+-------------+--------------+
# | Electronics           |               90.8566  | 1.86527e-20 | Não é normal |
# +-----------------------+------------------------+-------------+--------------+
# | Home&Kitchen          |              155.803   | 1.47158e-34 | Não é normal |
# +-----------------------+------------------------+-------------+--------------+
# | OfficeProducts        |                2.93464 | 0.230542    | É normal     |
# +-----------------------+------------------------+-------------+--------------+

# %% [markdown]
# **Teste de Kruskal-Wallis**
#
#
# ---

# %% [markdown]
# Como o teste de normalidade mostrou que os dados para cada categoria apresentam disteibuição não normal. Vamos utilizar o teste de Kruskal-Wallis.
#
# O teste de Kruskal-Wallis avalia se diferentes amostras apresentam diferença significativa entre si. É uma alternativa à ANOVA quando as variáveis ​​não são normalmente distribuídas.

# %%
# Lista de categorias a serem comparadas
categorias = ['Computers&Accessories', 'Electronics', 'Home&Kitchen', 'OfficeProducts']

# Lista para armazenar as avaliações de cada categoria
ratings_por_categoria = []

for categoria in categorias:
    ratings_por_categoria.append(review_product[review_product['category'] == categoria]['rating'])

# Executando o teste de Kruskal-Wallis
statistic, p_value = kruskal(*ratings_por_categoria)

# Imprimindo os resultados
print(f'Estatística do teste de Kruskal-Wallis: {statistic}')
print(f'Valor-p: {p_value}')

# Verificando o resultado com um nível de significância de 0.05
significancia = 0.05
if p_value < significancia:
    print('Rejeitamos a hipótese nula. Pelo menos uma das medianas é diferente.')
else:
    print('Aceitamos a hipótese nula. As medianas são iguais entre as categorias.')
# Out:
# Estatística do teste de Kruskal-Wallis: 62.597232447363574
# Valor-p: 1.637495603210564e-13
# Rejeitamos a hipótese nula. Pelo menos uma das medianas é diferente.

# %% [markdown]
# **Mann-Whitney**
#
#
# ---

# %% [markdown]
# Foi verificado que pelo menos uma das medianas é diferente, por isso, vamos utilizar o teste de Mann-Whitney para identificar quais categorias apresentam diferenças significativas nas medianas das avaliações.
#
# Além do fato das amostras serem não normais, elas são não pareadas, por isso, estamos utilizando o teste de Mann-Whitney.

# %%
# Lista de categorias a serem comparadas
categorias = ['Computers&Accessories', 'Electronics', 'Home&Kitchen', 'OfficeProducts']

# Lista para armazenar as avaliações de cada categoria
ratings_por_categoria = [review_product[review_product['category'] == categoria]['rating'] for categoria in categorias]

# Lista para armazenar os resultados
resultados = []

# Matriz para armazenar os valores-p
matriz_valor_p = np.zeros((len(categorias), len(categorias)))

# Realizando o teste para cada par de categorias:
for i in range(len(categorias)):
    for j in range(i + 1, len(categorias)):
        # Comparação entre as categorias i e j
        categoria1 = categorias[i]
        categoria2 = categorias[j]
        avaliacoes_categoria1 = ratings_por_categoria[i]
        avaliacoes_categoria2 = ratings_por_categoria[j]

        # Realizando o Teste Mann-Whitney
        estatisticas_mann, p_valor_mann = mannwhitneyu(avaliacoes_categoria1, avaliacoes_categoria2)

        # Verificando significância estatística (opcional):
        significancia = 0.05
        if p_valor_mann < significancia:
            diferenca_significativa = 'Há diferença significativa entre as medianas'
        else:
            diferenca_significativa = 'Não apresentam diferença significativa entre as medianas'

        # Salvando os resultados
        resultados.append([categoria1, categoria2, estatisticas_mann, p_valor_mann, diferenca_significativa])

        # Preenchendo a matriz com os valores-p
        matriz_valor_p[i, j] = p_valor_mann
        matriz_valor_p[j, i] = p_valor_mann  # A matriz é simétrica

# Criando o dataframe com os resultados
df_results = pd.DataFrame(resultados, columns=['Categoria 1', 'Categoria 2', 'Estatística Mann-Whitney', 'Valor-p', 'Diferença Significativa'])

# Imprimindo os resultados formatados em uma tabela
print(tabulate(df_results, headers='keys', tablefmt='grid', showindex=False))

# Criando uma máscara para esconder a parte superior do heatmap
mask = np.triu(np.ones_like(matriz_valor_p, dtype=bool))  # Cria uma máscara triangular superior

# Criando um heatmap dos valores-p
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_valor_p, annot=True, xticklabels=categorias, yticklabels=categorias, cmap='viridis', cbar_kws={'label': 'Valor-p'}, mask=mask)
plt.title('Heatmap dos Valores-p do Teste de Mann-Whitney entre Categorias')
plt.xlabel('Categoria')
plt.ylabel('Categoria')
plt.show()
# Out:
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+
# | Categoria 1           | Categoria 2    |   Estatística Mann-Whitney |     Valor-p | Diferença Significativa                      |
# +=======================+================+============================+=============+==============================================+
# | Computers&Accessories | Electronics    |                   136435   | 6.58537e-06 | Há diferença significativa entre as medianas |
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+
# | Computers&Accessories | Home&Kitchen   |                   123738   | 1.79984e-09 | Há diferença significativa entre as medianas |
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+
# | Computers&Accessories | OfficeProducts |                     4316.5 | 0.000334694 | Há diferença significativa entre as medianas |
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+
# | Electronics           | Home&Kitchen   |                   125126   | 0.0382077   | Há diferença significativa entre as medianas |
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+
# | Electronics           | OfficeProducts |                     3696.5 | 3.19011e-07 | Há diferença significativa entre as medianas |
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+
# | Home&Kitchen          | OfficeProducts |                     2961.5 | 7.85131e-08 | Há diferença significativa entre as medianas |
# +-----------------------+----------------+----------------------------+-------------+----------------------------------------------+

# %% [markdown]
# ## **Gráficos**

# %% [markdown]
# **Distribuição das Avaliações por Categoria**
#
#
# ---

# %%
# Lista de categorias a serem comparadas
categorias = ['Computers&Accessories', 'Electronics', 'Home&Kitchen', 'OfficeProducts']

# Preparando os dados para o box plot
data = []
medianas = []
for categoria, ratings in zip(categorias, ratings_por_categoria):
    data.append(pd.DataFrame({'Categoria': categoria, 'Avaliação': ratings}))
    medianas.append(ratings.median())

df_boxplot = pd.concat(data)

# Criando o box plot com seaborn
plt.figure(figsize=(12, 8))
ax = sns.boxplot(x='Categoria', y='Avaliação', data=df_boxplot, palette='viridis')

# Adicionando as medianas ao gráfico
for i, mediana in enumerate(medianas):
    ax.text(i, mediana, f'{mediana:.2f}', ha='center', va='center', fontweight='bold', color='white', bbox=dict(facecolor='black', alpha=0.5))

plt.title('Distribuição das Avaliações por Categoria')
plt.xlabel('Categoria')
plt.ylabel('Avaliação')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-283-d1961f11d47e>:15: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **Análise das medianas das avaliações**
#
#
# ---

# %% [markdown]
# O teste estatístico mostrou que existe diferença significativa entre as medianas, então agora podemos avaliar qual categoria se destaca tendo uma mediana maior.

# %%
# agrupando os dados da variável category
review_product_category = review_product.groupby('category').agg(rating_mean=('rating', 'mean'), rating_median=('rating', 'median'), review_id=('review_id', 'count')).reset_index()
review_product_category['rating_mean'] = review_product_category['rating_mean'].round(2)
review_product_category
# Out:
#                 category  rating_mean  rating_median  review_id
# 0          Car&Motorbike         3.80           3.80          1
# 1  Computers&Accessories         4.16           4.20        450
# 2            Electronics         4.08           4.10        520
# 3    Health&PersonalCare         4.00           4.00          1
# 4           Home&Kitchen         4.04           4.10        447
# 5        HomeImprovement         4.25           4.25          2
# 6     MusicalInstruments         3.90           3.90          2
# 7         OfficeProducts         4.31           4.30         31
# 8             Toys&Games         4.30           4.30          1

# %% [markdown]
# Dentre as categorias acima, a que apresenta uma maior mediana foi a Office Products e Toys&Games. Porém, a categoria Toys&Games	apresenta somente uma avaliação, então podemos cocluir que **a categoria que apresenta uma maior mediana é a Office Products.**

# %% [markdown]
# **Gráfico da avaliação média por categoria**
#
#
# ---

# %%
review_product_category = review_product.groupby('category').agg({'rating': 'median', 'review_id': 'count'}).reset_index()
review_product_category = review_product_category.rename(columns={'rating': 'rating_median', 'review_id': 'review_count'})

# Ordenar o DataFrame por 'rating_median' para o gráfico
review_product_category_sorted = review_product_category.sort_values(by='rating_median', ascending=False)

# Configuração do estilo dos gráficos
sns.set(style="whitegrid")

# Definir o tamanho da figura
fig, ax1 = plt.subplots(figsize=(14, 8))

# Criar as barras para rating_median
sns.barplot(x='category', y='rating_median', data=review_product_category_sorted, ax=ax1, palette='viridis')

# Adicionar títulos e rótulos de eixos para o primeiro eixo y
ax1.set_xlabel('Categoria')
ax1.set_ylabel('Mediana das Avaliações ')
ax1.set_title('Mediana das Avaliações  e Contagem de Avaliações por Categoria')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

# Mostrar os valores das barras para rating_median
for index, value in enumerate(review_product_category_sorted['rating_median']):
    ax1.text(index, value, f'{value:.2f}', ha='center', va='bottom')

# Criar um segundo eixo y para review_count
ax2 = ax1.twinx()
ax2.set_ylabel('Contagem de Avaliações')

# Adicionar os pontos para review_count
ax2.plot(ax1.get_xticks(), review_product_category_sorted['review_count'], color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='Contagem de Avaliações')

# Mostrar os valores dos pontos para review_count
for index, value in enumerate(review_product_category_sorted['review_count']):
    ax2.text(index, value, f'{value}', ha='center', va='bottom', color='blue')

# Adicionar a legenda para o segundo eixo y
ax2.legend(loc='upper left')

# Mostrar o gráfico
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-285-4bbc2f16c135>:14: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-285-4bbc2f16c135>:20: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# Ao analisar as medianas e a quantidade de avaliações é possível verificar que existe três categorias de produtos que apresentam um maior número de avaliações. São essas:
#
# * Computers&Accessories
# * Electronics
# * Home&Kitchen
#
# Dessas três categorias, a **Computers&Accessories** apresenta maior mediana de avaliaçõe (4.20).

# %% [markdown]
# ## **Segmentação - Avaliação das avaliações altas por categoria**

# %% [markdown]
# O código a seguir, segmenta os dados em avaliações (rating) altas e baixas e faz a contabilização de avaliações altas por categoria para verificar qual categoria teve mais avaliações altas.
#
# A segmentação foi feita por quartis, as avaliações a partir do quartil 3 foram consideradas altas.
#
# Os resultados estão em porcentagem, pois cada categoria apresenta valores diferentes quantidades de avaliações, tendo categorias como COMPUTERS&ACCESSORIES, HEALTH&PERSONALCARE, HOMEIMPROVEMENT, MUSICALINSTRUMENTS e TOYS&GAMES que apresentam somente uma ou duas avaliações.

# %%
# Contagem de produtos com avaliações altas por categoria de produto

def separar_e_contabilizar_avaliacoes_altas(review_product):
    """
    Separa as avaliações "altas" (quartil 3 para cima) e conta quantas avaliações "altas" cada categoria teve.

    Argumentos:
        review_product (DataFrame): O DataFrame com os dados.

    Retorna:
        DataFrame: Um DataFrame com a contagem de avaliações "altas" por categoria.
    """
    categorias = review_product['category'].unique()
    contagem_avaliacoes_altas = []

    for categoria in categorias:
        dados_categoria = review_product[review_product['category'] == categoria].copy()
        q3 = dados_categoria['rating'].quantile(0.75)

        # Marcar as avaliações "altas"
        dados_categoria.loc[:,'avaliacao_alta'] = np.where(dados_categoria['rating'] >= q3, 1, 0)

        # Contar quantas avaliações "altas" a categoria teve
        contagem_alta = dados_categoria['avaliacao_alta'].sum()

        contagem_avaliacoes_altas.append({
            'category': categoria,
            'quantidade_avaliacoes_altas': contagem_alta
        })

    # Converter a lista de contagem para um DataFrame
    df_contagem_avaliacoes_altas = pd.DataFrame(contagem_avaliacoes_altas)

    return df_contagem_avaliacoes_altas

# Exemplo de uso
df_contagem_avaliacoes_altas = separar_e_contabilizar_avaliacoes_altas(review_product.copy())

#Em ordem decrescente
df_contagem_avaliacoes_altas = df_contagem_avaliacoes_altas.sort_values(by='quantidade_avaliacoes_altas', ascending=False)
df_contagem_avaliacoes_altas
# Out:
#                 category  quantidade_avaliacoes_altas
# 2  Computers&Accessories                          182
# 1           Home&Kitchen                          169
# 0            Electronics                          144
# 3         OfficeProducts                           13
# 4             Toys&Games                            1
# 5        HomeImprovement                            1
# 7    Health&PersonalCare                            1
# 8          Car&Motorbike                            1
# 9     MusicalInstruments                            1
# 6                    NaN                            0

# %% [markdown]
# **Normalizando:**

# %%
def separar_e_normalizar_avaliacoes_altas(review_product):
    """
    Separa as avaliações "altas" (quartil 3 para cima) e calcula a proporção de avaliações "altas" para cada categoria.

    Argumentos:
        review_product (DataFrame): O DataFrame com os dados.

    Retorna:
        DataFrame: Um DataFrame com a proporção de avaliações "altas" por categoria.
    """
    categorias = review_product['category'].unique()
    proporcao_avaliacoes_altas = []

    for categoria in categorias:
        dados_categoria = review_product[review_product['category'] == categoria].copy()
        q3 = dados_categoria['rating'].quantile(0.75)

        # Marcar as avaliações "altas"
        dados_categoria.loc[:, 'avaliacao_alta'] = np.where(dados_categoria['rating'] >= q3, 1, 0)

        # Contar quantas avaliações "altas" a categoria teve
        contagem_alta = dados_categoria['avaliacao_alta'].sum()

        # Total de avaliações na categoria
        total_avaliacoes = dados_categoria.shape[0]

        # Calcular a proporção de avaliações "altas"
        proporcao_alta = round((contagem_alta / total_avaliacoes)*100, 1)

        proporcao_avaliacoes_altas.append({
            'category': categoria,
            'proporcao_avaliacoes_altas': proporcao_alta,
            'quantidade_avaliacoes_altas': contagem_alta,
            'total_avaliacoes': total_avaliacoes
        })

    # Converter a lista de proporções para um DataFrame
    df_proporcao_avaliacoes_altas = pd.DataFrame(proporcao_avaliacoes_altas)

    return df_proporcao_avaliacoes_altas

# Exemplo de uso
df_proporcao_avaliacoes_altas = separar_e_normalizar_avaliacoes_altas(review_product.copy())

# Colocar em ordem decrescente
df_proporcao_avaliacoes_altas = df_proporcao_avaliacoes_altas.sort_values(by='quantidade_avaliacoes_altas', ascending=False)
df_proporcao_avaliacoes_altas
# Out:
# <ipython-input-287-365a52e9d5f0>:28: RuntimeWarning:
#
# invalid value encountered in scalar divide
#                 category  proporcao_avaliacoes_altas  \
# 2  Computers&Accessories                        40.4
# 1           Home&Kitchen                        37.8
# 0            Electronics                        27.7
# 3         OfficeProducts                        41.9
# 4             Toys&Games                       100.0
# 5        HomeImprovement                        50.0
# 7    Health&PersonalCare                       100.0
# 8          Car&Motorbike                       100.0
# 9     MusicalInstruments                        50.0
# 6                    NaN                         NaN
#
#    quantidade_avaliacoes_altas  total_avaliacoes
# 2                          182               450
# 1                          169               447
# 0                          144               520
# 3                           13                31
# 4                            1                 1
# 5                            1                 2
# 7                            1                 1
# 8                            1                 1
# 9                            1                 2
# 6                            0                 0

# %% [markdown]
# **Gráfico da quantidade de avaliações altas**

# %%
# Configuração do estilo dos gráficos
sns.set(style="whitegrid")

# Definir o tamanho da figura
fig, ax1 = plt.subplots(figsize=(14, 8))

# Criar as barras para quantidade_avaliacoes_altas
sns.barplot(x='category', y='quantidade_avaliacoes_altas', data=df_proporcao_avaliacoes_altas, ax=ax1, palette='viridis')

# Adicionar títulos e rótulos de eixos para o primeiro eixo y
ax1.set_xlabel('Categorias')
ax1.set_ylabel('Quantidade de Avaliações Altas')
ax1.set_title('Quantidade de Avaliações Altas por Categoria')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

# Mostrar os valores das barras para quantidade_avaliacoes_altas
for index, value in enumerate(df_proporcao_avaliacoes_altas['quantidade_avaliacoes_altas']):
    ax1.text(index, value, f'{value:.2f}', ha='center', va='bottom')

# Criar um segundo eixo y para proporcao_avaliacoes_altas
ax2 = ax1.twinx()
ax2.set_ylabel('Proporção de Avaliações Altas por Categoria')

# Adicionar os pontos para proporcao_avaliacoes_altas
ax2.plot(range(len(df_proporcao_avaliacoes_altas['category'])), df_proporcao_avaliacoes_altas['proporcao_avaliacoes_altas'], color='red', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='% de avaliações altas')

# Mostrar os valores dos pontos para proporcao_avaliacoes_altas
for index, value in enumerate(df_proporcao_avaliacoes_altas['proporcao_avaliacoes_altas']):
    ax2.text(index, value, f'{value:.2f}', ha='center', va='bottom', color='red')

# Adicionar a legenda para o segundo eixo y
ax2.legend(loc='upper left')

# Mostrar o gráfico
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-288-dd45f2a42496>:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-288-dd45f2a42496>:14: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %% [markdown]
# **Através da análise do gráfico acima obtido nessa seção, é possível verificar que das três categorias com mais avaliações (*Computers&Accessories,  Electronics, Home&Kitchen*) a que apresentou uma maior porcentagem de avaliações altas foi a Computers&Accessories.**

# %% [markdown]
# # **Análise das Avaliações - NLP**
#
#
#
# ---

# %% [markdown]
# Estamos utilizando a Processamento de Linguagem Natural (NLP) para analisar sentimentos dos usuários, com o objetivo de compreender as emoções dos clientes em suas compras online.
#
# Esta análise de sentimentos nos permite extrair informações sobre a percepção do público em relação a um determinado item ao entender quais são as palavras mais associadas aos produtos e a frequência que ela ocorre.

# %% [markdown]
# # **Títulos**

# %% [markdown]
# Nessa seção, iremos fazer a análise dos sentimentos, examinando o texto dos títulos das avaliações.

# %% [markdown]
# ## **Tratamento de textos**

# %%
# !pip install langdetect wordninja vaderSentiment
import pandas as pd
import re
import nltk
from langdetect import detect
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import wordninja
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: wordninja in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.7.4)

# %%
# Verificar se existem valores nulos na coluna review_title:

review_product['review_title'].isnull().sum()
# Out:
# 0

# %%
# Substituir quebras de linha (\n e \r) da coluna review_title por espaços em uma lista de textos:

import re

def re_breakline(text_list):
    """
    Args:
    ----------
    text_list: list object with text content to be prepared [type: list]
    """

    # Applying regex to replace newlines with spaces
    return [re.sub(r'[\n\r]', ' ', r) for r in text_list]

# Aplicando a função na coluna 'comment' do DataFrame df_comments
review_product['review_title'] = re_breakline(review_product['review_title'].tolist())

# %%
# Remover emojis:

# Função para remover emojis
def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # símbolos & pictogramas
                               u"\U0001F680-\U0001F6FF"  # transporte e símbolos de mapas
                               u"\U0001F1E0-\U0001F1FF"  # bandeiras (iOS)
                               u"\U00002500-\U00002BEF"  # caracteres chineses comuns
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # flags (iOS)
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Remover emojis:
review_product['review_title'] = review_product['review_title'].apply(lambda x: remove_emojis(str(x)))

# %%
# Remover todos os caracteres que não são alfanuméricos (\w) ou espaços em branco (\s):
review_product['review_title'] = review_product['review_title'].str.replace(r'[^\w\s]', '', regex=True)

# %%
# Converter os textos da coluna review_title para letras minúsculas:
review_product['review_title'] = review_product['review_title'].str.lower()

# %%
# Substituir links pela palavra link na coluna review_title:
review_product['review_title'] = review_product['review_title'].str.replace(r'http\S+', 'link', regex=True)

# %%
# Substituir datas pela palavra data na coluna review_title:
review_product['review_title'] = review_product['review_title'].str.replace(r'\d{4}-\d{2}-\d{2}', 'data', regex=True)

# %%
# Substituir símbolos monetários da coluna review_title por "monetary_value":
review_product['review_title'] = review_product['review_title'].str.replace(r'\$\d+', 'monetary_value', regex=True)

# %%
# Substituir valores numéricos da coluna review_title por "numeric_value":
review_product['review_title'] = review_product['review_title'].str.replace(r'\d+', 'numeric_value', regex=True)

# %%
# Substituir palavras de negação da coluna review_title por "negation":
review_product['review_title'] = review_product['review_title'].str.replace(r'\b(no|not|never)\b', 'negation', regex=True)

# %%
# Eliminar espaços em branco desnecessários da coluna review_title:
review_product['review_title'] = review_product['review_title'].str.strip()

# %%
# Remoção de espaços extras entre as palavras:
review_product['review_title'] = review_product['review_title'].apply(lambda x: re.sub(r'\s+', ' ', x.strip()))

# %%
# Substituir "productgood" por "product good" na coluna review_title:
review_product['review_title'] = review_product['review_title'].str.replace(r'productgood', 'product good', regex=True)

# Substituir "qualitygood" por "quality good" na coluna review_title:
review_product['review_title'] = review_product['review_title'].str.replace(r'qualitygood', 'quality good', regex=True)

# %%
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)

# %%
from langdetect import detect
import nltk

# Detectar o idioma de cada título
review_product['language'] = review_product['review_title'].apply(detect)

# %%
# Agrupar e contar por idioma:
language_counts = review_product.groupby('language').size().reset_index(name='count')
language_counts
# Out:
#   language  count
# 0       en   1459
# 1       et      1
# 2       fr      1
# 3       it      2
# 4       ro      1

# %%
# Usar apenas as linhas em que "language" é igual a "en":
review_product = review_product[review_product['language'] == 'en']

# %%
import spacy

# Carregar o modelo de linguagem do spaCy
nlp = spacy.load("en_core_web_sm")

# Função para filtrar palavras não inglesas
def filter_non_english_words(text):
    doc = nlp(text)
    # Lista de palavras comuns em inglês (usando vocabulário spaCy)
    common_english_words = set([token.text for token in nlp.vocab if token.is_alpha and token.is_lower])
    filtered_words = [token.text for token in doc if token.is_alpha and token.text.lower() in common_english_words]
    return " ".join(filtered_words)

# Aplicar a função para filtrar palavras não inglesas
review_product['review_title'] = review_product['review_title'].apply(filter_non_english_words)

review_product.head(3)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 3  AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 3  R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...
#
#                                         review_title  \
# 0  excellent solution for sony tvsworth purchasev...
# 1  just go for pin plug should be theremixer is g...
# 3  centre keynice phonegood for exam preparing st...
#
#                                       review_content  \
# 0  Sometimes its simple solutions that come to re...
# 1  Product is so good but packaging was so bad😠.,...
# 3  Phone is ok except middle button it’s a headac...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 3  https://m.media-amazon.com/images/I/41w5fk8Vl6...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 3  https://www.amazon.in/Nokia-105-Single-Keypad-...     4.0
#
#                                         product_name      category  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen
# 3  Nokia 105 Single SIM, Keypad Mobile Phone with...   Electronics
#
#    discounted_price  actual_price  discount_percentage  \
# 0             239.0         699.0                 66.0
# 1            1999.0        3210.0                 38.0
# 3            1299.0        1599.0                 19.0
#
#                                        about_product language
# 0  Replacement for Sony RM-YD092 ,Fits with vario...       en
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...       en
# 3  All-new redesigned Nokia mobile which is famil...       en

# %%
# Função para remover stopwords
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Aplicando a função remove_stopwords à coluna review_title
review_product['review_title'] = review_product['review_title'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenização:

from nltk.tokenize import word_tokenize

# Baixar os recursos necessários para tokenização
#nltk.download('punkt')

# Definir uma função para tokenizar o texto
def tokenize_text(text):
    return word_tokenize(text)

# Aplicar a tokenização em cada título de avaliação
review_product['tokenized_title'] = review_product['review_title'].apply(tokenize_text)

# Exibir o DataFrame resultante
review_product.head(3)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 3  AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 3  R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...
#
#                                         review_title  \
# 0  excellent solution sony tvsworth purchasevery ...
# 1  go pin plug theremixer good well jar goodbut p...
# 3  centre keynice phonegood exam preparing studen...
#
#                                       review_content  \
# 0  Sometimes its simple solutions that come to re...
# 1  Product is so good but packaging was so bad😠.,...
# 3  Phone is ok except middle button it’s a headac...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 3  https://m.media-amazon.com/images/I/41w5fk8Vl6...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 3  https://www.amazon.in/Nokia-105-Single-Keypad-...     4.0
#
#                                         product_name      category  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen
# 3  Nokia 105 Single SIM, Keypad Mobile Phone with...   Electronics
#
#    discounted_price  actual_price  discount_percentage  \
# 0             239.0         699.0                 66.0
# 1            1999.0        3210.0                 38.0
# 3            1299.0        1599.0                 19.0
#
#                                        about_product language  \
# 0  Replacement for Sony RM-YD092 ,Fits with vario...       en
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...       en
# 3  All-new redesigned Nokia mobile which is famil...       en
#
#                                      tokenized_title
# 0  [excellent, solution, sony, tvsworth, purchase...
# 1  [go, pin, plug, theremixer, good, well, jar, g...
# 3  [centre, keynice, phonegood, exam, preparing, ...

# %%
# Lematização:

from nltk.stem import WordNetLemmatizer

# Baixar recursos necessários para lematização
nltk.download('wordnet')
nltk.download('omw-1.4')

# Definir a lematização
lemmatizer = WordNetLemmatizer()

# Definir uma função para lematizar tokens
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# Aplicar a função de lematização em cada lista de tokens
review_product['lemmatized_tokens'] = review_product['tokenized_title'].apply(lemmatize_tokens)

# Exibir o DataFrame resultante
review_product.head(3)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 3  AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 3  R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...
#
#                                         review_title  \
# 0  excellent solution sony tvsworth purchasevery ...
# 1  go pin plug theremixer good well jar goodbut p...
# 3  centre keynice phonegood exam preparing studen...
#
#                                       review_content  \
# 0  Sometimes its simple solutions that come to re...
# 1  Product is so good but packaging was so bad😠.,...
# 3  Phone is ok except middle button it’s a headac...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 3  https://m.media-amazon.com/images/I/41w5fk8Vl6...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 3  https://www.amazon.in/Nokia-105-Single-Keypad-...     4.0
#
#                                         product_name      category  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen
# 3  Nokia 105 Single SIM, Keypad Mobile Phone with...   Electronics
#
#    discounted_price  actual_price  discount_percentage  \
# 0             239.0         699.0                 66.0
# 1            1999.0        3210.0                 38.0
# 3            1299.0        1599.0                 19.0
#
#                                        about_product language  \
# 0  Replacement for Sony RM-YD092 ,Fits with vario...       en
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...       en
# 3  All-new redesigned Nokia mobile which is famil...       en
#
#                                      tokenized_title  \
# 0  [excellent, solution, sony, tvsworth, purchase...
# 1  [go, pin, plug, theremixer, good, well, jar, g...
# 3  [centre, keynice, phonegood, exam, preparing, ...
#
#                                    lemmatized_tokens
# 0  [excellent, solution, sony, tvsworth, purchase...
# 1  [go, pin, plug, theremixer, good, well, jar, g...
# 3  [centre, keynice, phonegood, exam, preparing, ...

# %%
def separate_words(tokens):
    separated = []
    for token in tokens:
        split_result = wordninja.split(token)
        separated.extend(split_result)  # Adicione todos os resultados separados
    return ' '.join(separated)

# Aplicar a separação de palavras
review_product['lemmatized_tokens'] = review_product['lemmatized_tokens'].apply(separate_words)

# %% [markdown]
# ##  **Análise de Sentimentos**

# %% [markdown]
# Análise de Sentimento: Identifica se a avaliação é positiva, negativa ou neutra. Aqui, podemos verificar a frequência desses tipos de classificações.

# %%
# Instalar as bibliotecas necessárias
# !pip install textblob vaderSentiment

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import math

# Inicializar o analisador VADER
analyzer = SentimentIntensityAnalyzer()

# Função para analisar o sentimento usando VADER
def analyze_sentiment_vader(text):
    if not text or (isinstance(text, float) and math.isnan(text)):
        return None

    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']  # Usar o valor compound para uma visão geral do sentimento

# Supondo que review_product seja seu DataFrame e 'lemmatized_tokens' a coluna de texto
review_product['sentiment'] = review_product['lemmatized_tokens'].apply(lambda x: analyze_sentiment_vader(str(x)))

# Remover linhas onde a análise de sentimento retornou None
review_product = review_product.dropna(subset=['sentiment'])

# Mostrar os resultados
print(review_product[['lemmatized_tokens', 'sentiment']])
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.7.4)
#                                       lemmatized_tokens  sentiment
# 0     excellent solution sony tvs worth purchase ver...     0.3024
# 1     go pin plug the remixer good well jar good but...     0.8820
# 3     centre key nice phone good exam preparing stud...     0.9571
# 4     centre key nice phone good exam preparing stud...     0.9571
# 5     centre key nice phone good exam preparing stud...     0.9571
# ...                                                 ...        ...
# 1459  pocket friendly smart watch people love large ...     0.9744
# 1460  good product using spare cable car sturdy dura...     0.9738
# 1461  good product using spare cable car sturdy dura...     0.9738
# 1462  good product using spare cable car sturdy dura...     0.9738
# 1463  good ok nice product negation good negation ma...     0.9552
#
# [1459 rows x 2 columns]

# %%
# Função para classificar o sentimento
def classify_sentiment(score):
    if score >= 0.05:
        return 'positivo'
    elif score <= -0.05:
        return 'negativo'
    else:
        return 'neutro'

# Aplicar a função de classificação
review_product['sentiment_class'] = review_product['sentiment'].apply(classify_sentiment)

# Mostrar os resultados
print(review_product[['lemmatized_tokens', 'sentiment', 'sentiment_class']])
# Out:
#                                       lemmatized_tokens  sentiment  \
# 0     excellent solution sony tvs worth purchase ver...     0.3024
# 1     go pin plug the remixer good well jar good but...     0.8820
# 3     centre key nice phone good exam preparing stud...     0.9571
# 4     centre key nice phone good exam preparing stud...     0.9571
# 5     centre key nice phone good exam preparing stud...     0.9571
# ...                                                 ...        ...
# 1459  pocket friendly smart watch people love large ...     0.9744
# 1460  good product using spare cable car sturdy dura...     0.9738
# 1461  good product using spare cable car sturdy dura...     0.9738
# 1462  good product using spare cable car sturdy dura...     0.9738
# 1463  good ok nice product negation good negation ma...     0.9552
#
#      sentiment_class
# 0           positivo
# 1           positivo
# 3           positivo
# 4           positivo
# 5           positivo
# ...              ...
# 1459        positivo
# 1460        positivo
# 1461        positivo
# 1462        positivo
# 1463        positivo
#
# [1459 rows x 3 columns]

# %% [markdown]
# ### **Entradas classificadas como positivas, negativas ou neutras**
#
#
#
# ---

# %% [markdown]
# **Total por classificação**
#
#
# ---

# %% [markdown]
# O código a seguir conta e exibe o número total de entradas classificadas como "negativo", "positivo" e "neutro" na coluna sentiment_class do DataFrame review_product.

# %%
# Contar total de "negativo" na coluna sentiment_class:
total_negativo = review_product[review_product['sentiment_class'] == 'negativo'].shape[0]
print("Total de 'negativo':", total_negativo)

# Contar total de "positivo" na coluna sentiment_class:
total_positivo = review_product[review_product['sentiment_class'] == 'positivo'].shape[0]
print("Total de 'positivo':", total_positivo)

# Contar total de "neutro" na coluna sentiment_class:
total_neutro = review_product[review_product['sentiment_class'] == 'neutro'].shape[0]
print("Total de 'neutro':", total_neutro)
# Out:
# Total de 'negativo': 21
# Total de 'positivo': 1432
# Total de 'neutro': 6

# %% [markdown]
# **Gráfico com a distribuição por classificação**
#
#
# ---

# %%
# gráfico de barras

# Dados para o gráfico
sentiment_counts = {
    'positivo': total_positivo,
    'neutro': total_neutro,
    'negativo': total_negativo
}

# Criar o gráfico de barras
plt.figure(figsize=(8, 5))
bars = plt.bar(sentiment_counts.keys(), sentiment_counts.values(), color=['darkgoldenrod', 'orange', 'khaki'])
plt.xlabel('Sentimento')
plt.ylabel('Total de Entradas')
plt.title('Distribuição de Sentimentos nas Avaliações de Produtos')
plt.show()

# %% [markdown]
# É possível observar que a grande maioria das entradas foram classificadas como positivas.

# %% [markdown]
# **Títulos das avaliações que foram classificados como negativos**
#
#
# ---

# %%
with pd.option_context('display.max_colwidth', None, 'display.max_columns', None, 'display.max_rows', None):
    display(review_product[review_product['sentiment_class'] == 'negativo'][['review_title']])
# Out:
#                                                                                                                                                                                                                                                                           review_title
# 44                                                                                                                                            handy consumes less space unlike mixer grinderthird class productnot satisfactoryit wonderful productsupernhandyone jar negation working
# 97                                                                                                                                         nicegood productpoorits good working ironwater comes outaveragei collect damaged item return negation received replacementnot good ok price
# 134                                                                                                                                                  हnot good regular usepathetic battery back upgooddoes shouldvery pathetic battery negation buyworth buygood v please check buying
# 269                                                                                                                                       placed order doubt whether would work negation works wellvery bad remote baddoesnt works material quality nt nearby original oneno bluetooth
# 351   takes space negation convenient hurrynot useful cotton linen thick materiel fabricsreceived brokenonly lighter fabricthere learning curve may take people itit looks like imitation product pieces nt match properly look weakexcellent product received good conditionnot great
# 478                                                         buy ikea directlygood qualityone battery set provided frother battery negation available locallyvery bad product nt buy even negation return option availablenot ikea qualityaverage qualityreally goodnot powerful enough
# 487                                                                                                                                                                                   cutter speed power lownt happy wit prdctnot expectednot even worth starvery poor productnot good
# 543                                                                                                                                                                                  overall goodsturdyit turns yellowno issues yellowing nownot worthyawesomeamazingiphone back cover
# 584                                                                                                                                                                                  good product budget pricei purchased product shop rs including everything buy amazonworst product
# 715                                                                                                             netflix button negation working others works wellgoodcompatible vu premium tvnot like original one negation badnot good qualityworking finehalf button nt workhardness
# 718                                                                                                                                                                                    niceसनदर हreceived damaged product good quality productits fake lava usbaverage productcostless
# 793                                      good product worth itnot worthy buygood ok usevery nice productuseless productvery poor qualitywithin days purchase charging cable started showing hours full chargestopped working hardly days waste money ctype connector came plastic part
# 876                                                                                                                                     average usb hubinferior quality goodsits cheapbuilt quality lowokfinish negation goodrecieved damage piecepackaging damaged negation new piece
# 885                                                                             install csr driver advanced features stability bluetooththik hdriver installation cd missing packagenot compatible office usagesprthis orderwaste time money negation recommendwrong product delivered
# 889                                                                                                                                                                                                                     beast budgetfake negative reviewsgreat product low price range
# 1150                                                                                                              good productaverageaverage printerpackage goodvery poor quality month used printer printer print print refiledoes job damn slow wait agessuperbest product low price
# 1154                                                                                                                                              running time lessnot much usefulgood onenot gooduseful product improper bladesoverall good blend softer fruitsworth moneyworest item
# 1162                                                 watch negation smart one features make fool youworst watch connecting problem phone nd automatically disconnecting phonevery good quality product price lowgoodভলdamaged product supplied later exchangedbattery life lessamezing
# 1163                                                 watch negation smart one features make fool youworst watch connecting problem phone nd automatically disconnecting phonevery good quality product price lowgoodভলdamaged product supplied later exchangedbattery life lessamezing
# 1164                                                 watch negation smart one features make fool youworst watch connecting problem phone nd automatically disconnecting phonevery good quality product price lowgoodভলdamaged product supplied later exchangedbattery life lessamezing
# 1368                                                                                                                                                       nice product recommend buydo negation buy defective productwast moneyvery bad portablewaste money negation working properly

# %%
# Exportar dataframe com títulos que foram classificados como negativos:
review_product[review_product['sentiment_class'] == 'negativo'][['review_title']].to_csv('review_product_negative_title.csv', index=False)

# %%
#data frame
df_negative_title = review_product[review_product['sentiment_class'] == 'negativo']
df_positive_title = review_product[review_product['sentiment_class'] == 'positivo']

# %% [markdown]
# ### **Unigramas**
#
#
#
# ---

# %% [markdown]
# Os Unigramas nos fornecem informações de quais palavras são mais frequentes em avaliações positivas e negativas. Palavras como "bom", "excelente", "ótimo" podem ser comuns em avaliações positivas, enquanto "ruim", "péssimo", "horrível" podem ser mais frequentes em avaliações negativas.
#
# Com os unigramas podemos identificar palavras que carregam forte conotação emocional e como elas impactam a classificação geral de sentimentos.

# %% [markdown]
# #### **Unigrams | 10 palavras mais comuns nas avaliações positivas**

# %%
from nltk import ngrams
from collections import Counter

# %%
# Filtrar apenas os casos onde sentiment_class é "positivo"
reviews_negative = review_product[review_product['sentiment_class'] == 'positivo']

# Contar as palavras nos títulos das avaliações
all_words = ' '.join(reviews_negative['review_title']).split()
token_frequencies = Counter(all_words)

# Extrair as palavras e suas frequências
words, frequencies = zip(*token_frequencies.most_common(10))

# Configurações de estilo do seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Plotar o gráfico de barras usando seaborn
ax = sns.barplot(y=words, x=frequencies, palette="Blues_d")
ax.set_title('Top 10 Palavras Mais Comuns em Títulos de Avaliações Positivas')
ax.set_xlabel('Frequência')
ax.set_ylabel('Palavras')
ax.set_yticklabels(words, rotation=0)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-320-dcf79607320e>:16: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-320-dcf79607320e>:20: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
# adicionar palavras e frequencia em um novo data frame
df_unigrams_positive_title = pd.DataFrame({'Palavras': words, 'Frequência': frequencies})
df_unigrams_positive_title
# Out:
#    Palavras  Frequência
# 0      good        1477
# 1   product        1263
# 2  negation         553
# 3   quality         473
# 4     price         239
# 5      nice         211
# 6     money         187
# 7     value         175
# 8     cable         175
# 9      best         163

# %% [markdown]
# #### **Unigrams | 10 palavras mais comuns nas avaliações negativas**

# %%
# Filtrar apenas os casos onde sentiment_class é "negativo"
reviews_negative = review_product[review_product['sentiment_class'] == 'negativo']

# Contar as palavras nos títulos das avaliações
all_words = ' '.join(reviews_negative['review_title']).split()
token_frequencies = Counter(all_words)

# Extrair as palavras e suas frequências
words, frequencies = zip(*token_frequencies.most_common(10))

# Configurações de estilo do seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Plotar o gráfico de barras usando seaborn
ax = sns.barplot(y=words, x=frequencies, palette="Blues_d")
ax.set_title('Top 10 Palavras Mais Comuns em Títulos de Avaliações Negativas')
ax.set_xlabel('Frequência')
ax.set_ylabel('Palavras')
ax.set_yticklabels(words, rotation=0)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-322-3d77e6340212>:16: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-322-3d77e6340212>:20: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
# adicionar palavras e frequencia em um novo data frame
df_unigrams_negative_title = pd.DataFrame({'Palavras': words, 'Frequência': frequencies})
df_unigrams_negative_title
# Out:
#    Palavras  Frequência
# 0   product          19
# 1  negation          17
# 2      good          14
# 3   quality           8
# 4     price           6
# 5     watch           6
# 6   working           5
# 7   battery           4
# 8        nt           4
# 9       buy           4

# %% [markdown]
# ### **Bigramas**
#
#
#
# ---

# %% [markdown]
# Os bigramas nos fornecem insights de quais pares de palavras ocorrem frequentemente juntos em avaliações positivas e negativas, assim, elas nos ajudam a entender melhor o contexto em que uma palavra é usada, o que pode fornecer uma análise de sentimento mais precisa. Por exemplo, "não gostei" e "gostei muito" têm sentimentos opostos, e essa distinção é capturada melhor com bigramas do que com monogramas.

# %% [markdown]
# #### **Bigrams | 10 palavras mais comuns nas avaliações positivas**

# %%
# Filtrar apenas os casos onde sentiment_class é "positivo"
reviews_positive = review_product[review_product['sentiment_class'] == 'positivo']

# Função para extrair bigrams de uma lista de tokens
def extract_bigrams(tokens):
    return list(ngrams(tokens, 2))

# Extrair bigrams dos títulos de avaliações negativas
all_tokens = [token for title in reviews_positive['review_title'] for token in title.split()]
bigrams = extract_bigrams(all_tokens)

# Contar a frequência dos bigrams
bigram_freq = Counter(bigrams)
sorted_bigrams = bigram_freq.most_common(10)  # Top 10 bigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(bigram) for bigram, freq in sorted_bigrams]
y_values = [freq for bigram, freq in sorted_bigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='skyblue')
plt.xlabel('Frequência')
plt.ylabel('Bigrams')
plt.title('Top 10 Bigrams Mais Frequentes em Títulos de Avaliações Positivas')
plt.gca().invert_yaxis()  # Inverte a ordem dos bigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
#dataframe
df_bigrams_positive_title = pd.DataFrame({'Bigrams': x_labels, 'Frequência': y_values})
df_bigrams_positive_title
# Out:
#             Bigrams  Frequência
# 0      product good         342
# 1      good product         254
# 2      quality good          94
# 3      good quality          85
# 4       value money          52
# 5  negation working          45
# 6   quality product          44
# 7      nice product          43
# 8  product negation          40
# 9     negation good          32

# %% [markdown]
# #### **Bigrams | 10 palavras mais comuns nas avaliações negativas**

# %%
# Filtrar apenas os casos onde sentiment_class é "negativo"
reviews_negative = review_product[review_product['sentiment_class'] == 'negativo']

# Função para extrair bigrams de uma lista de tokens
def extract_bigrams(tokens):
    return list(ngrams(tokens, 2))

# Extrair bigrams dos títulos de avaliações negativas
all_tokens = [token for title in reviews_negative['review_title'] for token in title.split()]
bigrams = extract_bigrams(all_tokens)

# Contar a frequência dos bigrams
bigram_freq = Counter(bigrams)
sorted_bigrams = bigram_freq.most_common(10)  # Top 10 bigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(bigram) for bigram, freq in sorted_bigrams]
y_values = [freq for bigram, freq in sorted_bigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='skyblue')
plt.xlabel('Frequência')
plt.ylabel('Bigrams')
plt.title('Top 10 Bigrams Mais Frequentes em Títulos de Avaliações Negativas')
plt.gca().invert_yaxis()  # Inverte a ordem dos bigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
# Filtrar apenas os casos onde sentiment_class é "negativo"
reviews_negative = review_product[review_product['sentiment_class'] == 'negativo']

# Função para extrair bigrams de uma lista de tokens
def extract_bigrams(tokens):
    return list(ngrams(tokens, 2))

# Extrair bigrams dos títulos de avaliações negativas
all_tokens = [token for title in reviews_negative['review_title'] for token in title.split()]
bigrams = extract_bigrams(all_tokens)

# Contar a frequência dos bigrams
bigram_freq = Counter(bigrams)
sorted_bigrams = bigram_freq.most_common(10)  # Top 10 bigrams mais frequentes

# Preparar dados para a tabela
bigram_data = {'Bigram': [' '.join(bigram) for bigram, freq in sorted_bigrams],
               'Frequência': [freq for bigram, freq in sorted_bigrams]}

# Criar dataframe
bigram_df = pd.DataFrame(bigram_data)


df_bigrams_negative_title = bigram_df
df_bigrams_negative_title
# Out:
#              Bigram  Frequência
# 0      good quality           4
# 1  negation working           3
# 2    watch negation           3
# 3    negation smart           3
# 4         smart one           3
# 5      one features           3
# 6     features make           3
# 7         make fool           3
# 8     fool youworst           3
# 9    youworst watch           3

# %% [markdown]
# Principais bigramas negativos:
# *	Good quality
# *	Negation working
# *	Negation smart
# *	Smart one
# *	One features
# *	Features make
# *	Make fool
# *	Fool youworst
# *	Youworst watch
#
# Os principais bigramas apresentam reclamações como:
# * “**Negation working – Não funciona**”, o que pode representar que o produto não funciona ou não funciona como o cliente esperava;
# * “**Watch Negation**”, junto com "**Watch negation**", “**Smart one**” e  "**Youworst watch**" indicam que o produto não é um smart watch.
# * "**One features**", "**Features make**", "**Make fool**", "**Fool youworst**" podem indicar que vendedor enganou os clientes em relação às características do produto
#
#
# ---

# %% [markdown]
# ### **Trigramas**
#
#
#
# ---

# %% [markdown]
# Os trigramas, que são conjuntos de três palavras consecutivas, podem fornecer uma visão mais detalhada sobre o feedback dos usuários porque capturam contextos que revelam mais sobre a opinião dos usuários, como "não recomendo comprar" ou "produto de ótima qualidade".

# %% [markdown]
# #### **Trigrams | 10 palavras mais comuns nas avaliações positivas**

# %%
# Filtrar apenas os casos onde sentiment_class é "positivo"
review_positive = review_product[review_product['sentiment_class'] == 'positivo']

# Função para extrair trigrams de uma lista de tokens
def extract_trigrams(tokens):
    return list(ngrams(tokens, 3))

# Extrair trigrams dos títulos de avaliações negativas
all_tokens = [token for title in review_positive['review_title'] for token in title.split()]
trigrams = extract_trigrams(all_tokens)

# Contar a frequência dos trigrams
trigram_freq = Counter(trigrams)
sorted_trigrams = trigram_freq.most_common(10)  # Top 10 trigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(trigram) for trigram, freq in sorted_trigrams]
y_values = [freq for trigram, freq in sorted_trigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='lightgreen')
plt.xlabel('Frequência')
plt.ylabel('Trigrams')
plt.title('Top 10 Trigrams Mais Frequentes em Títulos de Avaliações Positivas')
plt.gca().invert_yaxis()  # Inverte a ordem dos trigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
#data frame
df_trigrams_positive = pd.DataFrame({'Trigrams': x_labels, 'Frequência': y_values})
df_trigrams_positive
# Out:
#                     Trigrams  Frequência
# 0          good product good          83
# 1       product good product          59
# 2       product good quality          25
# 3       quality good product          24
# 4       quality product good          15
# 5          good quality good          14
# 6            micro usb cable          13
# 7          nice product good          12
# 8       good quality product          12
# 9  product good productsuper          10

# %% [markdown]
# #### **Trigrams | 10 palavras mais comuns nas avaliações negativas**

# %%
# Filtrar apenas os casos onde sentiment_class é "negativo"
review_negative = review_product[review_product['sentiment_class'] == 'negativo']

# Função para extrair trigrams de uma lista de tokens
def extract_trigrams(tokens):
    return list(ngrams(tokens, 3))

# Extrair trigrams dos títulos de avaliações negativas
all_tokens = [token for title in review_negative['review_title'] for token in title.split()]
trigrams = extract_trigrams(all_tokens)

# Contar a frequência dos trigrams
trigram_freq = Counter(trigrams)
sorted_trigrams = trigram_freq.most_common(10)  # Top 10 trigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(trigram) for trigram, freq in sorted_trigrams]
y_values = [freq for trigram, freq in sorted_trigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='lightgreen')
plt.xlabel('Frequência')
plt.ylabel('Trigrams')
plt.title('Top 10 Trigrams Mais Frequentes em Títulos de Avaliações Negativas')
plt.gca().invert_yaxis()  # Inverte a ordem dos trigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
# Filtrar apenas os casos onde sentiment_class é "negativo"
review_negative = review_product[review_product['sentiment_class'] == 'negativo']

# Função para extrair trigrams de uma lista de tokens
def extract_trigrams(tokens):
    return list(ngrams(tokens, 3))

# Extrair trigrams dos títulos de avaliações negativas
all_tokens = [token for title in review_negative['review_title'] for token in title.split()]
trigrams = extract_trigrams(all_tokens)

# Contar a frequência dos trigrams
trigram_freq = Counter(trigrams)
sorted_trigrams = trigram_freq.most_common(10)  # Top 10 trigrams mais frequentes

# Preparar dados para a tabela
trigram_data = {'Trigram': [' '.join(trigram) for trigram, freq in sorted_trigrams],
                'Frequência': [freq for trigram, freq in sorted_trigrams]}

# Criar dataframe
trigram_df = pd.DataFrame(trigram_data)

df_trigrams_negative_title = trigram_df
df_trigrams_negative_title
# Out:
#                      Trigram  Frequência
# 0       watch negation smart           3
# 1         negation smart one           3
# 2         smart one features           3
# 3          one features make           3
# 4         features make fool           3
# 5         make fool youworst           3
# 6        fool youworst watch           3
# 7  youworst watch connecting           3
# 8   watch connecting problem           3
# 9   connecting problem phone           3

# %% [markdown]
# Principais Trigramas:
#
# * watch negation smart
# * negation smart one
# * smart one features
# * one features make
# * features make fool
# * make fool youworst
# * fool youworst watch
# * youworst watch connecting
# * watch connecting problem
# * connecting problem phone
#
#
# Assim como os bigramas, os trigramas negativos continuam falando características ruins em relação a possivelmente smart watchs.

# %% [markdown]
# ### **Exportando**

# %%
from google.colab import drive
import os

# Montar o Google Drive
drive.mount('/content/drive')

# Definir o caminho do diretório
dir_path = '/content/drive/My Drive/Laboratoria/Projeto 4/Arquivos Finais - CSV/'

# Criar o diretório se ele não existir
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_sentiment_title
df_negative_title
df_positive_title
df_unigrams_positive_title
df_unigrams_negative_title
df_bigrams_positive_title
df_bigrams_negative_title
df_trigrams_positive_title
df_trigrams_negative_title

#exportando
df_sentiment_title.to_csv(dir_path + 'df_sentiment_title.csv', index=False)
df_negative_title.to_csv(dir_path + 'df_negative_title.csv', index=False)
df_positive_title.to_csv(dir_path + 'df_positive_title.csv', index=False)
df_unigrams_positive_title.to_csv(dir_path + 'df_unigrams_positive_title.csv', index=False)
df_unigrams_negative_title.to_csv(dir_path + 'df_unigrams_negative_title.csv', index=False)
df_bigrams_negative_title.to_csv(dir_path + 'df_bigrams_negative_title.csv', index=False)
df_bigrams_positive_title.to_csv(dir_path + 'df_bigrams_positive_title.csv', index=False)
df_trigrams_positive_title.to_csv(dir_path + 'df_trigrams_positive_title.csv', index=False)
df_trigrams_negative_title.to_csv(dir_path + 'df_trigrams_negative_title.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-333-735b9ef338ef> in <cell line: 8>()
#       6 df_bigrams_positive_title
#       7 df_bigrams_negative_title
# ----> 8 df_trigrams_positive_title
#       9 df_trigrams_negative_title
#      10
#
# NameError: name 'df_trigrams_positive_title' is not defined

# %% [markdown]
# # **Conteúdo das Avaliações**

# %% [markdown]
# Nessa seção, iremos fazer a análise dos sentimentos, examinando o conteúdo das avaliações.

# %% [markdown]
# ## **Tratamento dos textos**

# %%
# Verificar se existem valores nulos na coluna review_content:

review_product['review_content'].isnull().sum()
# Out:
# 0

# %%
# Substituir quebras de linha (\n e \r) da coluna review_title por espaços em uma lista de textos:

import re

def re_breakline(text_list):
    """
    Args:
    ----------
    text_list: list object with text content to be prepared [type: list]
    """

    # Applying regex to replace newlines with spaces
    return [re.sub(r'[\n\r]', ' ', r) for r in text_list]

# Aplicando a função na coluna 'comment' do DataFrame df_comments
review_product['review_content'] = re_breakline(review_product['review_content'].tolist())

# %%
# Remover emojis:

# Função para remover emojis
def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # símbolos & pictogramas
                               u"\U0001F680-\U0001F6FF"  # transporte e símbolos de mapas
                               u"\U0001F1E0-\U0001F1FF"  # bandeiras (iOS)
                               u"\U00002500-\U00002BEF"  # caracteres chineses comuns
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # flags (iOS)
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Remover emojis:
review_product['review_content'] = review_product['review_content'].apply(lambda x: remove_emojis(str(x)))

# %%
# Remover todos os caracteres que não são alfanuméricos (\w) ou espaços em branco (\s):
review_product['review_content'] = review_product['review_content'].str.replace(r'[^\w\s]', '', regex=True)

# %%
# Converter os textos da coluna review_content para letras minúsculas:
review_product['review_content'] = review_product['review_content'].str.lower()

# %%
# Substituir links pela palavra link na coluna review_content:
review_product['review_content'] = review_product['review_content'].str.replace(r'http\S+', 'link', regex=True)

# %%
# Substituir datas pela palavra data na coluna review_content:
review_product['review_content'] = review_product['review_content'].str.replace(r'\d{4}-\d{2}-\d{2}', 'data', regex=True)

# %%
# Substituir símbolos monetários da coluna review_content por "monetary_value":
review_product['review_content'] = review_product['review_content'].str.replace(r'\$\d+', 'monetary_value', regex=True)

# %%
# Substituir valores numéricos da coluna review_content por "numeric_value":
review_product['review_content'] = review_product['review_content'].str.replace(r'\d+', 'numeric_value', regex=True)

# %%
# Substituir palavras de negação da coluna review_content por "negation":
review_product['review_content'] = review_product['review_content'].str.replace(r'\b(no|not|never)\b', 'negation', regex=True)

# %%
# Eliminar espaços em branco desnecessários da coluna review_content:
review_product['review_content'] = review_product['review_content'].str.strip()

# %%
# Remoção de espaços extras entre as palavras:
review_product['review_content'] = review_product['review_content'].apply(lambda x: re.sub(r'\s+', ' ', x.strip()))

# %%
# Substituir "productgood" por "product good" na coluna review_content:
review_product['review_content'] = review_product['review_content'].str.replace(r'productgood', 'product good', regex=True)

# Substituir "qualitygood" por "quality good" na coluna review_content:
review_product['review_content'] = review_product['review_content'].str.replace(r'qualitygood', 'quality good', regex=True)

# %%
# Detectar o idioma de cada título
review_product['language_content'] = review_product['review_content'].apply(detect)

# %%
# Agrupar e contar por idioma:
language_counts_content = review_product.groupby('language_content').size().reset_index(name='count')
language_counts_content
# Out:
#   language_content  count
# 0               en   1458
# 1               te      1

# %%
import spacy

# Carregar o modelo de linguagem do spaCy
nlp = spacy.load("en_core_web_sm")

# Função para filtrar palavras não inglesas
def filter_non_english_words(text):
    doc = nlp(text)
    # Lista de palavras comuns em inglês (usando vocabulário spaCy)
    common_english_words = set([token.text for token in nlp.vocab if token.is_alpha and token.is_lower])
    filtered_words = [token.text for token in doc if token.is_alpha and token.text.lower() in common_english_words]
    return " ".join(filtered_words)

# Aplicar a função para filtrar palavras não inglesas
review_product['review_content'] = review_product['review_content'].apply(filter_non_english_words)

review_product.head(3)
# Out:
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 3  AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 3  R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...
#
#                                         review_title  \
# 0  excellent solution sony tvsworth purchasevery ...
# 1  go pin plug theremixer good well jar goodbut p...
# 3  centre keynice phonegood exam preparing studen...
#
#                                       review_content  \
# 0  sometimes its simple solutions that come to re...
# 1  product is so good but packaging was so badnot...
# 3  phone is ok except middle button its a headach...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 3  https://m.media-amazon.com/images/I/41w5fk8Vl6...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 3  https://www.amazon.in/Nokia-105-Single-Keypad-...     4.0
#
#                                         product_name      category  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen
# 3  Nokia 105 Single SIM, Keypad Mobile Phone with...   Electronics
#
#    discounted_price  actual_price  discount_percentage  \
# 0             239.0         699.0                 66.0
# 1            1999.0        3210.0                 38.0
# 3            1299.0        1599.0                 19.0
#
#                                        about_product language  \
# 0  Replacement for Sony RM-YD092 ,Fits with vario...       en
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...       en
# 3  All-new redesigned Nokia mobile which is famil...       en
#
#                                      tokenized_title  \
# 0  [excellent, solution, sony, tvsworth, purchase...
# 1  [go, pin, plug, theremixer, good, well, jar, g...
# 3  [centre, keynice, phonegood, exam, preparing, ...
#
#                                    lemmatized_tokens  sentiment  \
# 0  excellent solution sony tvs worth purchase ver...     0.3024
# 1  go pin plug the remixer good well jar good but...     0.8820
# 3  centre key nice phone good exam preparing stud...     0.9571
#
#   sentiment_class language_content
# 0        positivo               en
# 1        positivo               en
# 3        positivo               en

# %%
# Função para remover stopwords
nltk.download('stopwords')

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Aplicando a função remove_stopwords à coluna review_content
review_product['review_content'] = review_product['review_content'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Tokenização:

# Baixar os recursos necessários para tokenização
nltk.download('punkt')

# Definir uma função para tokenizar o texto
def tokenize_text(text):
    return word_tokenize(text)

# Aplicar a tokenização em cada conteúdo de avaliação
review_product['tokenized_content'] = review_product['review_content'].apply(tokenize_text)

# Exibir o DataFrame resultante
review_product.head(3)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 3  AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 3  R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...
#
#                                         review_title  \
# 0  excellent solution sony tvsworth purchasevery ...
# 1  go pin plug theremixer good well jar goodbut p...
# 3  centre keynice phonegood exam preparing studen...
#
#                                       review_content  \
# 0  sometimes simple solutions come rescue costly ...
# 1  product good packaging badnot able plug jn soc...
# 3  phone ok except middle button headache rest go...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 3  https://m.media-amazon.com/images/I/41w5fk8Vl6...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 3  https://www.amazon.in/Nokia-105-Single-Keypad-...     4.0
#
#                                         product_name      category  ...  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics  ...
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen  ...
# 3  Nokia 105 Single SIM, Keypad Mobile Phone with...   Electronics  ...
#
#    actual_price  discount_percentage  \
# 0         699.0                 66.0
# 1        3210.0                 38.0
# 3        1599.0                 19.0
#
#                                        about_product language  \
# 0  Replacement for Sony RM-YD092 ,Fits with vario...       en
# 1  Wattage: 500 W; Voltage: 220-240V ; Revolution...       en
# 3  All-new redesigned Nokia mobile which is famil...       en
#
#                                      tokenized_title  \
# 0  [excellent, solution, sony, tvsworth, purchase...
# 1  [go, pin, plug, theremixer, good, well, jar, g...
# 3  [centre, keynice, phonegood, exam, preparing, ...
#
#                                    lemmatized_tokens sentiment  \
# 0  excellent solution sony tvs worth purchase ver...    0.3024
# 1  go pin plug the remixer good well jar good but...    0.8820
# 3  centre key nice phone good exam preparing stud...    0.9571
#
#    sentiment_class language_content  \
# 0         positivo               en
# 1         positivo               en
# 3         positivo               en
#
#                                    tokenized_content
# 0  [sometimes, simple, solutions, come, rescue, c...
# 1  [product, good, packaging, badnot, able, plug,...
# 3  [phone, ok, except, middle, button, headache, ...
#
# [3 rows x 21 columns]

# %%
# Lematização:

# Baixar recursos necessários para lematização
nltk.download('wordnet')
nltk.download('omw-1.4')

# Definir a lematização
lemmatizer = WordNetLemmatizer()

# Definir uma função para lematizar tokens
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# Aplicar a função de lematização em cada lista de tokens
review_product['lemmatized_tokens_content'] = review_product['tokenized_content'].apply(lemmatize_tokens)

# Exibir o DataFrame resultante
review_product.head(3)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                              user_id  product_id  \
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B07ZR4S1G4
# 1  AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS...  B00HVXS7WC
# 3  AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25...  B09V2PZDX8
#
#                                            review_id  \
# 0  RN7RYZ9MBIC42,R2N4UBCVLGVVTW,R2E80AM1QM7WZ3,R2...
# 1  R143O8SM7QE4W5,RQBZ31QLH40O,R3KZC4ST0RAK64,R2P...
# 3  R1BFOK13WV2QLM,R3H97FN1H50F7F,R1IY2IDRUJX5O5,R...
#
#                                         review_title  \
# 0  excellent solution sony tvsworth purchasevery ...
# 1  go pin plug theremixer good well jar goodbut p...
# 3  centre keynice phonegood exam preparing studen...
#
#                                       review_content  \
# 0  sometimes simple solutions come rescue costly ...
# 1  product good packaging badnot able plug jn soc...
# 3  phone ok except middle button headache rest go...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1                                       indisponível
# 3  https://m.media-amazon.com/images/I/41w5fk8Vl6...
#
#                                         product_link  rating  \
# 0  https://www.amazon.in/Universal-Remote-Control...     4.4
# 1                                       indisponível     4.2
# 3  https://www.amazon.in/Nokia-105-Single-Keypad-...     4.0
#
#                                         product_name      category  ...  \
# 0  Universal Remote Control for All Sony TV for A...   Electronics  ...
# 1  Bajaj Rex 500W Mixer Grinder with Nutri-Pro Fe...  Home&Kitchen  ...
# 3  Nokia 105 Single SIM, Keypad Mobile Phone with...   Electronics  ...
#
#    discount_percentage                                      about_product  \
# 0                 66.0  Replacement for Sony RM-YD092 ,Fits with vario...
# 1                 38.0  Wattage: 500 W; Voltage: 220-240V ; Revolution...
# 3                 19.0  All-new redesigned Nokia mobile which is famil...
#
#    language                                    tokenized_title  \
# 0        en  [excellent, solution, sony, tvsworth, purchase...
# 1        en  [go, pin, plug, theremixer, good, well, jar, g...
# 3        en  [centre, keynice, phonegood, exam, preparing, ...
#
#                                    lemmatized_tokens sentiment  \
# 0  excellent solution sony tvs worth purchase ver...    0.3024
# 1  go pin plug the remixer good well jar good but...    0.8820
# 3  centre key nice phone good exam preparing stud...    0.9571
#
#   sentiment_class  language_content  \
# 0        positivo                en
# 1        positivo                en
# 3        positivo                en
#
#                                    tokenized_content  \
# 0  [sometimes, simple, solutions, come, rescue, c...
# 1  [product, good, packaging, badnot, able, plug,...
# 3  [phone, ok, except, middle, button, headache, ...
#
#                            lemmatized_tokens_content
# 0  [sometimes, simple, solution, come, rescue, co...
# 1  [product, good, packaging, badnot, able, plug,...
# 3  [phone, ok, except, middle, button, headache, ...
#
# [3 rows x 22 columns]

# %% [markdown]
# ## **Análise de Sentimentos**

# %%
# Instalar as bibliotecas necessárias

# Inicializar o analisador VADER
analyzer = SentimentIntensityAnalyzer()

# Função para analisar o sentimento usando VADER
def analyze_sentiment_vader(text):
    if not text or (isinstance(text, float) and math.isnan(text)):
        return None

    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']  # Usar o valor compound para uma visão geral do sentimento

# Supondo que review_product seja seu DataFrame e 'lemmatized_tokens' a coluna de texto
review_product['sentiment_content'] = review_product['lemmatized_tokens_content'].apply(lambda x: analyze_sentiment_vader(str(x)))

# Remover linhas onde a análise de sentimento retornou None
review_product = review_product.dropna(subset=['sentiment_content'])

# Mostrar os resultados
print(review_product[['lemmatized_tokens_content', 'sentiment_content']])
# Out:
#                               lemmatized_tokens_content  sentiment_content
# 0     [sometimes, simple, solution, come, rescue, co...             0.9800
# 1     [product, good, packaging, badnot, able, plug,...             0.8176
# 3     [phone, ok, except, middle, button, headache, ...             0.8977
# 4     [phone, ok, except, middle, button, headache, ...             0.8977
# 5     [phone, ok, except, middle, button, headache, ...             0.8977
# ...                                                 ...                ...
# 1459  [smart, watch, good, proper, large, displayvoi...             0.9954
# 1460  [fast, chargingcable, seems, good, quality, ne...             0.9560
# 1461  [fast, chargingcable, seems, good, quality, ne...             0.9560
# 1462  [fast, chargingcable, seems, good, quality, ne...             0.9560
# 1463  [good, phoneoknice, product, rangeperformance,...             0.6705
#
# [1459 rows x 2 columns]

# %%
# Função para classificar o sentimento
def classify_sentiment(score):
    if score >= 0.05:
        return 'positivo'
    elif score <= -0.05:
        return 'negativo'
    else:
        return 'neutro'

# Aplicar a função de classificação
review_product['sentiment_class_content'] = review_product['sentiment_content'].apply(classify_sentiment)

# Mostrar os resultados
print(review_product[['lemmatized_tokens_content', 'sentiment_content', 'sentiment_class_content']])
# Out:
#                               lemmatized_tokens_content  sentiment_content  \
# 0     [sometimes, simple, solution, come, rescue, co...             0.9800
# 1     [product, good, packaging, badnot, able, plug,...             0.8176
# 3     [phone, ok, except, middle, button, headache, ...             0.8977
# 4     [phone, ok, except, middle, button, headache, ...             0.8977
# 5     [phone, ok, except, middle, button, headache, ...             0.8977
# ...                                                 ...                ...
# 1459  [smart, watch, good, proper, large, displayvoi...             0.9954
# 1460  [fast, chargingcable, seems, good, quality, ne...             0.9560
# 1461  [fast, chargingcable, seems, good, quality, ne...             0.9560
# 1462  [fast, chargingcable, seems, good, quality, ne...             0.9560
# 1463  [good, phoneoknice, product, rangeperformance,...             0.6705
#
#      sentiment_class_content
# 0                   positivo
# 1                   positivo
# 3                   positivo
# 4                   positivo
# 5                   positivo
# ...                      ...
# 1459                positivo
# 1460                positivo
# 1461                positivo
# 1462                positivo
# 1463                positivo
#
# [1459 rows x 3 columns]

# %% [markdown]
# ### **Entradas classificadas como positivas, negativas ou neutras**
#
#
#
# ---

# %% [markdown]
# **Total por classificação**
#
#
# ---

# %%
# Contar total de "negativo" na coluna sentiment_class_content:
total_negativo_2 = review_product[review_product['sentiment_class_content'] == 'negativo'].shape[0]
print("Total de 'negativo':", total_negativo_2)

# Contar total de "positivo" na coluna sentiment_class_content:
total_positivo_2 = review_product[review_product['sentiment_class_content'] == 'positivo'].shape[0]
print("Total de 'positivo':", total_positivo_2)

# Contar total de "neutro" na coluna sentiment_class_content:
total_neutro_2 = review_product[review_product['sentiment_class_content'] == 'neutro'].shape[0]
print("Total de 'neutro':", total_neutro_2)
# Out:
# Total de 'negativo': 27
# Total de 'positivo': 1423
# Total de 'neutro': 9

# %% [markdown]
# **Gráfico com a distribuição por classificação**
#
#
# ---

# %%
# gráfico de barras

# Dados para o gráfico
sentiment_counts = {
    'positivo': total_positivo_2,
    'negativo': total_negativo_2,
    'neutro': total_neutro_2
}

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(sentiment_counts.keys(), sentiment_counts.values(), color=['darkgoldenrod', 'orange', 'khaki'])
plt.xlabel('Sentimento')
plt.ylabel('Total de Entradas')
plt.title('Distribuição de Sentimentos nas Avaliações de Produtos')
plt.show()

# %% [markdown]
# É possível observar que a grande maioria das entradas foram classificadas como **positivas**.

# %% [markdown]
# **Conteúdo das avaliações classificadas como negativas**
#
#
# ---

# %%
with pd.option_context('display.max_colwidth', None, 'display.max_columns', None, 'display.max_rows', None):
    display(review_product[review_product['sentiment_class_content'] == 'negativo'][['review_title','review_content']])
# Out:
#                                                                                                                                                                                                                                  review_title  \
# 40                                                                                                    good productnot upto expectationnot recommended buyingvery delicate productworth buygood productjust fine buygood stickiness bad handle
# 121   good product worst deliveryoverall ok outer steel kafi hot ho jata hejo kids k liye kafi harmful henice productlovely product filtering holes big ants get indont buy prestige water kettle productbest productmediumheats handle sides
# 132                                                                                                                     lightingtiny usefulfair productworth money case usb pin got broken month usagegoodsmall handygood productworth buying
# 193                                                                                                                  need improve outlookscratch product noisy oneexcellent product goodfabulousgood itemvery bad experiencebest market price
# 212                                                                                                                                                         usablegoodawesomesatisfiedpurifierbeware buy onlinevery good quailityeasy install
# 235                                                                                                           juicer negation effectiveok goodproducts quality goodcoupler stopped working within months buyingit goodgood buygoodweight less
# 328                                                                                                         good product negation excellent sayvery poor qualityokgoodvery good product satisfied performancewill get job donegoodvalue money
# 545                                                                                                                                                                        goodbest pricegood phonenicevalue moneyठकठक hai overall reviewgood
# 546                                                                                                                                                                        goodbest pricegood phonenicevalue moneyठकठक hai overall reviewgood
# 547                                                                                                                                                                        goodbest pricegood phonenicevalue moneyठकठक hai overall reviewgood
# 584                                                                                                                                         good product budget pricei purchased product shop rs including everything buy amazonworst product
# 605                                                                                                  niceperfect reliable standard size good suction bathroomgood got costly exhaust bathroomgood productrequest returnexchangeeasy useno bad
# 695                                                                                                                                                                        good goodgood productsatisfiedgood small roomunsurenot baddont bye
# 847                                                                                                                                       totally simple good product goodnormalrice cooker goodexcellent productgud productpowergood product
# 859                                                                                                                                                     good productnot badworking airtel dthgoodok negation badthis oldnot bed worst product
# 866                                                                           good productvalue moneyauto cut negation working properly fan continues even auto cutroom heaterworth moneybudget friendlybest room heaternot satisfied product
# 917                                                                                                                               great productvery good working nicehorrible user experience account poor hardwarenot worthy laggy sometimes
# 942                                                                                     negation per descriptionits negation battery fooling namedesign problem getting overheatedit good medium speed chargergoodok chinesegoodfast charging
# 964   fast charging cablegood productdont buyexcellent design material quality amazing charging speedit supports fast charging also support android auto cargood type c cable less pricefast charging negation supportnot fast charging cable
# 1054                                                                                                                    highly displayedvery convenient egg boilinggood produvtgoodnice fitting issuequality itemautocut stopped working days
# 1115                                                                                                                        yet know performancegoodhamara bajajbattery isuegood png model made chinavalue moneyexpansiveservice installation
# 1120                                                                                                                              sensors burnt wrist upon wearing overnightworst buyits goodlow battery life okay buysuperb goodgood product
# 1220                              goodsound low another brand comparing betterservice provider negation meet home refuse tv negation using bad servicegood productok superfloor stand negation come gooda budget friendly tv clumsy ui remote
# 1221                              goodsound low another brand comparing betterservice provider negation meet home refuse tv negation using bad servicegood productok superfloor stand negation come gooda budget friendly tv clumsy ui remote
# 1222                              goodsound low another brand comparing betterservice provider negation meet home refuse tv negation using bad servicegood productok superfloor stand negation come gooda budget friendly tv clumsy ui remote
# 1271                                                                                                                     poor productnot working properlyaveragenice itemscord negation enough longgoodgoogeverything fine except cord length
# 1363                                                              overall good productvalue money brandheatergood product home room heaterits negation repairable allelectricity current passing entire bodyone rod negation working solution
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  review_content
# 40                                                                                                                                                                                                                                                                                                                                 issue built quality poor broke use rest adhesion goodthe product negation sturdy handle broke weekthe adhesive working diffuct peel tapeproduct okay stick delicate broke difficult use productthe handle product broke used second time poor quality would negation recommendits value moneyeasy useproduct good use wish handle roller easy usewe beagle dog extensive use lint rollers household using expensive consume rollers every month thought trying one though bad lint roller stickiness glue paper good enough remove dog hair quality handle really bad negation even last days ended using wooden stick long pencils job makers spent making good handle even cost would rs higher could great product especially households pets need frequently might go back buying product look something
# 121                                                                                                                                                                                                                                                                                                                 product got damaged request replacement pain strated days continuing follow product got replaced amazon delivery guys rude days negation wonder customer care give generic sop reply anyways product got delivered good feel like expensive colour quality averagei like product dislike outer steel makes hot full chargedonly disappointed cord lengthlovely productsturdynice colorissue house water filtering holes big enough dispense leftover water everyday wash pot heatingin months stops working service center almost close pune frusteted product bad service prestige negation go productvery good productmedium typethe fiber plastic handle becomes hot outer body difficult handle immediately heating easy clean cord length medium enough keep kettle height ground kept vertically line electric switch
# 132                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        recieved wrong color oksimple quick solution night time study session bought rupees cuz nt wanna pay rs shipping order productgo use carefully plugging insuperpurchased pieces kept one travel bag use travels rural areas fix power bank power cuts one cargood productvalue money
# 193                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          look item negation impressive need improve cord length negation sufficient bouble existing lengthgot kettle yesterday got scratches kettle bit noisy automatic switch negation workingnicegood workmaza agyaliked mosteasy usei gifted item think nt item came loose handle kept water boiling whole unit hot including handle lid negation stopping automatically water boiled total waste money nt expect poor companybest price
# 212                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     good servicegoodi like producttaste also good worth money productoki updating review hope get published brand pay attention every two three months unit problem inlet system many times inlet stops taking water indicator shows tank filling rectified service person indicator showing tank filling inlet valve shut show purple light means low negation pressure faulty unit installation guy service persons right stated faulty low quality units sold online whose statement ignored thinking every offline seller says alas wrong want unit removed immediately want hard earned money backat price product suitableesy install
# 235                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       juicer negation effectiveok goodlink expect prestige product stop working within months buying coupler nt rotating tried reset still negation working waste money brandnicegood qualityworth buy iteasy use clean noisy use small baby wake sleepingmotor sound heavy
# 328                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          two negative things mention cable rigid movement usb connector point inserting removing device end usb connector little loose must tightly seatedother features alrightthis fourth time order cable earlier cable good seems compromise quality negation happyworth valuegoodvery good product value money satisfied performancewont cure cancer simple cable nothing much expectvery good producttoo longdurablegood retro device
# 545                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                camera display poor quality battery good nothing badnice phone reasonable pricegoodnicevalue moneytheek hai negation badgood
# 546                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                camera display poor quality battery good nothing badnice phone reasonable pricegoodnicevalue moneytheek hai negation badgood
# 547                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                camera display poor quality battery good nothing badnice phone reasonable pricegoodnicevalue moneytheek hai negation badgood
# 584                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           like happyplease nt buy heater stopped working days negation able return product also waste money
# 605                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        reasonably good producta bit costly meusing since year negation problem facedsound normalthe shape negation fit want get installed want round one get exchanged returned pleaseeasy usegood product speed bit low hence less suction power low noise
# 695                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          workinggoodgood product nice productcant use long hours good small rooms used minimum amount timenot sure use overnightnice bad high priceplease nt bye ordered amazon basics room heater running well two months suddenly stop working want claim year warrenty customer card service really sucks called customer service first told register warrenty first register warrenty takes days register apply warrenty told email amazon brand email disaster started told email takes days process warrenty till date days complain register nt get warrenty till date please nt bye
# 847                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        using cooking riceits getting repair regularlyrecently buy new rice cooker averageexcellent productvery good productpower adapter negation working pins gone wrong remaking goodlike
# 859                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            value moneyusually gdgood product goodquality poor responce latethis looking guessquality okk negation bed body negation proper tight fixedthe product poor quality seems like duplicate remote nt work properly
# 866                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        good product price ok product goodeasy use handyauto cut continue starts fanwhich lower tempi liked swivelling action spread heatbeat productbest room heaterthank youi received broken article negation replacement service product
# 917                                                                                                                everything great love thisvery good working nicefirst thanks amazon listing returnable item effective cost less device reason purchasing experience google tv account interface useful standard android tv one terms discovery listed content negation relevanthowever realme lets user device bug ridden beginning basically abandoned device months last software update feb still riddled bugs negation see google tv stick heats enough scald touch stutters like crazy usage day part due lackluster arm cores lacking performance compared cores present sticks years ago also due poor ram managementonly reason get would price less prepared suffer laggy interface known issues remote failing within months still males sense get fire tv stick refined receives updates although interface love hate onefor google tv experience better go google tv chrome cast costs bomb india offersgot used productit trapped also proformance twice degrade fire stick also negation sucking wifi well computer fire stick
# 942                                                                                                                                                                                                                                                                                                                                                                                                                                                             batteries negation charge per description charge hrs full recharge used properly hrs charges charging negation last days usei noticed got batteries much lighter normal batteries suspicious using heavily battery runs much quicker battery saw back case written batteryeverything else works fine intended nt think deceiving customers giving another product advertising something else fraud behavior price justifiedgetting overheated charging hour fear getting melted bodygood mid speed chargeri impressedno chinese goods favouritei like product using keyboardcharging battery hours time hrsgood onei using charger charge existing rechargable batteries aa aaa
# 964                                                                                                                                                                                                                                                                                                            awesome product fast mobile charging cable like itgood product wish available black white gets dirty easilyfor month negation issues started becoming useless nt buy looks alright bad local cable phone charges slowly disconnect connect cables ports reassemble still would reduce battery nt used worse cable disappointing money waste also packaging open negation sealed recieved seller fraudlittle grip given plugin typec pin sideso smoothly remove instead sudden little jerkfirst l shaped port easy use charge iam using car android autooverall excellentlink fast charging adapter slow charging cable vooc negation supportthough call fast charging cable actually negation fast charging cablei tried samsung fast charging adapter slow charging cable look sturdiness etc impressiveplanning return product
# 1054                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              negation bad negation goodtakes mins make hard boil eggscan also used steam momosall goodgoodvery comfortable stylish productlid negation fitted productquality item goodoverall ok product autocut stopped working days light also negation work properly cautious wait time
# 1115                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            week yet know performance overall till date working finegoodgood qualitybattery capacity poor powerproduct fine disappointed seeing made china lable png version also seller sent lpg model first instead png check model received product working finelink seems working fine till poor service bajaj servicemanhe came hanged geyser wall said work limited onlywe call another technician complete installation plumbing workeven pipes cells negation come geyser sold bajaj serviceman marks bajaj service
# 1120                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          sensors burnt two point dia wrist upon wearing overnight abandoned using fear enclosed photos herewithworst buy belt quality totally poor performance average negation proper tracing activities battery life averagevalue moneyits goodlow batter lifenice smartwatch big display long battery life max featuresgoodgood product
# 1220                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              overall goodtv picture ok smart bettersound low another brandservice provider refuse install tv bad service samsung calling times service provider negation meet home addresswhy bad badthey product negation come support stand wall hanging hook install tvpicture quality poor cablesfloor stand negation come buy seperately request amazon cleary mention add pay seperate charges installation guy buy floor mount good
# 1221                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              overall goodtv picture ok smart bettersound low another brandservice provider refuse install tv bad service samsung calling times service provider negation meet home addresswhy bad badthey product negation come support stand wall hanging hook install tvpicture quality poor cablesfloor stand negation come buy seperately request amazon cleary mention add pay seperate charges installation guy buy floor mount good
# 1222                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              overall goodtv picture ok smart bettersound low another brandservice provider refuse install tv bad service samsung calling times service provider negation meet home addresswhy bad badthey product negation come support stand wall hanging hook install tvpicture quality poor cablesfloor stand negation come buy seperately request amazon cleary mention add pay seperate charges installation guy buy floor mount good
# 1271                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             product company heating liters water minutes wastage electricity moneyvery bad quality wire rodthe product ok quality bit low ca nt expect premium costvery fastergudnicenicecord length small
# 1363  product nice bigger socket plug negation easly available cornersit negation suffocatinglink go however knowing consumes lot electricity buy live punjab upto units free hehei earlier bought helps keep place really warmvery good product winter kids much moreall ecectric devices prone damages faults possible repaired unfortunately product nt option purchase went complete wastefirst things firstits negation bad heater provides plenty warmthhowever unit received one major rather fatal issue current passing entire body front grill area near handle back ca nt hold without getting electric shock running turn knob simply move one position another would need unplug power source first otherwise fatal use night keep reach otherwise wake night drinking water anything else might accidentally touch die homes children needs extra protectivenow negation sure whether fault unit general problem type heaters requested replacement lets see replacement unit works ill update review accordinglyin heater one rod negation working call bajaj customer care number given pamphlet person came bajaj issue solved

# %%
# Exportar dataframe com o conteúdo das avaliações negativas:
review_product[review_product['sentiment_class_content'] == 'negativo'][['review_content']].to_csv('review_product_negative_content.csv', index=False)

# %%
# colocar o conjunto de entradas positivas e negativas em um data frame
df_negativo = review_product[review_product['sentiment_class_content'] == 'negativo']
df_positivo = review_product[review_product['sentiment_class_content'] == 'positivo']

df_avaliacoes = pd.concat([df_negativo, df_positivo])
df_avaliacoes
# Out:
#                                                 user_id  product_id  \
# 40    AE556ASSODHNECNYDEABP6Q7Z75Q,AESPTUXAQMTJ64NCR...  B07HK53XM4
# 121   AEDCFJT7COKZ3DP4YGWKH6KU7LAA,AFCOSVW2NHSFLPG7O...  B07VNFP3C2
# 132   AEEH5DFNKICJXQME6UXNS3P3OM3A,AGBSAL7DSIA2DOH4O...  B08TDJ5BVF
# 193   AEKI4HAUSUPZGRQ6Q3ATSP4TB6CQ,AEL7BRNIG3LMKHN7N...  B094G9L9LT
# 212   AELCV26DAB56JEU7CL2LUTR2TYKA,AHQQWCVTBJQ767433...  B096NTB9XT
# ...                                                 ...         ...
# 1459  AHZNSNBVKQR4OGJAQHE4DCDA4YHA,AFBW6COTZXGHQMWVD...  B0B3MWYCHQ
# 1460  AHZWJCVEIEI76H2VGMUSN5D735IQ,AH2DFUHFTG4CKQFVG...  B09W5XR9RT
# 1461  AHZWJCVEIEI76H2VGMUSN5D735IQ,AH2DFUHFTG4CKQFVG...  B09W5XR9RT
# 1462  AHZWJCVEIEI76H2VGMUSN5D735IQ,AH2DFUHFTG4CKQFVG...  B09W5XR9RT
# 1463  AHZWXUWE3RGLDH4JJUK3HT3VMBJA,AFWUWJMEO4IQEMHKM...  B09HSKYMB3
#
#                                               review_id  \
# 40    R2T39I2ZEKM9PL,R1ZBMWBRCRX6M1,R14ROZ9SPSVA1C,R...
# 121   R3QP7PGD3SMG5I,R3ANC3TLK8732Y,RE9NKZ6CH2C3S,R2...
# 132   R3163MRJDEJMN7,RSQGCR6V7H766,R39PS8UO1CZS2D,R2...
# 193   R18T6LNT4V3WIK,R3J5KJWXWZ9BTL,R27KT7RSJUJ9WK,R...
# 212   RU0EQUWAQWSU6,R2R99SCVYQYHPL,R7O3R0R2OR9EZ,R1E...
# ...                                                 ...
# 1459  R1AIQQLE21YDXS,R26ABOIUJ8UXJ7,R93L2MCBC4Y90,R2...
# 1460  R1Y30KU04V3QF4,RK3DSUGKIZT8Z,R3BIG7J6V2JZTU,R1...
# 1461  R1Y30KU04V3QF4,RK3DSUGKIZT8Z,R3BIG7J6V2JZTU,R1...
# 1462  R1Y30KU04V3QF4,RK3DSUGKIZT8Z,R3BIG7J6V2JZTU,R1...
# 1463  R1GS92IDBGXYCS,R8H8QTOWYMITR,RCSP9RH3A0VAE,R2S...
#
#                                            review_title  \
# 40    good productnot upto expectationnot recommende...
# 121   good product worst deliveryoverall ok outer st...
# 132   lightingtiny usefulfair productworth money cas...
# 193   need improve outlookscratch product noisy onee...
# 212   usablegoodawesomesatisfiedpurifierbeware buy o...
# ...                                                 ...
# 1459  pocket friendly smart watch people loves large...
# 1460  good productusing spare cable carsturdy durabl...
# 1461  good productusing spare cable carsturdy durabl...
# 1462  good productusing spare cable carsturdy durabl...
# 1463  goodoknice product negation good negation matc...
#
#                                          review_content  \
# 40    issue built quality poor broke use rest adhesi...
# 121   product got damaged request replacement pain s...
# 132   recieved wrong color oksimple quick solution n...
# 193   look item negation impressive need improve cor...
# 212   good servicegoodi like producttaste also good ...
# ...                                                 ...
# 1459  smart watch good proper large displayvoice ass...
# 1460  fast chargingcable seems good quality negation...
# 1461  fast chargingcable seems good quality negation...
# 1462  fast chargingcable seems good quality negation...
# 1463  good phoneoknice product rangeperformance fine...
#
#                                                img_link  \
# 40                                         indisponível
# 121                                        indisponível
# 132   https://m.media-amazon.com/images/I/31s6OZfTO2...
# 193                                        indisponível
# 212                                        indisponível
# ...                                                 ...
# 1459  https://m.media-amazon.com/images/I/41ziJKWj9L...
# 1460  https://m.media-amazon.com/images/W/WEBP_40237...
# 1461  https://m.media-amazon.com/images/I/4177nw8okb...
# 1462  https://m.media-amazon.com/images/I/4177nw8okb...
# 1463  https://m.media-amazon.com/images/I/31Hb9RGI+j...
#
#                                            product_link  rating  \
# 40                                         indisponível     3.5
# 121                                        indisponível     3.9
# 132   https://www.amazon.in/COSMOS-Portable-Flexible...     3.8
# 193                                        indisponível     3.8
# 212                                        indisponível     4.0
# ...                                                 ...     ...
# 1459  https://www.amazon.in/Fire-Boltt-Bluetooth-Ass...     4.2
# 1460  https://www.amazon.in/Duracell-Lightning-Certi...     4.4
# 1461  https://www.amazon.in/Duracell-Lightning-Certi...     4.4
# 1462  https://www.amazon.in/Duracell-Lightning-Certi...     4.4
# 1463  https://www.amazon.in/REDMI-Sport-Carbon-Black...     4.3
#
#                                            product_name  \
# 40    Bulfyss Plastic Sticky Lint Roller Hair Remove...
# 121           Prestige 1.5 Litre Kettle 1500-watts, Red
# 132   E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...
# 193   KENT 16088 Vogue Electric Kettle 1.8 Litre 150...
# 212   Aquaguard Aura RO+UV+UF+Taste Adjuster(MTDS) w...
# ...                                                 ...
# 1459  Fire-Boltt Ring 3 Smart Watch 1.8 Biggest Disp...
# 1460  Duracell USB C To Lightning Apple Certified (M...
# 1461  Duracell USB C To Lightning Apple Certified (M...
# 1462  Duracell USB C To Lightning Apple Certified (M...
# 1463  MI REDMI 9i Sport (Carbon Black, 64 GB) (4 GB ...
#
#                    category  ...  language  \
# 40             Home&Kitchen  ...        en
# 121            Home&Kitchen  ...        en
# 132   Computers&Accessories  ...        en
# 193            Home&Kitchen  ...        en
# 212            Home&Kitchen  ...        en
# ...                     ...  ...       ...
# 1459            Electronics  ...        en
# 1460  Computers&Accessories  ...        en
# 1461  Computers&Accessories  ...        en
# 1462  Computers&Accessories  ...        en
# 1463            Electronics  ...        en
#
#                                         tokenized_title  \
# 40    [good, productnot, upto, expectationnot, recom...
# 121   [good, product, worst, deliveryoverall, ok, ou...
# 132   [lightingtiny, usefulfair, productworth, money...
# 193   [need, improve, outlookscratch, product, noisy...
# 212   [usablegoodawesomesatisfiedpurifierbeware, buy...
# ...                                                 ...
# 1459  [pocket, friendly, smart, watch, people, loves...
# 1460  [good, productusing, spare, cable, carsturdy, ...
# 1461  [good, productusing, spare, cable, carsturdy, ...
# 1462  [good, productusing, spare, cable, carsturdy, ...
# 1463  [goodoknice, product, negation, good, negation...
#
#                                       lemmatized_tokens sentiment  \
# 40    good product not up to expectation not recomme...    0.7944
# 121   good product worst delivery overall ok outer s...    0.8957
# 132   lighting tiny useful fair product worth money ...    0.8658
# 193   need improve outlook scratch product noisy one...    0.9410
# 212   usable good awesome satisfied purifier beware ...    0.9422
# ...                                                 ...       ...
# 1459  pocket friendly smart watch people love large ...    0.9744
# 1460  good product using spare cable car sturdy dura...    0.9738
# 1461  good product using spare cable car sturdy dura...    0.9738
# 1462  good product using spare cable car sturdy dura...    0.9738
# 1463  good ok nice product negation good negation ma...    0.9552
#
#      sentiment_class language_content  \
# 40          positivo               en
# 121         positivo               en
# 132         positivo               en
# 193         positivo               en
# 212         positivo               en
# ...              ...              ...
# 1459        positivo               en
# 1460        positivo               en
# 1461        positivo               en
# 1462        positivo               en
# 1463        positivo               en
#
#                                       tokenized_content  \
# 40    [issue, built, quality, poor, broke, use, rest...
# 121   [product, got, damaged, request, replacement, ...
# 132   [recieved, wrong, color, oksimple, quick, solu...
# 193   [look, item, negation, impressive, need, impro...
# 212   [good, servicegoodi, like, producttaste, also,...
# ...                                                 ...
# 1459  [smart, watch, good, proper, large, displayvoi...
# 1460  [fast, chargingcable, seems, good, quality, ne...
# 1461  [fast, chargingcable, seems, good, quality, ne...
# 1462  [fast, chargingcable, seems, good, quality, ne...
# 1463  [good, phoneoknice, product, rangeperformance,...
#
#                               lemmatized_tokens_content sentiment_content  \
# 40    [issue, built, quality, poor, broke, use, rest...           -0.6478
# 121   [product, got, damaged, request, replacement, ...           -0.4215
# 132   [recieved, wrong, color, oksimple, quick, solu...           -0.4215
# 193   [look, item, negation, impressive, need, impro...           -0.5563
# 212   [good, servicegoodi, like, producttaste, also,...           -0.7845
# ...                                                 ...               ...
# 1459  [smart, watch, good, proper, large, displayvoi...            0.9954
# 1460  [fast, chargingcable, seems, good, quality, ne...            0.9560
# 1461  [fast, chargingcable, seems, good, quality, ne...            0.9560
# 1462  [fast, chargingcable, seems, good, quality, ne...            0.9560
# 1463  [good, phoneoknice, product, rangeperformance,...            0.6705
#
#      sentiment_class_content
# 40                  negativo
# 121                 negativo
# 132                 negativo
# 193                 negativo
# 212                 negativo
# ...                      ...
# 1459                positivo
# 1460                positivo
# 1461                positivo
# 1462                positivo
# 1463                positivo
#
# [1450 rows x 24 columns]

# %% [markdown]
# ### **Unigramas**
#
#
#
# ---

# %% [markdown]
# #### **Unigrams | 10 palavras mais comuns nas avaliações positivas**

# %%
# Filtrar apenas os casos onde sentiment_class_content é "positivo"
reviews_negative = review_product[review_product['sentiment_class_content'] == 'positivo']

# Contar as palavras no conteúdo das avaliações
all_words = ' '.join(reviews_negative['review_content']).split()
token_frequencies = Counter(all_words)

# Extrair as palavras e suas frequências
words_positive, frequencies_positive = zip(*token_frequencies.most_common(10))

# Configurações de estilo do seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Plotar o gráfico de barras usando seaborn
ax = sns.barplot(y=words_positive, x=frequencies_positive, palette="Blues_d")
ax.set_title('Top 10 Palavras Mais Comuns em Avaliações Positivas')
ax.set_xlabel('Frequência')
ax.set_ylabel('Palavras')
ax.set_yticklabels(words_positive, rotation=0)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-360-06ef8b05f364>:16: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-360-06ef8b05f364>:20: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
# adicionar palavras e frequencia em um novo data frame
df_unigramas_positive = pd.DataFrame({'Palavras': words_positive, 'Frequência': frequencies_positive})
df_unigramas_positive
# Out:
#    Palavras  Frequência
# 0      good        4525
# 1  negation        4377
# 2   product        2855
# 3   quality        2089
# 4        nt        1850
# 5       use        1458
# 6       one        1250
# 7     cable        1220
# 8      like        1145
# 9      also        1125

# %% [markdown]
# #### **Unigrams | 10 palavras mais comuns nas avaliações negativas**

# %%
# Filtrar apenas os casos onde sentiment_class_content é "negativo"
reviews_negative = review_product[review_product['sentiment_class_content'] == 'negativo']

# Contar as palavras no conteúdo das avaliações
all_words = ' '.join(reviews_negative['review_content']).split()
token_frequencies = Counter(all_words)

# Extrair as palavras e suas frequências
words, frequencies = zip(*token_frequencies.most_common(10))

# Configurações de estilo do seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Plotar o gráfico de barras usando seaborn
ax = sns.barplot(y=words, x=frequencies, palette="Blues_d")
ax.set_title('Top 10 Palavras Mais Comuns em Avaliações Negativas')
ax.set_xlabel('Frequência')
ax.set_ylabel('Palavras')
ax.set_yticklabels(words, rotation=0)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-362-4799c4480cca>:16: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-362-4799c4480cca>:20: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
# adicionar palavras e frequencia em um novo data frame
df_unigramas_negative = pd.DataFrame({'Palavras': words, 'Frequência': frequencies})
df_unigramas_negative
# Out:
#    Palavras  Frequência
# 0  negation          52
# 1   product          36
# 2      good          22
# 3   quality          16
# 4      poor          15
# 5   service          15
# 6        nt          15
# 7       bad          14
# 8       use          13
# 9   working          13

# %% [markdown]
# ### **Bigramas**
#
#
#
# ---

# %% [markdown]
# #### **Bigrams | 10 palavras mais comuns nas avaliações positivas**

# %%
# Filtrar apenas os casos onde sentiment_class_content é "positivo"
reviews_positive = review_product[review_product['sentiment_class_content'] == 'positivo']

# Função para extrair bigrams de uma lista de tokens
def extract_bigrams(tokens):
    return list(ngrams(tokens, 2))

# Extrair bigrams do conteúdo das avaliações negativas
all_tokens = [token for title in reviews_positive['review_content'] for token in title.split()]
bigrams = extract_bigrams(all_tokens)

# Contar a frequência dos bigrams
bigram_freq = Counter(bigrams)
sorted_bigrams = bigram_freq.most_common(10)  # Top 10 bigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(bigram) for bigram, freq in sorted_bigrams]
y_values = [freq for bigram, freq in sorted_bigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='skyblue')
plt.xlabel('Frequência')
plt.ylabel('Bigrams')
plt.title('Top 10 Bigrams Mais Frequentes em Avaliações Positivas')
plt.gca().invert_yaxis()  # Inverte a ordem dos bigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
#dataframe
df_bigrams_positive = pd.DataFrame({'Bigrams': x_labels, 'Frequência': y_values})
df_bigrams_positive
# Out:
#          Bigrams  Frequência
# 0   good product         363
# 1   product good         280
# 2   quality good         267
# 3   good quality         225
# 4          ca nt         222
# 5  sound quality         215
# 6       easy use         215
# 7  negation good         203
# 8  fast charging         187
# 9    value money         184

# %% [markdown]
# #### **Bigrams | 10 palavras mais comuns nas avaliações negativas**

# %%
# Filtrar apenas os casos onde sentiment_class_content é "negativo"
reviews_positive = review_product[review_product['sentiment_class_content'] == 'negativo']

# Função para extrair bigrams de uma lista de tokens
def extract_bigrams(tokens):
    return list(ngrams(tokens, 2))

# Extrair bigrams do conteúdo das avaliações negativas
all_tokens = [token for title in reviews_positive['review_content'] for token in title.split()]
bigrams = extract_bigrams(all_tokens)

# Contar a frequência dos bigrams
bigram_freq = Counter(bigrams)
sorted_bigrams = bigram_freq.most_common(10)  # Top 10 bigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(bigram) for bigram, freq in sorted_bigrams]
y_values = [freq for bigram, freq in sorted_bigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='skyblue')
plt.xlabel('Frequência')
plt.ylabel('Bigrams')
plt.title('Top 10 Bigrams Mais Frequentes em Avaliações Negativas')
plt.gca().invert_yaxis()  # Inverte a ordem dos bigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
#dataframe
df_bigrams_negative = pd.DataFrame({'Bigrams': x_labels, 'Frequência': y_values})
df_bigrams_negative
# Out:
#             Bigrams  Frequência
# 0     negation come           7
# 1  product negation           5
# 2      poor quality           5
# 3      quality poor           4
# 4       bad service           4
# 5  installation guy           4
# 6      good product           4
# 7         google tv           4
# 8    charging cable           4
# 9     fast charging           4

# %% [markdown]
# Vamos analisar os principais bigramas negativos:
#
# Bigramas mais frequentes em avaliações negativas
#
# - Negative come - Não veio
# - Product come - produto veio.
# - Quality poor - qualidade ruim
# - Bad service - serviço ruim
# - Installation guy - rapaz das instalação
# - Good product - bom produto
# - Google tv
# - Charging cable - cabo de recarga
# - Fast charging - carregamento rápido
#
# 1. **Negative come**:
#
#     Os clientes estão reclamando que o produto não foi entregue ou que a entrega não atendeu às expectativas. Isso aponta para problemas graves no serviço de entrega, que precisam ser investigados e resolvidos imediatamente.
#
# 2. **Product come**:
#
#     Isso pode sugerir que os clientes estão comentando sobre a condição em que o produto chegou. Frases como "product came damaged" ou "product came late" são possíveis contextos. Isso aponta para possíveis problemas logísticos ou de qualidade no transporte.
#
# 3. **Quality poor**:
#
#     Há uma clara indicação de que os clientes estão insatisfeitos com a qualidade do produto. Isso pode levar a uma revisão dos padrões de qualidade e controle do produto.
#
# 4. **Bad service**:
#
#     Os clientes estão insatisfeitos com o atendimento ao cliente ou serviços associados ao produto. Melhorar a formação dos funcionários de suporte ao cliente e revisar os procedimentos de atendimento pode ser necessário.
#
# 5. **Installation guy**:
#
#     Isso pode indicar problemas com o serviço de instalação oferecido. Pode ser útil investigar o desempenho dos técnicos de instalação e a satisfação dos clientes com o serviço prestado.
#
# 6. **Good product**:
#
#     Embora este bigrama seja positivo, seu aparecimento em avaliações negativas pode indicar um contexto em que um produto bom é associado a uma experiência negativa. Por exemplo, "Good product but bad service" ou "Good product but came damaged".
#
# 7. **Google tv**:
#
#     Este bigrama sugere que os clientes mencionam "Google TV" em suas avaliações negativas. Pode haver problemas específicos relacionados a esse produto ou integração com ele que precisam ser investigados.
#
# 8. **Charging cable**:
#
#     Problemas relacionados ao cabo de carregamento são mencionados. Isso pode indicar que os clientes estão enfrentando dificuldades com a durabilidade, compatibilidade ou desempenho dos cabos fornecidos.
#
# 9. **Fast charging**:
#
#     A funcionalidade de carregamento rápido pode estar causando insatisfação. Isso pode incluir reclamações sobre a velocidade real de carregamento, problemas de compatibilidade, ou questões de sobreaquecimento.

# %% [markdown]
# ### **Trigramas**
#
#
#
# ---

# %% [markdown]
# #### **Trigrams | 10 palavras mais comuns nas avaliações positivas**

# %%
# Filtrar apenas os casos onde sentiment_class_content é "positivo"
review_positive = review_product[review_product['sentiment_class_content'] == 'positivo']

# Função para extrair trigrams de uma lista de tokens
def extract_trigrams(tokens):
    return list(ngrams(tokens, 3))

# Extrair trigrams do conteúdo de avaliações positivas
all_tokens = [token for title in review_positive['review_content'] for token in title.split()]
trigrams = extract_trigrams(all_tokens)

# Contar a frequência dos trigrams
trigram_freq = Counter(trigrams)
sorted_trigrams = trigram_freq.most_common(10)  # Top 10 trigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(trigram) for trigram, freq in sorted_trigrams]
y_values = [freq for trigram, freq in sorted_trigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='lightgreen')
plt.xlabel('Frequência')
plt.ylabel('Trigrams')
plt.title('Top 10 Trigrams Mais Frequentes em Avaliações Positivas')
plt.gca().invert_yaxis()  # Inverte a ordem dos trigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
#data frame
df_trigrams_positive = pd.DataFrame({'Trigrams': x_labels, 'Frequência': y_values})
df_trigrams_positive
# Out:
#                 Trigrams  Frequência
# 0  quality negation good          36
# 1      good battery life          35
# 2       product easy use          34
# 3   good quality product          33
# 4     build quality good          32
# 5    product price range          31
# 6      quality also good          30
# 7     good product price          28
# 8       good value money          27
# 9    battery backup good          26

# %% [markdown]
# #### **Trigrams | 10 palavras mais comuns nas avaliações negativas**

# %%
# Filtrar apenas os casos onde sentiment_class_content é "negativo"
review_positive = review_product[review_product['sentiment_class_content'] == 'negativo']

# Função para extrair trigrams de uma lista de tokens
def extract_trigrams(tokens):
    return list(ngrams(tokens, 3))

# Extrair trigrams do conteúdo de avaliações negativas
all_tokens = [token for title in review_positive['review_content'] for token in title.split()]
trigrams = extract_trigrams(all_tokens)

# Contar a frequência dos trigrams
trigram_freq = Counter(trigrams)
sorted_trigrams = trigram_freq.most_common(10)  # Top 10 trigrams mais frequentes

# Preparar dados para o gráfico
x_labels = [' '.join(trigram) for trigram, freq in sorted_trigrams]
y_values = [freq for trigram, freq in sorted_trigrams]

# Gerar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(x_labels, y_values, color='lightgreen')
plt.xlabel('Frequência')
plt.ylabel('Trigrams')
plt.title('Top 10 Trigrams Mais Frequentes em Avaliações Negativas')
plt.gca().invert_yaxis()  # Inverte a ordem dos trigrams para o mais frequente aparecer no topo
plt.tight_layout()
plt.show()

# %%
# Filtrar apenas os casos onde sentiment_class_content é "negativo"
review_negative = review_product[review_product['sentiment_class_content'] == 'negativo']

# Função para extrair trigrams de uma lista de tokens
def extract_trigrams(tokens):
    return list(ngrams(tokens, 3))

# Extrair trigrams do conteúdo de avaliações negativas
all_tokens = [token for title in review_negative['review_content'] for token in title.split()]
trigrams = extract_trigrams(all_tokens)

# Contar a frequência dos trigrams
trigram_freq = Counter(trigrams)
sorted_trigrams = trigram_freq.most_common(10)  # Top 10 trigrams mais frequentes

# Preparar dados para a tabela
trigram_data = {'Trigram': [' '.join(trigram) for trigram, freq in sorted_trigrams],
                'Frequência': [freq for trigram, freq in sorted_trigrams]}

# Criar dataframe
trigram_df = pd.DataFrame(trigram_data)

# Exibir tabela
df_trigrams_negative = trigram_df
df_trigrams_negative
# Out:
#                                     Trigram  Frequência
# 0                       camera display poor           3
# 1                      display poor quality           3
# 2                      poor quality battery           3
# 3                      quality battery good           3
# 4                      battery good nothing           3
# 5                      good nothing badnice           3
# 6                     nothing badnice phone           3
# 7                  badnice phone reasonable           3
# 8       phone reasonable pricegoodnicevalue           3
# 9  reasonable pricegoodnicevalue moneytheek           3

# %% [markdown]
# Trigramas mais frequentes em avaliações negativas:
# * Câmera display poor
# *	Display poor quality
# *	Poor quality batery
# *	Quality batery good
# *	Batery good nothing
# *	Good nothing badnice
# *	Nothing badnice phone
# *	Badnice phone reasonable
# *	Phone reasonable pricegoodnicevalue
# *	Reasonable pricegoodnicevalue moneytheek
#
#
# Os trigramas mais frequentes se tratam de termos associados a baixa qualidade dos produtos, como ter um display ruim, baixa qualidade da bateria, entre outros termos que estão associados ao descontentamento em relação aos produtos adquiridos.
#
# Esses trigramas, trazem os pontos que mais levam avaliações negativas e servem como um norte em relação aos produtos que são vendidos na Amazon.

# %% [markdown]
# ### Exportando

# %%
from google.colab import drive
import os

# Montar o Google Drive
drive.mount('/content/drive')

# Definir o caminho do diretório
dir_path = '/content/drive/My Drive/Laboratoria/Projeto 4/Arquivos Finais - CSV/'

# Criar o diretório se ele não existir
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_sentiment
df_negativo
df_positivo
df_unigramas_positive
df_unigramas_negative
df_bigrams_positive
df_trigrams_positive
df_trigrams_negative
df_avaliacoes

# exportando
df_sentiment.to_csv(dir_path + 'df_sentiment.csv', index=False)
df_negativo.to_csv(dir_path + 'df_negativo.csv', index=False)
df_positivo.to_csv(dir_path + 'df_positivo.csv', index=False)
df_unigramas_positive.to_csv(dir_path + 'df_unigramas_positive.csv', index=False)
df_unigramas_negative.to_csv(dir_path + 'df_unigramas_negative.csv', index=False)
df_bigrams_negative.to_csv(dir_path + 'df_bigrams_negative.csv', index=False)
df_bigrams_positive.to_csv(dir_path + 'df_bigrams_positive.csv', index=False)
df_trigrams_positive.to_csv(dir_path + 'df_trigrams_positive.csv', index=False)
df_trigrams_negative.to_csv(dir_path + 'df_trigrams_negative.csv', index=False)
df_avaliacoes.to_csv(dir_path + 'df_avaliaçoes.csv', index=False)

# %% [markdown]
# ## **Conclusão**

# %% [markdown]
# A análise das abvaliações do produtos da Ama
